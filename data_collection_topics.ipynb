# %% [markdown]
# # The New York Times articles in 2019 and 2020: what prevails.

# %% [markdown]
# This is the first notebook of the New York Times project series. The goal of this notebook is to analyze the headlines, keywords and the lead paragraphs of the NYT throughout the past year and a half and distinguish the most prevalent issues and enduring topics.

# %% [markdown]
# #### Import tools and libraries:

# %%
import os
import pandas as pd
import requests
import json
import time
import dateutil
import datetime
import configparser
from dateutil.relativedelta import relativedelta
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %% [markdown]
# #### Determine the timeframe of the analysis:

# %%
end = datetime.date.today()
start = datetime.date(2019, 1, 1)
print('Start date: ' + str(start))
print('End date: ' + str(end))
# Out:
# Start date: 2019-01-01
# End date: 2020-08-31

# %% [markdown]
# #### Breaking the data into the monthly groups:

# %%
months_in_range = [x.split(' ') for x in pd.date_range(start, end, freq='MS').strftime("%Y %-m").tolist()]
months_in_range
# Out:
# [['2019', '1'],
#  ['2019', '2'],
#  ['2019', '3'],
#  ['2019', '4'],
#  ['2019', '5'],
#  ['2019', '6'],
#  ['2019', '7'],
#  ['2019', '8'],
#  ['2019', '9'],
#  ['2019', '10'],
#  ['2019', '11'],
#  ['2019', '12'],
#  ['2020', '1'],
#  ['2020', '2'],
#  ['2020', '3'],
#  ['2020', '4'],
#  ['2020', '5'],
#  ['2020', '6'],
#  ['2020', '7'],
#  ['2020', '8']]

# %% [markdown]
# #### The helper functions below extract the NYT data through the API and save it into csv files:

# %%
def send_request(date):
    '''Sends a request to the NYT Archive API for given date.'''
    base_url = 'https://api.nytimes.com/svc/archive/v1/'
    url = base_url + '/' + date[0] + '/' + date[1] + '.json?api-key=' + 'F9FPP1mJjiX8pAEFAxBYBg08vZECa39n'
    try:
        response = requests.get(url, verify=False).json()
    except Exception:
        return None
    time.sleep(6)
    return response


def is_valid(article, date):
    '''An article is only worth checking if it is in range, and has a headline.'''
    is_in_range = date > start and date < end
    has_headline = type(article['headline']) == dict and 'main' in article['headline'].keys()
    return is_in_range and has_headline


def parse_response(response):
    '''Parses and returns response as pandas data frame.'''
    data = {'headline': [],  
        'date': [], 
        'doc_type': [],
        'material_type': [],
        'section': [],
        'keywords': [],
        'lead_paragraph': []}
    
    articles = response['response']['docs'] 
    for article in articles: # For each article, make sure it falls within our date range
        date = dateutil.parser.parse(article['pub_date']).date()
        if is_valid(article, date):
            data['date'].append(date)
            data['headline'].append(article['headline']['main']) 
            if 'section' in article:
                data['section'].append(article['section_name'])
            else:
                data['section'].append(None)
            data['doc_type'].append(article['document_type'])
            if 'type_of_material' in article: 
                data['material_type'].append(article['type_of_material'])
            else:
                data['material_type'].append(None)
            keywords = [keyword['value'] for keyword in article['keywords'] if keyword['name'] == 'subject']
            data['keywords'].append(keywords)
            if 'lead_paragraph' in article:
                data['lead_paragraph'].append(article['lead_paragraph'])
            else:
                data['lead_paragraph'].append(None)
    return pd.DataFrame(data) 


def get_data(dates):
    '''Sends and parses request/response to/from NYT Archive API for given dates.'''
    total = 0
    print('Date range: ' + str(dates[0]) + ' to ' + str(dates[-1]))
    if not os.path.exists('headlines'):
        os.mkdir('headlines')
    for date in dates:
        print('Working on ' + str(date) + '...')
        csv_path = 'headlines/' + date[0] + '-' + date[1] + '.csv'
        if not os.path.exists(csv_path): # If we don't already have this month 
            response = send_request(date)
            if response is not None:
                df = parse_response(response)
                total += len(df)
                df.to_csv(csv_path, index=False)
                print('Saving ' + csv_path + '...')
    print('Number of articles collected: ' + str(total))

# %%
get_data(months_in_range)
# Out:
# Date range: ['2019', '1'] to ['2020', '8']
# Working on ['2019', '1']...
# Saving headlines/2019-1.csv...
# Working on ['2019', '2']...
# Saving headlines/2019-2.csv...
# Working on ['2019', '3']...
# Saving headlines/2019-3.csv...
# Working on ['2019', '4']...
# Saving headlines/2019-4.csv...
# Working on ['2019', '5']...
# Saving headlines/2019-5.csv...
# Working on ['2019', '6']...
# Saving headlines/2019-6.csv...
# Working on ['2019', '7']...
# Saving headlines/2019-7.csv...
# Working on ['2019', '8']...
# Saving headlines/2019-8.csv...
# Working on ['2019', '9']...
# Saving headlines/2019-9.csv...
# Working on ['2019', '10']...
# Saving headlines/2019-10.csv...
# Working on ['2019', '11']...
# Saving headlines/2019-11.csv...
# Working on ['2019', '12']...
# Saving headlines/2019-12.csv...
# Working on ['2020', '1']...
# Saving headlines/2020-1.csv...
# Working on ['2020', '2']...
# Saving headlines/2020-2.csv...
# Working on ['2020', '3']...
# Saving headlines/2020-3.csv...
# Working on ['2020', '4']...
# Saving headlines/2020-4.csv...
# Working on ['2020', '5']...
# Saving headlines/2020-5.csv...
# Working on ['2020', '6']...
# Saving headlines/2020-6.csv...
# Working on ['2020', '7']...
# Saving headlines/2020-7.csv...
# Working on ['2020', '8']...
# Saving headlines/2020-8.csv...
# Number of articles collected: 135954

# %% [markdown]
# #### Concatenate csv monthly files:

# %%
import glob
import pandas as pd

# get data file names
path = "headlines/"
filenames = glob.glob("*.csv")

dfs = []
print(filenames)
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
big_frame = pd.concat(dfs, ignore_index=True)
# Out:
# ['2019-1.csv', '2020-5.csv', '2020-4.csv', '2019-2.csv', '2020-6.csv', '2020-7.csv', '2019-3.csv', '2019-7.csv', '2020-3.csv', '2020-2.csv', '2019-6.csv', '2019-4.csv', '2020-1.csv', '2019-5.csv', '2019-10.csv', '2019-11.csv', '2019-12.csv', '2019-8.csv', '2019-9.csv', '2020-8.csv']

# %% [markdown]
# * **big_frame** constitutes all the review for 2019 and 2020 (until August 2020 - that's the timeframe I'm using)

# %%
big_frame
# Out:
#                                                  headline        date  \
# 0                                     Your Hopes for 2019  2019-01-02
# 1       ‘The Venerable W.’ Review: A Buddhist Monk Pre...  2019-01-03
# 2       Yellow Vest Leader Is Arrested in France Amid ...  2019-01-03
# 3       Learning With: ‘NASA’s New Horizons Spacecraft...  2019-01-02
# 4           White Cube? These 3 Art Shows Buck Convention  2019-01-03
# ...                                                   ...         ...
# 135949  Big Oil Is in Trouble. Its Plan: Flood Africa ...  2020-08-30
# 135950        The Princess vs. the Portrait in Trumpworld  2020-08-29
# 135951  Jeanette Carlson, Who Fought Apartheid, Dies a...  2020-08-30
# 135952                    What to Know About Colon Cancer  2020-08-29
# 135953  Compare Pages From an Uncensored Book on Inves...  2020-08-29
#
#           doc_type        material_type  section  \
# 0          article                Op-Ed      NaN
# 1          article               Review      NaN
# 2          article                 News      NaN
# 3          article                 News      NaN
# 4          article                 News      NaN
# ...            ...                  ...      ...
# 135949     article                 News      NaN
# 135950     article                Op-Ed      NaN
# 135951     article                 News      NaN
# 135952     article                 News      NaN
# 135953  multimedia  Interactive Feature      NaN
#
#                                                  keywords  \
# 0       ['Love (Emotion)', 'United States Politics and...
# 1       ['Documentary Films and Programs', 'Muslims an...
# 2       ['Yellow Vests Movement', 'Demonstrations, Pro...
# 3                                                      []
# 4                                                 ['Art']
# ...                                                   ...
# 135949  ['Global Warming', 'Environment', 'Greenhouse ...
# 135950  ['Presidential Election of 2020', 'Republican ...
# 135951      ['Apartheid (Policy)', 'Deaths (Obituaries)']
# 135952  ['Colon and Colorectal Cancer', 'Tests (Medica...
# 135953                                                 []
#
#                                            lead_paragraph
# 0       How do you define hope — a state of mind, a pl...
# 1       This film completes what its director, Barbet ...
# 2       PARIS — The French police have arrested a prom...
# 3                            Before reading the article:
# 4       Art galleries, especially those on the Lower E...
# ...                                                   ...
# 135949  Confronting a climate crisis that threatens th...
# 135950  WASHINGTON — As long as the Trumps were hijack...
# 135951  Jeanette Carlson, an anti-apartheid activist w...
# 135952  In the wake of Chadwick Boseman’s death from c...
# 135953                                                NaN
#
# [135954 rows x 7 columns]

# %% [markdown]
# #### Topic modeling: 2019 - 2020

# %% [markdown]
# The purpose of the analysis below is to run topic modeling on headlines, keywords and lead paragraphs of The New York Times articles for the past year and a half. I want to make sure that headlines are consistent with the introductory paragraphs and keywords. Also, I wanted to make sure I am not in any way misinterpreting the Times' journalism style and the topic of my research is relevant, before I dig deeper into the archives.

# %%
from collections import defaultdict 
import re, string
from gensim import corpora
from gensim.models import LdaModel 
import pyLDAvis.gensim

# %%
big_frame_corpus_headline = big_frame['headline']
big_frame_corpus_keywords = big_frame['keywords']
big_frame_corpus_lead = big_frame['lead_paragraph']

# %%
from nltk.corpus import stopwords

# %% [markdown]
# Data pre-processing:

# %%
headlines = [re.sub(r'[^\w\s]','',str(item)) for item in big_frame_corpus_headline]

# %%
keywords = [re.sub(r'[^\w\s]','',str(item)) for item in big_frame_corpus_keywords]

# %%
lead = [re.sub(r'[^\w\s]','',str(item)) for item in big_frame_corpus_lead]

# %%
stopwords = set(stopwords.words('english'))

# %%
headline_texts = [[word for word in document.lower().split() if word not in stopwords] for document in headlines]

# %%
headline_texts
# Out:
# [['hopes', '2019'],
#  ['venerable', 'w', 'review', 'buddhist', 'monk', 'preaches', 'hate'],
#  ['yellow', 'vest', 'leader', 'arrested', 'france', 'amid', 'crackdown'],
#  ['learning',
#   'nasas',
#   'new',
#   'horizons',
#   'spacecraft',
#   'triumphant',
#   'encounter',
#   'distant',
#   'object',
#   'ever',
#   'visited'],
#  ['white', 'cube', '3', 'art', 'shows', 'buck', 'convention'],
#  ['new', 'sentences', 'nasser', 'hussains', 'sky', 'wri', 'tei', 'ngs'],
#  ['12', 'dance', 'performances', 'see', 'nyc', 'weekend'],
#  ['5', 'comedy', 'shows', 'catch', 'nyc', 'weekend'],
#  ['chinas', 'moon', 'landing', 'lunar', 'rover', 'begins', 'exploration'],
#  ['mitt', 'romney', 'faces', 'counterattacks', 'trump', 'allies'],
#  ['chelsea', 'signs', 'christian', 'pulisic', '73', 'million'],
#  ['saudi', 'arabia', 'denies', 'issuing', 'american', 'weapons', 'sudanese'],
#  ['undocumented',
#   'worker',
#   'says',
#   'trump',
#   'resort',
#   'shielded',
#   'secret',
#   'service'],
#  ['miss', 'california', 'long', 'farewell', 'jerry', 'brown'],
#  ['democrats', 'new', 'power'],
#  ['trumps', 'shutdown', 'border', 'security'],
#  ['denmark',
#   'train',
#   'accident',
#   'kills',
#   '6',
#   'shuts',
#   'major',
#   'transit',
#   'artery'],
#  ['5',
#   'children',
#   'headed',
#   'disney',
#   'world',
#   'among',
#   '7',
#   'killed',
#   'florida',
#   'crash'],
#  ['corrections', 'january', '2', '2019'],
#  ['california', 'forces', 'pet', 'stores', 'sell', 'dogs', 'cats', 'shelters'],
#  ['good', 'bad', 'black', 'panther'],
#  ['12', 'pop', 'rock', 'jazz', 'concerts', 'check', 'nyc', 'weekend'],
#  ['trumps', 'freewheeling', 'mostly', 'factfree', 'cabinet', 'meeting'],
#  ['film', 'club', 'diamenteurs'],
#  ['double', 'dose', 'optimism'],
#  ['isnt', 'affected', 'government', 'shutdown'],
#  ['house', 'representatives', 'convenes', 'theres', 'one', 'empty', 'seat'],
#  ['stop', 'subway', 'fare', 'beaters'],
#  ['volatility',
#   'continues',
#   'rising',
#   'oil',
#   'prices',
#   'help',
#   'wall',
#   'st',
#   'erase',
#   'early',
#   'losses'],
#  ['2', 'divorce', 'lawyers', 'better', 'divorce', 'still', 'together'],
#  ['new',
#   'chapter',
#   'space',
#   'exploration',
#   'china',
#   'reaches',
#   'far',
#   'side',
#   'moon'],
#  ['ray', 'sawyer', 'cover', 'rolling', 'stone', 'singer', 'dies', '81'],
#  ['trump',
#   'says',
#   'mattis',
#   'resignation',
#   'essentially',
#   'firing',
#   'escalating',
#   'new',
#   'front',
#   'military',
#   'critics'],
#  ['twisted',
#   'sister',
#   'clashes',
#   'australian',
#   'politician',
#   'rock',
#   'anthem'],
#  ['give', 'smoking'],
#  ['praise', 'iris', 'murdoch'],
#  ['quiet', 'place', 'huge', 'hit', 'oscar', 'listen'],
#  ['michelle', 'yeoh', 'ferocious', 'mothers', 'heartbreaking', 'leaders'],
#  ['bristolmyers', 'acquire', 'celgene', 'deal', 'worth', '74', 'billion'],
#  ['2',
#   'indian',
#   'women',
#   'enter',
#   'sabarimala',
#   'temple',
#   'setting',
#   'protests',
#   'near',
#   'hindu',
#   'shrine'],
#  ['quadrantids', 'meteor', 'shower', 'peak', 'night', 'skies'],
#  ['watergate', 'class', '74', 'valuable', 'lessons', 'freshman', 'democrats'],
#  ['game',
#   'thronesstyle',
#   'poster',
#   'overshadowed',
#   'trump',
#   'cabinet',
#   'meeting',
#   'nobody',
#   'talked'],
#  ['cathay', 'pacific', 'surprised', 'offer', '16000', 'fare', '675'],
#  ['ny', 'today', 'yes', 'weather', 'crazy', 'rainy'],
#  ['116th',
#   'congress',
#   'updates',
#   'house',
#   'approves',
#   'plan',
#   'reopen',
#   'government',
#   'likely',
#   'pass',
#   'senate'],
#  ['tech', 'surprised', 'scared', 'us', '2018'],
#  ['chinas', 'gulag', 'muslims'],
#  ['far', 'side', 'moon', 'china', 'world', 'hope', 'find'],
#  ['mighty',
#   'tree',
#   'grows',
#   'georgetown',
#   'belongs',
#   'patrick',
#   'ewing',
#   'alonzo',
#   'mourning'],
#  ['forprofit',
#   'chain',
#   'cancels',
#   '494',
#   'million',
#   'student',
#   'debt',
#   'end',
#   'state',
#   'investigations'],
#  ['overlooked',
#   'karen',
#   'sparck',
#   'jones',
#   'established',
#   'basis',
#   'search',
#   'engines'],
#  ['oscar', 'rewind', 'pop', 'star', 'plays', 'performer', 'wins', 'happened'],
#  ['freed', 'forced', 'marriages', 'uk', 'women', 'stuck', 'bill'],
#  ['see', 'new', 'york', 'art', 'galleries', 'week'],
#  ['1', 'million', 'homes', 'minnesota', 'mississippi', 'washington'],
#  ['pen', 'proves', 'mighty', 'unlikely', 'trump', 'correspondent'],
#  ['teenagers', 'times', 'december', '2018'],
#  ['thought', 'flu', 'first', 'heart', 'could', 'barely', 'pump'],
#  ['north',
#   'koreas',
#   'envoy',
#   'italy',
#   'disappears',
#   'raising',
#   'suspicions',
#   'defection'],
#  ['shutdown', 'nancy', 'pelosi', 'apple', 'wednesday', 'evening', 'briefing'],
#  ['david', 'silva', 'manchester', 'citys', 'key', 'piece', 'valuable', 'ever'],
#  ['top', 'qatari', 'soccer', 'official', 'barred', 'tournament', 'uae'],
#  ['market',
#   'cools',
#   'median',
#   'price',
#   'manhattan',
#   'apartment',
#   'drops',
#   '1',
#   'million',
#   '999000'],
#  ['hold', 'healthy', 'grudges'],
#  ['politics', 'trump', 'rejects', 'shutdown', 'compromise'],
#  ['vanishing', 'review', 'lighthouse', 'temptation'],
#  ['rust',
#   'creek',
#   'review',
#   'woman',
#   'stranded',
#   'backwoods',
#   'kentucky',
#   'could',
#   'go',
#   'wrong'],
#  ['phillies', 'sign', 'david', 'robertson', 'adding', 'offseason', 'spending'],
#  ['death', 'toll', 'russia', 'apartment', 'blast', 'rises', '38'],
#  ['leonard',
#   'cohens',
#   'posthumous',
#   'collection',
#   'poems',
#   'lyrics',
#   'sketches'],
#  ['voting', 'issues', 'gerrymanders', 'key', 'political', 'battlegrounds'],
#  ['review', 'millbrook', 'winery', 'jarrahdale', 'western', 'australia'],
#  ['mitt', 'romney', 'says', 'trump', 'risen', 'mantle', 'office'],
#  ['hakeem', 'jeffries', 'doesnt', 'want', 'called', 'next', 'obama'],
#  ['louis', 'ck', 'crossed', 'line'],
#  ['think', 'curiously', 'fashionable', 'footwear'],
#  ['leaping'],
#  ['five',
#   'ways',
#   'elizabeth',
#   'warren',
#   '2020',
#   'hopefuls',
#   'campaign',
#   'theres',
#   'campaign',
#   'yet'],
#  ['raising',
#   'kids',
#   'isnt',
#   'easy',
#   'parenting',
#   'advice',
#   'often',
#   'makes',
#   'harder'],
#  ['protecting', 'pregnant', 'workers'],
#  ['pope',
#   'cites',
#   'crisis',
#   'credibility',
#   'message',
#   'us',
#   'bishops',
#   'sex',
#   'abuse'],
#  ['10', 'winter', 'fashion', 'ideas', 'inspired', 'english', 'countryside'],
#  ['word', 'quiz', 'bluff'],
#  ['nfl', 'playoff', 'predictions', 'picks', 'wildcard', 'round'],
#  ['picking', 'steam', 'bath'],
#  ['14yearold', 'charged', 'murder', 'egg', 'prank', 'fatal', 'crash'],
#  ['ringing',
#   '2019',
#   'ryan',
#   'seacrest',
#   'anderson',
#   'cooper',
#   'opera',
#   'lovers'],
#  ['judge',
#   'blocks',
#   'new',
#   'york',
#   'city',
#   'law',
#   'aimed',
#   'curbing',
#   'airbnb',
#   'rentals'],
#  ['uffizi',
#   'prods',
#   'germans',
#   'return',
#   'painting',
#   'stolen',
#   'world',
#   'war',
#   'ii'],
#  ['hungarys', 'plight'],
#  ['providence', 'ri', 'bustle', 'gives', 'way', 'simple', 'pleasures'],
#  ['government',
#   'shutdown',
#   'moon',
#   'landing',
#   'captain',
#   'tennille',
#   'thursday',
#   'briefing'],
#  ['trouble', 'ethiopias', 'ethnic', 'federalism'],
#  ['inauguration', 'cuomo', 'rallies', 'state', 'trump'],
#  ['spy', 'american', 'loves', 'russia', 'ensnared', 'new', 'cold', 'war'],
#  ['winter',
#   'tv',
#   'preview',
#   'true',
#   'detective',
#   'carmen',
#   'sandiego',
#   '19',
#   'shows',
#   'watch'],
#  ['tarik', 'cohen', 'makes', 'football', 'fun', 'chicago'],
#  ['newly', 'divided', 'government', 'control', 'political', 'agenda'],
#  ['pittsburgh', 'report', 'five', 'places', 'healing', 'art'],
#  ['parting',
#   'gift',
#   'urban',
#   'meyer',
#   'gives',
#   'ohio',
#   'state',
#   'rose',
#   'bowl',
#   'victory'],
#  ['excess', 'weight', 'contributes', '7', 'percent', 'cancers'],
#  ['driving', 'teach', 'us', 'living'],
#  ['unbearable', 'heaviness', 'clutter'],
#  ['la', 'religieuse', 'culture', 'war', 'casualty', '1960s', 'france'],
#  ['cold', 'outside', 'earth', 'closest', 'approach', 'sun'],
#  ['offered',
#   'free',
#   'tickets',
#   'schindlers',
#   'list',
#   'germanys',
#   'far',
#   'right',
#   'sees',
#   'provocation'],
#  ['paparazzi',
#   'dogs',
#   'rabbitgirl',
#   'conquered',
#   'new',
#   'york',
#   'city',
#   'streets'],
#  ['dispute', 'runaway', 'slaves', 'helped', 'fuel', 'civil', 'war'],
#  ['us',
#   'ambassador',
#   'visits',
#   'american',
#   'arrested',
#   'russia',
#   'spying',
#   'charge'],
#  ['mitt', 'romney', 'china', 'ultima', 'thule', 'wednesday', 'briefing'],
#  ['apollo', 'theater', 'celebrated', 'new', 'graphic', 'novel'],
#  ['snowmanlike',
#   'photo',
#   'ultima',
#   'thule',
#   'sent',
#   'home',
#   'nasas',
#   'new',
#   'horizons',
#   'spacecraft'],
#  ['mitt', 'romney', 'piling', 'trump'],
#  ['xi',
#   'jinping',
#   'warns',
#   'taiwan',
#   'unification',
#   'goal',
#   'force',
#   'option'],
#  ['heading', 'west', 'new', 'development'],
#  ['turn', 'volume'],
#  ['charges', 'domestic', 'violence', 'reuben', 'foster', 'dropped'],
#  ['quotation',
#   'day',
#   'family',
#   'seeks',
#   'asylum',
#   'battling',
#   'back',
#   'zealots',
#   'attack'],
#  ['call', 'arms', 'supreme', 'court'],
#  ['police',
#   'investigating',
#   'driveby',
#   'shooting',
#   'jazmine',
#   'barnes',
#   'seek',
#   'publics',
#   'help'],
#  ['blake', 'w', 'nordstrom', 'scion', 'retail', 'family', 'dies', '58'],
#  ['mike', 'tomlin', 'damage', 'control', 'antonio', 'browns', 'absence'],
#  ['chinese',
#   'companies',
#   'flocked',
#   'us',
#   'markets',
#   '2018',
#   'trade',
#   'war',
#   'may',
#   'role'],
#  ['whats', 'going', 'graph', 'jan', '9', '2019'],
#  ['would', 'gop', 'vote', 'convict', 'trump'],
#  ['one',
#   'americas',
#   'vital',
#   'exports',
#   'education',
#   'never',
#   'goes',
#   'abroad',
#   'still',
#   'faces',
#   'threats'],
#  ['dealbook',
#   'briefing',
#   'apples',
#   'struggles',
#   'add',
#   'uncertainty',
#   'markets'],
#  ['rents', 'rise', '2018'],
#  ['full', 'shutdown', 'l', 'train', 'halted', 'cuomo'],
#  ['trump',
#   'county',
#   'confronts',
#   'administration',
#   'amid',
#   'rash',
#   'child',
#   'cancers'],
#  ['work',
#   'hard',
#   'help',
#   'others',
#   'honor',
#   'family',
#   '3',
#   'lessons',
#   'triplets',
#   'learned',
#   'life'],
#  ['cholesterol', 'may', 'higher', 'holidays'],
#  ['8', 'things', 'kids', 'nyc', 'weekend'],
#  ['gene', 'okerlund', 'serious', 'voice', 'pro', 'wrestling', 'dead', '76'],
#  ['corrections', 'january', '3', '2019'],
#  ['quotation',
#   'day',
#   'china',
#   'turns',
#   'censorship',
#   'lucrative',
#   'factory',
#   'work'],
#  ['gore', 'graft', 'weve', 'learned', 'far', 'el', 'chapo', 'trial'],
#  ['new',
#   'york',
#   'citys',
#   'poor',
#   'promised',
#   'halfpriced',
#   'metrocards',
#   'theyre',
#   'still',
#   'waiting'],
#  ['ecb', 'takes', 'reins', 'italian', 'bank', 'prevent', 'wider', 'crisis'],
#  ['trump',
#   'democrats',
#   'dig',
#   'talks',
#   'reopen',
#   'government',
#   'go',
#   'nowhere'],
#  ['st', 'johns', 'rides', 'transfers', 'renewed', 'relevance'],
#  ['chinese',
#   'consumers',
#   'confidence',
#   'sags',
#   'casting',
#   'pall',
#   'global',
#   'economy'],
#  ['jair',
#   'bolsonaro',
#   'day',
#   '1',
#   'undermines',
#   'indigenous',
#   'brazilians',
#   'rights'],
#  ['probably', 'best', 'bath', 'new', 'york', 'city'],
#  ['migrants', 'rescued', 'greeks', 'sea', 'reward', 'citizenship'],
#  ['get', 'preschoolers', 'share'],
#  ['china', 'kerala', 'moon', 'landing', 'thursday', 'briefing'],
#  ['2019', 'golden', 'globes', 'predictions', 'movies', 'win'],
#  ['stand', 'lounge', 'less', 'dont', 'lose', 'weight'],
#  ['army', 'need', 'recruits', 'turns', 'focus', 'liberalleaning', 'cities'],
#  ['congress',
#   'espionage',
#   'china',
#   'economy',
#   'thursday',
#   'evening',
#   'briefing'],
#  ['think', 'youre', 'get', 'fired'],
#  ['world', 'needs', 'america', 'china', 'get', 'along'],
#  ['chigozie', 'obioma', 'book'],
#  ['led',
#   'cult',
#   'bourbons',
#   'distillers',
#   'dream',
#   'napafication',
#   'kentucky'],
#  ['queen', 'ally', 'alchemy', 'musical', 'stardom', 'big', 'screen'],
#  ['learning', 'chinas', 'forbidden', 'history', 'censor'],
#  ['l', 'train', 'shutdown', 'canceled', 'exactly', 'mean'],
#  ['hard', 'part', 'getting', 'californians', 'buy', 'legal', 'weed'],
#  ['homes', 'sale', 'new', 'york', 'new', 'jersey'],
#  ['intimate',
#   'photos',
#   'community',
#   'resilience',
#   'new',
#   'yorks',
#   'chinatown',
#   '1980s'],
#  ['doulas', 'calm', 'nerves', 'bridge', 'cultures', 'childbirth'],
#  ['republicans', 'support', 'immigration'],
#  ['yes', 'mr', 'trump', 'look', 'foolish'],
#  ['ian', 'schrager', 'still', 'creating', 'buzz'],
#  ['learning',
#   'newly',
#   'divided',
#   'government',
#   'control',
#   'political',
#   'agenda'],
#  ['state',
#   'like',
#   'sleep',
#   'review',
#   'suspicious',
#   'suicide',
#   'drives',
#   'suffocating',
#   'thriller'],
#  ['washington',
#   'state',
#   'bans',
#   'sale',
#   'semiautomatic',
#   'assault',
#   'rifles',
#   '21'],
#  ['likability', 'politics', 'sexist', 'yes', 'also', 'outdated'],
#  ['first', 'solo', 'antarctic', 'traverse'],
#  ['daughters', 'rich', 'friends', 'driving', 'nuts'],
#  ['yankees', 'taking', 'chance', 'shortstop', 'troy', 'tulowitzki'],
#  ['man', 'charged', 'murder', 'killing', 'california', 'police', 'officer'],
#  ['predictions', '2019'],
#  ['defiant', 'interview', 'jail', 'cell', 'soon', 'turn', 'murder', 'scene'],
#  ['11', 'new', 'books', 'recommend', 'week'],
#  ['somers', 'ny', 'closeknit', 'town', 'plenty', 'shopping', 'great', 'parks'],
#  ['much', 'watching', 'time', 'weekend'],
#  ['could', 'wrong', 'little', 'moral', 'clarity'],
#  ['reportage', 'rises', 'art'],
#  ['best', 'california', 'stories', '2018'],
#  ['animals', 'getting', 'better', 'acting'],
#  ['mexico', 'calls', 'us', 'investigate', 'use', 'tear', 'gas', 'border'],
#  ['hamilton', 'leads', 'recordbreaking', 'holiday', 'week', 'broadway'],
#  ['facing', 'rejection'],
#  ['devices', 'invade', 'life', '2019', 'whats', 'overhyped'],
#  ['go', 'bare'],
#  ['tango', 'heart'],
#  ['hurricanes', 'shootings', 'fires', 'time', 'editors', 'emergency', 'kit'],
#  ['questions', 'answered'],
#  ['heres', 'didnt', 'vote', 'nancy', 'pelosi', 'speaker'],
#  ['weve', 'learned', 'ultima', 'thule', 'nasas', 'new', 'horizons', 'mission'],
#  ['end', 'age', 'apple'],
#  ['rashida',
#   'tlaib',
#   'sworn',
#   'palestinianamericans',
#   'respond',
#   'tweetyourthobe'],
#  ['falling', 'stock', 'market', 'nothing'],
#  ['house', 'hunting', 'south', 'africa'],
#  ['readers', 'first', 'memory', 'racism', 'youre', 'black'],
#  ['chuck', 'schumer', 'wall', 'shutdown', 'era', 'divided', 'government'],
#  ['apples', 'warning', 'surprise', 'suppliers'],
#  ['london', 'stages', 'atmosphere', 'tragic'],
#  ['ny', 'today', '9', 'stories', 'matter', '2019'],
#  ['2019', 'spoleto', 'festival', 'feature', 'new', 'salome'],
#  ['harry', 'reid', 'words', 'washington'],
#  ['cook', 'right'],
#  ['easy', 'new', 'years', 'resolution', 'help', 'earth', 'consuming', 'less'],
#  ['useless', 'knowledge', 'begets', 'new', 'horizons'],
#  ['news', '2018', 'memorable', 'corrections'],
#  ['white',
#   'house',
#   'mulls',
#   'jim',
#   'webb',
#   'exdemocratic',
#   'senator',
#   'next',
#   'defense',
#   'secretary'],
#  ['fork'],
#  ['french', 'doctors', 'office', 'taught', 'health', 'care'],
#  ['gillian',
#   'anderson',
#   'reads',
#   'maternal',
#   'wisdom',
#   '5',
#   'pounds',
#   'worth'],
#  ['apple', 'cuts', 'revenue', 'forecast', 'slow', 'iphone', 'sales', 'china'],
#  ['four', 'simple', 'words', 'help', 'live', 'well'],
#  ['5', 'film', 'series', 'catch', 'nyc', 'weekend'],
#  ['choir', 'composition'],
#  ['dangerous', 'rise', 'iud', 'poverty', 'cure'],
#  ['whats',
#   'tv',
#   'thursday',
#   'support',
#   'girls',
#   'black',
#   'mirror',
#   'bandersnatch'],
#  ['bandersnatch', 'sopranos', 'myth', 'certainty'],
#  ['escape', 'room', 'review', 'puzzle', 'way', 'youre', 'dead'],
#  ['geoffrey',
#   'langlands',
#   'lauded',
#   'british',
#   'educator',
#   'pakistan',
#   'dies',
#   '101'],
#  ['unsentimental',
#   'darkly',
#   'elegant',
#   'stories',
#   'ruth',
#   'prawer',
#   'jhabvala'],
#  ['nancy',
#   'pelosi',
#   'elected',
#   'speaker',
#   'democrats',
#   'take',
#   'control',
#   'house'],
#  ['saudi',
#   'arabia',
#   'seeks',
#   'death',
#   'penalty',
#   '5',
#   'suspects',
#   'khashoggi',
#   'killing'],
#  ['netflix', 'bird', 'box', 'fans', 'please', 'open', 'eyes'],
#  ['us', 'congress', 'turkey', 'china', 'friday', 'briefing'],
#  ['william',
#   'c',
#   'thompson',
#   'pioneering',
#   'black',
#   'legislator',
#   'judge',
#   'dies',
#   '94'],
#  ['nancy',
#   'pelosi',
#   'icon',
#   'female',
#   'power',
#   'reclaim',
#   'role',
#   'speaker',
#   'seal',
#   'place',
#   'history'],
#  ['mrinal', 'sen', 'one', 'indias', 'leading', 'directors', 'dies', '95'],
#  ['texas', 'land', 'football', 'rugby', 'rescue'],
#  ['word', 'quiz', 'agog'],
#  ['30', 'art', 'exhibitions', 'view', 'nyc', 'weekend'],
#  ['ate', 'mall', 'pizza', 'fell', 'love', 'america'],
#  ['edgar',
#   'hilsenrath',
#   '92',
#   'writer',
#   'unvarnished',
#   'holocaust',
#   'novels',
#   'dies'],
#  ['national', 'parks', 'museums', 'affected', 'shutdown'],
#  ['photographers', 'insider', 'view', 'bohemian', 'life'],
#  ['congress', 'turkey', 'apple', 'thursday', 'briefing'],
#  ['neil',
#   'degrasse',
#   'tysons',
#   'show',
#   'pulled',
#   'amid',
#   'misconduct',
#   'allegations'],
#  ['set', 'new', 'years', 'resolutions'],
#  ['7', 'classical', 'music', 'concerts', 'see', 'nyc', 'weekend'],
#  ['three',
#   'simple',
#   'tonics',
#   'sustain',
#   'one',
#   'new',
#   'yorks',
#   'busiest',
#   'chefs'],
#  ['paul', 'danos', 'cup', 'runneth'],
#  ['fewer', 'women', 'directed', 'top', 'films', '2018', 'study', 'finds'],
#  ['illegal',
#   'butt',
#   'lift',
#   'injection',
#   'leads',
#   'death',
#   'manslaughter',
#   'charge'],
#  ['many', 'lives', 'sharon', 'van', 'etten'],
#  ['philippine', 'mayor', 'behind', 'congressmans', 'killing', 'police', 'say'],
#  ['giants', 'general', 'manager', 'noncommittal', 'eli', 'mannings', 'future'],
#  ['marie', 'kondo', 'reality', 'show', 'netflixs', 'tidying'],
#  ['pelosi', 'takes', 'attempt', 'revive', 'lost', 'art', 'legislating'],
#  ['saving', 'earth', 'president'],
#  ['sexism',
#   'claims',
#   'bernie',
#   'sanderss',
#   '2016',
#   'run',
#   'paid',
#   'less',
#   'treated',
#   'worse'],
#  ['2019'],
#  ['londons', 'theaters', 'tackle', 'big', 'issue', 'womens', 'bathrooms'],
#  ['tsa', 'without', 'public', 'face'],
#  ['bob',
#   'einstein',
#   '76',
#   'aka',
#   'super',
#   'dave',
#   'osborne',
#   'larry',
#   'david',
#   'pal',
#   'dies'],
#  ['whats', 'tv', 'wednesday', 'grownish', 'atlanta'],
#  ['daryl', 'dragon', 'captain', 'tennille', 'pop', 'duo', 'dies', '76'],
#  ['grave', 'fireflies', 'review', 'pioneering', 'animated', 'classic'],
#  ['tesla',
#   'reports',
#   'record',
#   'output',
#   'cuts',
#   'prices',
#   'shares',
#   'plunge'],
#  ['julie', 'sweet', 'accenture', 'could', 'see', 'future', 'quit', 'job'],
#  ['artwork', 'taken', 'africa', 'returning', 'home', 'transformed'],
#  ['wrong', 'facebookfriend', 'nephews', 'girlfriend'],
#  ['homes', 'sale', 'manhattan', 'queens'],
#  ['film', 'transgender', 'dancer', 'dangerous', 'watch'],
#  ['chadwick', 'boseman', 'embodies', 'black', 'male', 'dignity'],
#  ['ny',
#   'police',
#   'official',
#   'took',
#   'las',
#   'vegas',
#   'trip',
#   'gifts',
#   'acquitted',
#   'corruption',
#   'charges'],
#  ['last', 'month', 'investors', 'seemed', 'pessimistic', 'seem', 'prescient'],
#  ['dealbook', 'briefing', 'could', 'go', 'wrong', '2019', 'plenty'],
#  ['car', 'tuneups', 'require', 'audio', 'engineers'],
#  ['spurning',
#   'erdogans',
#   'vision',
#   'turks',
#   'leave',
#   'droves',
#   'draining',
#   'money',
#   'talent'],
#  ['discussion', 'questions', 'heart', 'history'],
#  ['unification', 'plan', 'china', 'finds', 'takers', 'taiwan'],
#  ['mexico', 'city', 'director', 'roma', 'remembers', 'hears'],
#  ['broad', 'city', 'ending', 'peace', 'creators'],
#  ['elizabeth', 'warren', 'wants', 'stop', 'inequality', 'starts'],
#  ['jair',
#   'bolsonaro',
#   'sworn',
#   'brazils',
#   'president',
#   'cementing',
#   'rightward',
#   'shift'],
#  ['13', 'plays', 'musicals', 'go', 'nyc', 'weekend'],
#  ['affirmative',
#   'action',
#   'college',
#   'admissions',
#   'problem',
#   'meritocracy',
#   'isnt',
#   'meritocratic'],
#  ['path',
#   'train',
#   'loses',
#   '400',
#   'million',
#   'year',
#   'keep',
#   'spending',
#   'billions'],
#  ['hold', 'grudge'],
#  ['whats',
#   'different',
#   'mtas',
#   'new',
#   'plan',
#   'repairing',
#   'l',
#   'train',
#   'tunnel'],
#  ['change4', 'studies', 'moon'],
#  ['sign', '30day', 'well', 'challenge'],
#  ['1', 'woman', '12', 'months', '52', 'places'],
#  ['bids', 'blocks', 'fun', 'weekend', 'ultimate', 'nationals'],
#  ['get', '1', 'million'],
#  ['market', 'new', 'york', 'city'],
#  ['market', 'new', 'york', 'region'],
#  ['locally', 'grown', 'australian', 'food', 'loan', 'required'],
#  ['modern', 'ranch', 'south', 'africas', 'eastern', 'coast'],
#  ['living', 'somers', 'ny'],
#  ['jenny',
#   'mccarthy',
#   'anderson',
#   'cooper',
#   'ryan',
#   'seacrest',
#   'ring',
#   'new',
#   'year'],
#  ['inside', 'pelosis', 'leadership', 'playbook'],
#  ['protests', 'break', '2', 'women', 'enter', 'hindu', 'temple', 'india'],
#  ['feel', 'good', 'sensations'],
#  ['venerable', 'w', 'review', 'buddhist', 'monk', 'preaches', 'hate'],
#  ['yellow', 'vest', 'leader', 'arrested', 'france', 'amid', 'crackdown'],
#  ['white', 'cube', '3', 'art', 'shows', 'buck', 'convention'],
#  ['married', 'city', 'hall', 'didnt', 'toss', 'bouquet'],
#  ['trump',
#   'holds',
#   'firm',
#   'shutdown',
#   'never',
#   'mentions',
#   'one',
#   'group',
#   'federal',
#   'workers'],
#  ['upended', 'lives', 'avoid', 'l', 'train', 'shutdown', 'shutdown'],
#  ['elizabeth', 'warren', 'campaigns', 'iowa', 'starts'],
#  ['new', 'sentences', 'nasser', 'hussains', 'sky', 'wri', 'tei', 'ngs'],
#  ['12', 'dance', 'performances', 'see', 'nyc', 'weekend'],
#  ['5', 'comedy', 'shows', 'catch', 'nyc', 'weekend'],
#  ['ishmael', 'reeds', 'play', 'challenging', 'hamilton', 'get', 'reading'],
#  ['ever', 'recover', 'diverticulitis'],
#  ['chinas', 'moon', 'landing', 'lunar', 'rover', 'begins', 'exploration'],
#  ['undocumented',
#   'worker',
#   'says',
#   'trump',
#   'resort',
#   'shielded',
#   'secret',
#   'service'],
#  ['miss', 'california', 'long', 'farewell', 'jerry', 'brown'],
#  ['demonizing', 'crack', 'mothers', 'victimizing', 'children'],
#  ['theres',
#   'real',
#   'tension',
#   'democrats',
#   'puzzle',
#   'whether',
#   'woman',
#   'beat',
#   'trump'],
#  ['knicks',
#   'beat',
#   'lebronless',
#   'lakers',
#   'time',
#   'celebrate',
#   'like',
#   'super',
#   'bowl'],
#  ['thai', 'takes', 'cue', 'brooklyn', 'neighbors'],
#  ['5',
#   'children',
#   'headed',
#   'disney',
#   'world',
#   'among',
#   '7',
#   'killed',
#   'florida',
#   'crash'],
#  ['must', 'writers', 'moral', 'contracts', 'may', 'require'],
#  ['learning',
#   '2',
#   'indian',
#   'women',
#   'enter',
#   'sabarimala',
#   'temple',
#   'setting',
#   'protests',
#   'near',
#   'hindu',
#   'shrine'],
#  ['black', 'people', 'directed', 'top', 'films', 'study', 'says'],
#  ['advocates', 'legalizing', 'pot', 'dont', 'want', 'know'],
#  ['12', 'pop', 'rock', 'jazz', 'concerts', 'check', 'nyc', 'weekend'],
#  ['american', 'dream', 'isnt', 'black', 'millennials'],
#  ['trumps', 'freewheeling', 'mostly', 'factfree', 'cabinet', 'meeting'],
#  ['film', 'club', 'diamenteurs'],
#  ['double', 'dose', 'optimism'],
#  ['thomas', 'page', 'mcbee', 'questioner', 'masculinity', 'spends', 'sundays'],
#  ['police',
#   'investigate',
#   'sexual',
#   'assault',
#   'allegations',
#   'woman',
#   'vegetative',
#   'state',
#   'gives',
#   'birth'],
#  ['chinese', 'dad', 'switched', 'iphone', 'huawei'],
#  ['meet', 'timess', 'new', 'carpetbagger', 'columnist'],
#  ['saving', 'local', 'communities', 'globalized', 'world'],
#  ['house', 'representatives', 'convenes', 'theres', 'one', 'empty', 'seat'],
#  ['new',
#   'yorks',
#   'hottest',
#   'contest',
#   'race',
#   'public',
#   'advocate',
#   'really'],
#  ['americas', 'political', 'future', 'san', 'antonio'],
#  ['2', 'divorce', 'lawyers', 'better', 'divorce', 'still', 'together'],
#  ['new',
#   'chapter',
#   'space',
#   'exploration',
#   'china',
#   'reaches',
#   'far',
#   'side',
#   'moon'],
#  ['twisted',
#   'sister',
#   'clashes',
#   'australian',
#   'politician',
#   'rock',
#   'anthem'],
#  ['china',
#   'targets',
#   'prominent',
#   'uighur',
#   'intellectuals',
#   'erase',
#   'ethnic',
#   'identity'],
#  ['give', 'smoking'],
#  ['praise', 'iris', 'murdoch'],
#  ['us', 'auto', 'sales', 'put', 'big', 'number', 'show', 'signs', 'strain'],
#  ['quiet', 'place', 'huge', 'hit', 'oscar', 'listen'],
#  ['michelle', 'yeoh', 'ferocious', 'mothers', 'heartbreaking', 'leaders'],
#  ['explosives', 'used', 'demolition', 'tappan', 'zee', 'bridge', 'span'],
#  ['fight', 'keep', 'teachers', 'tech', 'hubs', 'priced'],
#  ['bristolmyers', 'acquire', 'celgene', 'deal', 'worth', '74', 'billion'],
#  ['american', 'jews', 'israeli', 'jews', 'headed', 'messy', 'breakup'],
#  ['china', 'pours', '218', 'billion', 'economy', 'growth', 'slows'],
#  ['quadrantids', 'meteor', 'shower', 'peak', 'night', 'skies'],
#  ['watergate', 'class', '74', 'valuable', 'lessons', 'freshman', 'democrats'],
#  ['game',
#   'thronesstyle',
#   'poster',
#   'overshadowed',
#   'trump',
#   'cabinet',
#   'meeting',
#   'nobody',
#   'talked'],
#  ['shutdown',
#   'persists',
#   'new',
#   'congress',
#   'opens',
#   'celebration',
#   'uncertainty'],
#  ['misconduct',
#   'federal',
#   'prisons',
#   'tolerated',
#   'ignored',
#   'congressional',
#   'report',
#   'says'],
#  ['cathay', 'pacific', 'surprised', 'offer', '16000', 'fare', '675'],
#  ['dealbook', 'briefing', 'slow', 'growth', 'weighs', 'markets'],
#  ['ny', 'today', 'yes', 'weather', 'crazy', 'rainy'],
#  ['ny', 'today', 'l', 'train', 'shutdown', 'apocalypse', 'never', 'mind'],
#  ['116th',
#   'congress',
#   'updates',
#   'house',
#   'approves',
#   'plan',
#   'reopen',
#   'government',
#   'likely',
#   'pass',
#   'senate'],
#  ['rashida',
#   'tlaibs',
#   'expletiveladen',
#   'cry',
#   'impeach',
#   'trump',
#   'upends',
#   'democrats',
#   'talking',
#   'points'],
#  ['far', 'side', 'moon', 'china', 'world', 'hope', 'find'],
#  ['mighty',
#   'tree',
#   'grows',
#   'georgetown',
#   'belongs',
#   'patrick',
#   'ewing',
#   'alonzo',
#   'mourning'],
#  ['deep', 'winter', 'lets', 'discuss', 'stifling', 'starting', 'pitchers'],
#  ['forprofit',
#   'chain',
#   'cancels',
#   '494',
#   'million',
#   'student',
#   'debt',
#   'end',
#   'state',
#   'investigations'],
#  ['morality', 'selfism'],
#  ['bandersnatch', 'many', 'paths', 'add', 'anything'],
#  ['oscar', 'rewind', 'pop', 'star', 'plays', 'performer', 'wins', 'happened'],
#  ['one', 'photographers', 'delicious', 'technicolor', 'homage', 'apples'],
#  ['shutdown', 'jobs', 'markets', 'friday', 'evening', 'briefing'],
#  ['see', 'new', 'york', 'art', 'galleries', 'week'],
#  ['snowflakes', 'millennials', 'asked', 'join', 'ranks', 'british', 'army'],
#  ['pen', 'proves', 'mighty', 'unlikely', 'trump', 'correspondent'],
#  ['teenagers', 'times', 'december', '2018'],
#  ['afghan',
#   'leaders',
#   'dispute',
#   'trumps',
#   'claim',
#   'soviets',
#   'invaded',
#   'fight',
#   'terrorists'],
#  ['north',
#   'koreas',
#   'envoy',
#   'italy',
#   'disappears',
#   'raising',
#   'suspicions',
#   'defection'],
#  ['kansas', 'senator', 'pat', 'roberts', 'seek', 'reelection'],
#  ['4', 'new', 'yorkers', 'experts', 'living', 'know', 'dont'],
#  ['whos', 'afraid', 'budget', 'deficit'],
#  ['trumps', 'wall', 'trumps', 'shutdown', 'trumps', 'side', 'story'],
#  ['back', 'bayou', 'james', 'lee', 'burkes', 'latest', 'novel'],
#  ['behind', 'cover', 'american', 'dream', 'destroyed'],
#  ['shes', 'metoo', 'mission', 'china', 'battling', 'censors', 'lawsuits'],
#  ['top', 'qatari', 'soccer', 'official', 'barred', 'tournament', 'uae'],
#  ['800000',
#   'poor',
#   'new',
#   'yorkers',
#   '30000',
#   'get',
#   'new',
#   'halfpriced',
#   'metrocards'],
#  ['market',
#   'cools',
#   'median',
#   'price',
#   'manhattan',
#   'apartment',
#   'drops',
#   '1',
#   'million',
#   '999000'],
#  ['britney',
#   'spears',
#   'announces',
#   'indefinite',
#   'work',
#   'hiatus',
#   'cancels',
#   'las',
#   'vegas',
#   'residency'],
#  ['politics', 'trump', 'rejects', 'shutdown', 'compromise'],
#  ['vanishing', 'review', 'lighthouse', 'temptation'],
#  ['rust',
#   'creek',
#   'review',
#   'woman',
#   'stranded',
#   'backwoods',
#   'kentucky',
#   'could',
#   'go',
#   'wrong'],
#  ['phillies', 'sign', 'david', 'robertson', 'adding', 'offseason', 'spending'],
#  ['american',
#   'detained',
#   'moscow',
#   'also',
#   'british',
#   'irish',
#   'canadian',
#   'passports'],
#  ['expert', 'called', 'market', 'plunge', 'heres', 'sees', '2019'],
#  ['quotation',
#   'day',
#   'pelosi',
#   'rises',
#   'speaker',
#   'divided',
#   'rule',
#   'dawns',
#   'paralyzed',
#   'capital'],
#  ['review', 'millbrook', 'winery', 'jarrahdale', 'western', 'australia'],
#  ['people', 'vs', 'donald', 'j', 'trump'],
#  ['politics', 'biggest', 'stories', 'week'],
#  ['silence', 'music', 'meditation'],
#  ['inquiry', 'migrant', 'shelters', 'poses', 'dilemma', 'happens', 'children'],
#  ['powell',
#   'says',
#   'patient',
#   'fed',
#   'watching',
#   'signs',
#   'economic',
#   'weakness'],
#  ['end', 'navys', 'breadandwater', 'punishment'],
#  ['enes',
#   'kanter',
#   'skip',
#   'knicks',
#   'trip',
#   'london',
#   'citing',
#   'fear',
#   'turkish',
#   'retaliation'],
#  ['five', 'carryon', 'essentials', 'travelers', 'love', 'pack', 'light'],
#  ['aiming', 'trump', 'democrats', 'lay', 'agenda', 'postshutdown', 'congress'],
#  ['egypt',
#   'tried',
#   'block',
#   'broadcast',
#   'cbs',
#   'interview',
#   'president',
#   'sisi'],
#  ['honoring',
#   'quieter',
#   'characters',
#   'tale',
#   'mass',
#   'shootings',
#   'double',
#   'survivors'],
#  ['genius', 'insomnia'],
#  ['pope',
#   'cites',
#   'crisis',
#   'credibility',
#   'message',
#   'us',
#   'bishops',
#   'sex',
#   'abuse'],
#  ['10', 'winter', 'fashion', 'ideas', 'inspired', 'english', 'countryside'],
#  ['word', 'quiz', 'bluff'],
#  ['pompeo',
#   'plans',
#   'press',
#   'saudi',
#   'leaders',
#   'killing',
#   'jamal',
#   'khashoggi'],
#  ['nfl', 'playoff', 'predictions', 'picks', 'wildcard', 'round'],
#  ['14yearold', 'charged', 'murder', 'egg', 'prank', 'fatal', 'crash'],
#  ['playlist', 'dangelos', 'cowboy', 'soul', '9', 'new', 'songs'],
#  ['new', 'years', 'sounds', 'week', 'classical', 'music'],
#  ['judge',
#   'dismisses',
#   'lawsuit',
#   'knight',
#   'landesman',
#   'artforum',
#   'magazine'],
#  ['2',
#   'mental',
#   'health',
#   'patients',
#   'drowned',
#   'sheriffs',
#   'van',
#   'florence',
#   'deputies',
#   'face',
#   'charges'],
#  ['corrections', 'january', '4', '2019'],
#  ['judge',
#   'blocks',
#   'new',
#   'york',
#   'city',
#   'law',
#   'aimed',
#   'curbing',
#   'airbnb',
#   'rentals'],
#  ['hackers',
#   'leak',
#   'details',
#   'german',
#   'lawmakers',
#   'except',
#   'far',
#   'right'],
#  ['hungarys', 'plight'],
#  ['providence', 'ri', 'bustle', 'gives', 'way', 'simple', 'pleasures'],
#  ['five', 'places', 'visit', 'beverly', 'hills'],
#  ['belgium',
#   'bans',
#   'religious',
#   'slaughtering',
#   'practices',
#   'drawing',
#   'praise',
#   'protest'],
#  ['fratricide', 'full', 'bloom', 'israeli', 'election', 'campaign', 'heats'],
#  ['government',
#   'shutdown',
#   'moon',
#   'landing',
#   'captain',
#   'tennille',
#   'thursday',
#   'briefing'],
#  ['bold', 'question', 'precedes', 'proposal'],
#  ['2018', 'best', 'year', 'human', 'history'],
#  ['afghan', 'war', 'casualty', 'report', 'dec', '28jan', '3'],
#  ['strong',
#   'hiring',
#   'fed',
#   'chiefs',
#   'reassurance',
#   'rates',
#   'delight',
#   'investors'],
#  ['trouble', 'ethiopias', 'ethnic', 'federalism'],
#  ['spy', 'american', 'loves', 'russia', 'ensnared', 'new', 'cold', 'war'],
#  ['lived', 'love', 'nest'],
#  ['winter',
#   'tv',
#   'preview',
#   'true',
#   'detective',
#   'carmen',
#   'sandiego',
#   '19',
#   'shows',
#   'watch'],
#  ['tarik', 'cohen', 'makes', 'football', 'fun', 'chicago'],
#  ['philippine',
#   'police',
#   'kill',
#   'exmayor',
#   'accused',
#   'drug',
#   'crimes',
#   'duterte'],
#  ['first', 'career', 'goal', 'gives', 'islanders', 'overtime', 'win'],
#  ['lebron', 'james', 'expected', 'miss', 'least', 'another', 'week'],
#  ['legal', 'abortions', 'begin', 'ireland', 'solidarity', 'small', 'protests'],
#  ['choreographer', 'gives', 'ambition', 'recklessness'],
#  ['critics', 'favorite', 'space', 'music', 'new', 'york', 'turns', '40'],
#  ['elites', 'ever', 'done', 'fox'],
#  ['price',
#   'value',
#   'chinese',
#   'phone',
#   'makers',
#   'outpace',
#   'apple',
#   'much',
#   'world'],
#  ['trump',
#   'raises',
#   'possibility',
#   'declaring',
#   'national',
#   'emergency',
#   'border'],
#  ['thirst', 'literature', 'meets', 'thirst', 'beer'],
#  ['ringo',
#   'lam',
#   'director',
#   'hong',
#   'kong',
#   'classic',
#   'city',
#   'fire',
#   'dies',
#   '63'],
#  ['ellen',
#   'degeneres',
#   'academy',
#   'reinstate',
#   'kevin',
#   'hart',
#   'oscars',
#   'host'],
#  ['driving', 'teach', 'us', 'living'],
#  ['unbearable', 'heaviness', 'clutter'],
#  ['edward', 'goreys', 'childrens', 'books', 'illustrations', 'revisited'],
#  ['offered',
#   'free',
#   'tickets',
#   'schindlers',
#   'list',
#   'germanys',
#   'far',
#   'right',
#   'sees',
#   'provocation'],
#  ['paparazzi',
#   'dogs',
#   'rabbitgirl',
#   'conquered',
#   'new',
#   'york',
#   'city',
#   'streets'],
#  ['pipe', 'dream', 'bipartisanship'],
#  ['one', '10', 'adults', 'food', 'allergy', 'many', 'say', 'one'],
#  ['us',
#   'ambassador',
#   'visits',
#   'american',
#   'arrested',
#   'russia',
#   'spying',
#   'charge'],
#  ['jailing',
#   'wrong',
#   'man',
#   'mug',
#   'shot',
#   'searches',
#   'persist',
#   'new',
#   'york',
#   'despite',
#   'serious',
#   'risks'],
#  ['rose', 'bowl', 'stand', 'way', 'bigger', 'college', 'football', 'playoff'],
#  ['heading', 'west', 'new', 'development'],
#  ['turn', 'volume'],
#  ['skate', 'feels', 'free'],
#  ['charges', 'domestic', 'violence', 'reuben', 'foster', 'dropped'],
#  ['call', 'arms', 'supreme', 'court'],
#  ['toll',
#   'science',
#   'research',
#   'mounts',
#   'government',
#   'shutdown',
#   'continues'],
#  ['americans', 'get', 'along'],
#  ['blake', 'w', 'nordstrom', 'scion', 'retail', 'family', 'dies', '58'],
#  ['board', 'books', 'let', 'toddlers', 'join', 'action'],
#  ['mike', 'tomlin', 'damage', 'control', 'antonio', 'browns', 'absence'],
#  ['whats', 'going', 'graph', 'jan', '9', '2019'],
#  ['shutdown', 'according', 'trump'],
#  ['bowling',
#   'alley',
#   'shooting',
#   'california',
#   'leaves',
#   '3',
#   'dead',
#   '4',
#   'injured'],
#  ['would', 'gop', 'vote', 'convict', 'trump'],
#  ['like', 'game', 'designer', 'new', 'york', 'times'],
#  ['one',
#   'americas',
#   'vital',
#   'exports',
#   'education',
#   'never',
#   'goes',
#   'abroad',
#   'still',
#   'faces',
#   'threats'],
#  ['herb',
#   'kelleher',
#   'whose',
#   'southwest',
#   'airlines',
#   'reshaped',
#   'industry',
#   'dies',
#   '87'],
#  ['dealbook',
#   'briefing',
#   'apples',
#   'struggles',
#   'add',
#   'uncertainty',
#   'markets'],
#  ['rents', 'rise', '2018'],
#  ['france',
#   'debates',
#   'teach',
#   'arabic',
#   'public',
#   'school',
#   'local',
#   'mosque'],
#  ['georges',
#   'loinger',
#   'wartime',
#   'rescuer',
#   'jewish',
#   'children',
#   'dies',
#   '108'],
#  ['new', 'paperback', 'elastic', 'brass'],
#  ['full', 'shutdown', 'l', 'train', 'halted', 'cuomo'],
#  ['nashville',
#   'lawmakers',
#   'urge',
#   'clemency',
#   'cyntoia',
#   'brown',
#   'trafficking',
#   'victim',
#   'imprisoned',
#   'murder'],
#  ['best', '85', 'life', 'lessons', 'oldest', 'old'],
#  ['8', 'things', 'kids', 'nyc', 'weekend'],
#  ['envoys', 'denounce', 'venezuelas', 'maduro', 'urge', 'cede', 'power'],
#  ['stocks',
#   'surge',
#   'powell',
#   'signals',
#   'fed',
#   'flexibility',
#   'jobs',
#   'data',
#   'eases',
#   'worries'],
#  ['corrections', 'january', '3', '2019'],
#  ['veterans', 'groups', 'compete', 'struggle', 'va'],
#  ['trump',
#   'administration',
#   'freezes',
#   'raises',
#   'pence',
#   'cabinet',
#   'members'],
#  ['try', 'keep', 'australias', 'fastest', '92yearold', 'woman'],
#  ['danced', 'royalty', 'mostly', 'leering', 'men'],
#  ['quotation',
#   'day',
#   'china',
#   'turns',
#   'censorship',
#   'lucrative',
#   'factory',
#   'work'],
#  ['honey',
#   'lantree',
#   '75',
#   'rarity',
#   'female',
#   '60s',
#   'rock',
#   'drummer',
#   'dead'],
#  ['gore', 'graft', 'weve', 'learned', 'far', 'el', 'chapo', 'trial'],
#  ['new',
#   'york',
#   'citys',
#   'poor',
#   'promised',
#   'halfpriced',
#   'metrocards',
#   'theyre',
#   'still',
#   'waiting'],
#  ['carlos', 'ghosn', 'former', 'nissan', 'chairman', 'appear', 'court'],
#  ['los',
#   'angeles',
#   'accuses',
#   'weather',
#   'channel',
#   'app',
#   'covertly',
#   'mining',
#   'user',
#   'data'],
#  ['us',
#   'investigate',
#   'discrimination',
#   'native',
#   'students',
#   'montana',
#   'reservation'],
#  ['st', 'johns', 'rides', 'transfers', 'renewed', 'relevance'],
#  ['words', 'women', 'rule', 'headlines'],
#  ['chinese',
#   'consumers',
#   'confidence',
#   'sags',
#   'casting',
#   'pall',
#   'global',
#   'economy'],
#  ['apples', 'biggest', 'problem', 'mom'],
#  ['judge',
#   'extends',
#   'term',
#   'grand',
#   'jury',
#   'hearing',
#   'evidence',
#   'mueller'],
#  ['migrants', 'rescued', 'greeks', 'sea', 'reward', 'citizenship'],
#  ['get', 'preschoolers', 'share'],
#  ['variety', 'acrostic'],
#  ['breaking', 'news'],
#  ['day', '1', 'democratic', 'majority'],
#  ['week',
#   'arts',
#   'roy',
#   'hargrove',
#   'caleb',
#   'teicher',
#   'prototype',
#   'festival'],
#  ['speaker', 'pelosi', 'returns'],
#  ['trump', 'cannot', 'declare', 'emergency', 'build', 'wall'],
#  ['ocean', 'cleanup', 'plastic', 'collector', 'heading', 'home', 'pieces'],
#  ['purposeful', 'grain', 'bowl', 'full', 'delights'],
#  ['alabama', 'clemson', 'undefeated', 'one', 'win'],
#  ['long', 'alabama', 'south', 'sewanee'],
#  ['congress',
#   'espionage',
#   'china',
#   'economy',
#   'thursday',
#   'evening',
#   'briefing'],
#  ['taiwans',
#   'president',
#   'defying',
#   'xi',
#   'jinping',
#   'calls',
#   'unification',
#   'offer',
#   'impossible'],
#  ['spring', 'coming'],
#  ['surviving',
#   'r',
#   'kelly',
#   'documentary',
#   'lifetime',
#   'details',
#   'sex',
#   'abuse',
#   'accusations'],
#  ['fires',
#   'ravaged',
#   'california',
#   'utilities',
#   'lobbied',
#   'lawmakers',
#   'protection'],
#  ['chelsea', 'peretti', 'wants', 'comedies', 'funny'],
#  ['sounds',
#   'haunted',
#   'us',
#   'diplomats',
#   'cuba',
#   'lovelorn',
#   'crickets',
#   'scientists',
#   'say'],
#  ['trump',
#   'says',
#   'much',
#   'headway',
#   'talks',
#   'shutdown',
#   'enters',
#   'third',
#   'week'],
#  ['chigozie', 'obioma', 'book'],
#  ['john',
#   'flanagan',
#   'gop',
#   'state',
#   'senate',
#   'leader',
#   'seeks',
#   'treatment',
#   'alcohol',
#   'abuse'],
#  ['noisy', 'houseguests', 'upstairs', 'airbnb'],
#  ['week', 'tech', 'amazons', 'burning', 'problems'],
#  ['l', 'train', 'shutdown', 'canceled', 'exactly', 'mean'],
#  ['whats', 'tv', 'saturday', 'winter', 'castle', 'twilight'],
#  ['world', 'fine', 'lines', 'manchester', 'city', 'tightens', 'title', 'race'],
#  ['homes', 'sale', 'new', 'york', 'new', 'jersey'],
#  ['15', 'minimum', 'wage', 'need', '33', 'hour'],
#  ['alexandria',
#   'ocasiocortez',
#   'dancing',
#   'video',
#   'meant',
#   'smear',
#   'backfired'],
#  ['matteo',
#   'salvini',
#   'likes',
#   'nutella',
#   'kittens',
#   'part',
#   'social',
#   'media',
#   'strategy'],
#  ['violence',
#   'surges',
#   'yellow',
#   'vests',
#   'attack',
#   'french',
#   'government',
#   'ministry'],
#  ['michelle', 'obamas', 'book', '1', '1', 'finland', 'singapore', 'portugal'],
#  ['republicans', 'support', 'immigration'],
#  ['yes', 'mr', 'trump', 'look', 'foolish'],
#  ['ian', 'schrager', 'still', 'creating', 'buzz'],
#  ['learning',
#   'newly',
#   'divided',
#   'government',
#   'control',
#   'political',
#   'agenda'],
#  ['pit', 'bull', 'gets', 'rebrand'],
#  ['mcconnell',
#   'faces',
#   'pressure',
#   'republicans',
#   'stop',
#   'avoiding',
#   'shutdown',
#   'fight'],
#  ['latest', 'front', 'civil', 'rights'],
#  ['rocky', '2018', 'populism', 'far', 'west'],
#  ['state',
#   'like',
#   'sleep',
#   'review',
#   'suspicious',
#   'suicide',
#   'drives',
#   'suffocating',
#   'thriller'],
#  ['mens',
#   'team',
#   'tennis',
#   'events',
#   'rise',
#   'coed',
#   'hopman',
#   'cup',
#   'left',
#   'limbo'],
#  ['20', 'best', 'soups', 'stews'],
#  ['government', 'shutdown', 'may', 'turn', 'day', 'court', 'fouryear', 'wait'],
#  ['likability', 'politics', 'sexist', 'yes', 'also', 'outdated'],
#  ['christine', 'mcguire', 'eldest', 'singing', 'sisters', 'dead', '92'],
#  ['first', 'solo', 'antarctic', 'traverse'],
#  ['daughters', 'rich', 'friends', 'driving', 'nuts'],
#  ['whats',
#   'tv',
#   'friday',
#   'beautiful',
#   'boy',
#   'ron',
#   'funches',
#   'giggle',
#   'fit'],
#  ['making', 'peace', 'music', 'left', 'omnivorous', 'young', 'composer'],
#  ['new', 'battles', 'direction', 'jazz'],
#  ['11yearold',
#   'boys',
#   'death',
#   'brooklyn',
#   'may',
#   'caused',
#   'airborne',
#   'fish',
#   'proteins'],
#  ['man', 'charged', 'murder', 'killing', 'california', 'police', 'officer'],
#  ['predictions', '2019'],
#  ['economics', 'soaking', 'rich'],
#  ['defiant', 'interview', 'jail', 'cell', 'soon', 'turn', 'murder', 'scene'],
#  ['fed', 'chairman', 'powell', 'markets', 'hear'],
#  ['love', 'nothing', 'bad', 'yoga'],
#  ['11', 'new', 'books', 'recommend', 'week'],
#  ['us',
#   'accuses',
#   'iran',
#   'using',
#   'space',
#   'launch',
#   'cover',
#   'missile',
#   'program'],
#  ['word', 'quiz', 'regicide'],
#  ['amos', 'ozs', 'rebuke', 'cowardice'],
#  ['congress',
#   'examining',
#   'decision',
#   'lift',
#   'sanctions',
#   'russians',
#   'firms'],
#  ['l',
#   'train',
#   'shutdown',
#   'plan',
#   '3',
#   'years',
#   'making',
#   'unraveled',
#   '3',
#   'weeks'],
#  ['much', 'watching', 'time', 'weekend'],
#  ['start', 'running', 'routine'],
#  ['reportage', 'rises', 'art'],
#  ['immigrants', 'el', 'salvador', 'hopeful', 'fearful', 'future'],
#  ['best', 'california', 'stories', '2018'],
#  ['us',
#   'renews',
#   'china',
#   'travel',
#   'warning',
#   'citing',
#   'risk',
#   'arbitrary',
#   'detention'],
#  ['5', 'reasons', 'wouldnt', 'want', 'tim', 'cooks', 'shoes', 'right'],
#  ['mexico', 'calls', 'us', 'investigate', 'use', 'tear', 'gas', 'border'],
#  ['poem', 'oneway', 'gate'],
#  ['facing', 'rejection'],
#  ['devices', 'invade', 'life', '2019', 'whats', 'overhyped'],
#  ['go', 'bare'],
#  ['tango', 'heart'],
#  ['archaeologists',
#   'find',
#   'precolumbian',
#   'temple',
#   'flayed',
#   'lord',
#   'central',
#   'mexico'],
#  ['fugitive', 'slaves', 'road', 'civil', 'war'],
#  ['elephantsize', 'relative', 'mammals', 'grazed', 'alongside', 'dinosaurs'],
#  ['price',
#   'trumps',
#   'migrant',
#   'deterrence',
#   'strategy',
#   'new',
#   'chaos',
#   'border'],
#  ['us', 'best', 'worst', 'trailers', 'new', 'year'],
#  ['questions', 'answered'],
#  ['heres', 'didnt', 'vote', 'nancy', 'pelosi', 'speaker'],
#  ['kevin', 'tway', 'leads', 'tournament', 'champions', 'first', 'round'],
#  ['weve', 'learned', 'ultima', 'thule', 'nasas', 'new', 'horizons', 'mission'],
#  ['us',
#   'accuses',
#   'peru',
#   'violating',
#   'agreement',
#   'protect',
#   'rain',
#   'forest'],
#  ['supreme', 'court', 'takes', 'new', 'cases', 'partisan', 'gerrymandering'],
#  ['end', 'age', 'apple'],
#  ['rashida',
#   'tlaib',
#   'sworn',
#   'palestinianamericans',
#   'respond',
#   'tweetyourthobe'],
#  ['falling', 'stock', 'market', 'nothing'],
#  ['quotation', 'day', 'cry', 'impeach', 'upsets', 'agenda', 'democrats'],
#  ['game', 'thrones', 'say', 'donald', 'trump', 'thinks'],
#  ['tsa', 'screeners', 'working', 'without', 'pay', 'calling', 'sick'],
#  ['wells', 'fargo', 'generous', 'federal', 'workers'],
#  ['toxic',
#   'peroxide',
#   'found',
#   'dutch',
#   'beach',
#   'cargo',
#   'ship',
#   'loses',
#   '277',
#   'containers'],
#  ['readers', 'first', 'memory', 'racism', 'youre', 'black'],
#  ['marriott',
#   'concedes',
#   '5',
#   'million',
#   'passport',
#   'numbers',
#   'lost',
#   'hackers',
#   'encrypted'],
#  ['chuck', 'schumer', 'wall', 'shutdown', 'era', 'divided', 'government'],
#  ['apples', 'warning', 'surprise', 'suppliers'],
#  ['deal', 'brexit', 'finding', 'favor', 'british', 'conservatives'],
#  ['london', 'stages', 'atmosphere', 'tragic'],
#  ['choose', 'candidate'],
#  ['britain', 'needs', 'brexit', 'insurance', 'plan'],
#  ['2019', 'spoleto', 'festival', 'feature', 'new', 'salome'],
#  ['democratic', 'primary', 'doesnt', 'nightmare'],
#  ['tracking', 'demise', 'marriage', 'google', 'maps'],
#  ['could', 'face', 'mortality', 'sons', 'another', 'story'],
#  ['useless', 'knowledge', 'begets', 'new', 'horizons'],
#  ['news', '2018', 'memorable', 'corrections'],
#  ['white',
#   'house',
#   'mulls',
#   'jim',
#   'webb',
#   'exdemocratic',
#   'senator',
#   'next',
#   'defense',
#   'secretary'],
#  ['get', 'want', 'parents'],
#  ['russia', 'us', 'congress', 'brexit', 'friday', 'briefing'],
#  ['extravagant', 'life', 'hector', 'xtravaganza'],
#  ['russia', 'highrise', 'collapse', 'emblem', 'hardships', 'hinterlands'],
#  ['french', 'doctors', 'office', 'taught', 'health', 'care'],
#  ['choreographed', 'cacophony', 'ferryman'],
#  ['pet', 'insurance', 'policies', 'sold', 'worth', 'cost'],
#  ['5', 'film', 'series', 'catch', 'nyc', 'weekend'],
#  ['congress', 'stocks', 'china', 'friday', 'briefing'],
#  ['life', 'without', 'smartphone'],
#  ['choir', 'composition'],
#  ['letter', 'recommendation', 'old', 'english'],
#  ['dean', 'ford', 'singer', 'marmalades', 'reflections', 'dead', '72'],
#  ['eat', 'crave'],
#  ['japans',
#   'king',
#   'tuna',
#   'pays',
#   'record',
#   '3',
#   'million',
#   'bluefin',
#   'new',
#   'tokyo',
#   'fish',
#   'market'],
#  ['treating', 'fetus', 'person'],
#  ['whats',
#   'tv',
#   'thursday',
#   'support',
#   'girls',
#   'black',
#   'mirror',
#   'bandersnatch'],
#  ['escape', 'room', 'review', 'puzzle', 'way', 'youre', 'dead'],
#  ['geoffrey',
#   'langlands',
#   'lauded',
#   'british',
#   'educator',
#   'pakistan',
#   'dies',
#   '101'],
#  ['make', 'bucking', 'bull', 'good', 'breeding', 'maybe', 'cows', 'love'],
#  ['philip', 'rivers', 'doesnt', 'need', 'ring', 'great'],
#  ['unsentimental',
#   'darkly',
#   'elegant',
#   'stories',
#   'ruth',
#   'prawer',
#   'jhabvala'],
#  ['letters', 'editor'],
#  ['nancy',
#   'pelosi',
#   'elected',
#   'speaker',
#   'democrats',
#   'take',
#   'control',
#   'house'],
#  ['saudi',
#   'arabia',
#   'seeks',
#   'death',
#   'penalty',
#   '5',
#   'suspects',
#   'khashoggi',
#   'killing'],
#  ['migrants', 'tijuana', 'know', 'trump', 'doesnt', 'want', 'arent', 'giving'],
#  ['4', 'reasons', 'tampa', 'bay', 'lightning', 'dominated', 'nhl'],
#  ['us', 'congress', 'turkey', 'china', 'friday', 'briefing'],
#  ['william',
#   'c',
#   'thompson',
#   'pioneering',
#   'black',
#   'legislator',
#   'judge',
#   'dies',
#   '94'],
#  ['protesting', 'slave', 'law', 'thousands', 'take', 'streets', 'hungary'],
#  ['mrinal', 'sen', 'one', 'indias', 'leading', 'directors', 'dies', '95'],
#  ['harold',
#   'brown',
#   'defense',
#   'secretary',
#   'carter',
#   'administration',
#   'dies',
#   '91'],
#  ['cook', 'weekend'],
#  ['republicans',
#   'seek',
#   'boost',
#   'small',
#   'donations',
#   'fragmented',
#   'system',
#   'stymies'],
#  ['psychotherapists', 'plea', 'louis', 'ck'],
#  ['call', 'stay', 'vigilant'],
#  ['30', 'art', 'exhibitions', 'view', 'nyc', 'weekend'],
#  ['ate', 'mall', 'pizza', 'fell', 'love', 'america'],
#  ['marines',
#   'integrate',
#   'female',
#   'male',
#   'training',
#   'battalions',
#   'first',
#   'time'],
#  ['edgar',
#   'hilsenrath',
#   '92',
#   'writer',
#   'unvarnished',
#   'holocaust',
#   'novels',
#   'dies'],
#  ['shepherds', 'pie', 'loses', 'lamb'],
#  ['molly',
#   'crabapples',
#   'illustrated',
#   'reflection',
#   'sabahattin',
#   'alis',
#   'novel',
#   'madonna',
#   'fur',
#   'coat'],
#  ['photographers', 'insider', 'view', 'bohemian', 'life'],
#  ['new', 'faces'],
#  ['opposition', 'leader', 'seen', 'church', 'winning', 'congo', 'vote'],
#  ['congress', 'turkey', 'apple', 'thursday', 'briefing'],
#  ['neil',
#   'degrasse',
#   'tysons',
#   'show',
#   'pulled',
#   'amid',
#   'misconduct',
#   'allegations'],
#  ['justin', 'trudeau', 'make', 'two', 'row'],
#  ['7', 'classical', 'music', 'concerts', 'see', 'nyc', 'weekend'],
#  ['fewer', 'women', 'directed', 'top', 'films', '2018', 'study', 'finds'],
#  ['illegal',
#   'butt',
#   'lift',
#   'injection',
#   'leads',
#   'death',
#   'manslaughter',
#   'charge'],
#  ['approach', 'career', 'changes', 'find', 'niche', 'fill'],
#  ['many', 'lives', 'sharon', 'van', 'etten'],
#  ['philippine', 'mayor', 'behind', 'congressmans', 'killing', 'police', 'say'],
#  ['cornelia',
#   'street',
#   'café',
#   'pillar',
#   'greenwich',
#   'village',
#   'experimentation',
#   'closes',
#   'doors'],
#  ['property', 'brothers', 'offer', 'renovation', 'tips'],
#  ['border', 'wall', 'boxing', 'trump'],
#  ['trump',
#   'suggests',
#   'government',
#   'shutdown',
#   'could',
#   'last',
#   'months',
#   'even',
#   'years'],
#  ['need', 'keep', 'laughing'],
#  ['newly',
#   'single',
#   'review',
#   'breakup',
#   'leaves',
#   'director',
#   'directionless'],
#  ['pegi', 'young', '66', 'musician', 'started', 'school', 'disabled', 'dies'],
#  ['londons', 'theaters', 'tackle', 'big', 'issue', 'womens', 'bathrooms'],
#  ['celebrating', '200th', 'anniversary', 'queen', 'victoria'],
#  ['middleclass', 'shame', 'decide', 'america', 'headed'],
#  ['tsa', 'without', 'public', 'face'],
#  ['daryl', 'dragon', 'captain', 'tennille', 'pop', 'duo', 'dies', '76'],
#  ['grave', 'fireflies', 'review', 'pioneering', 'animated', 'classic'],
#  ['government', 'shutdown', 'leaves', 'workers', 'reeling', 'seem', 'pawns'],
#  ['dementia', 'may', 'never', 'improve', 'many', 'patients', 'still', 'learn'],
#  ['white', 'supremacy', 'genetics', 'dr', 'james', 'watson'],
#  ['notes', 'jerry', 'browns', 'long', 'nonfarewell', 'tour'],
#  ['boogie', 'bronx', 'girl'],
#  ['eureka', 'moment', 'subway'],
#  ['artwork', 'taken', 'africa', 'returning', 'home', 'transformed'],
#  ['rosalyn',
#   'terborgpenn',
#   '77',
# ...
#  ['golden', 'globes', '2019', 'parties', 'winner', 'billy', 'porter'],
#  ['trumps', 'wall', 'trumps', 'shutdown', 'trumps', 'side', 'story'],
#  ['supreme',
#   'court',
#   'wont',
#   'intervene',
#   'case',
#   'kennedy',
#   'cousin',
#   'skakel'],
#  ['politics', 'bolton', 'puts', 'conditions', 'syria', 'withdrawal'],
#  ['earth', 'moon', 'short', 'walk', 'high', 'line'],
#  ['afghan', 'villagers', 'panning', 'gold', 'die', 'tunnels', 'collapse'],
#  ['jazmine', 'barnes', 'case', 'shows', 'trauma', 'affect', 'memory'],
#  ['shortcut', 'cooking', 'jamie', 'oliver'],
#  ['softbank', 'bets', 'big', 'wework'],
#  ['wall',
#   'two',
#   'prayers',
#   'little',
#   'progress',
#   'weekend',
#   'meetings',
#   'shutdown'],
#  ['migrants', 'despair', 'growing', 'us', 'border', 'smugglers', 'profits'],
#  ['twist',
#   'jazmine',
#   'barnes',
#   'case',
#   'suspect',
#   'charged',
#   'capital',
#   'murder'],
#  ['pope', 'francis', 'appeals', 'europe', 'show', 'solidarity', 'migrants'],
#  ['people', 'vs', 'donald', 'j', 'trump'],
#  ['trump',
#   'promised',
#   'bring',
#   'jobs',
#   'back',
#   'tariffs',
#   'threaten',
#   'send',
#   'away'],
#  ['politics', 'biggest', 'stories', 'week'],
#  ['inquiry', 'migrant', 'shelters', 'poses', 'dilemma', 'happens', 'children'],
#  ['regina', 'king', 'times', 'gender', 'equity', 'golden', 'globes'],
#  ['enes',
#   'kanter',
#   'skip',
#   'knicks',
#   'trip',
#   'london',
#   'citing',
#   'fear',
#   'turkish',
#   'retaliation'],
#  ['five', 'carryon', 'essentials', 'travelers', 'love', 'pack', 'light'],
#  ['big', 'retailers', 'seek', 'cut', 'tax', 'bills', 'towns', 'bear', 'brunt'],
#  ['genius', 'insomnia'],
#  ['netanyahu',
#   'feeling',
#   'heat',
#   'grabs',
#   'spotlight',
#   'assail',
#   'witch',
#   'hunt',
#   'investigation'],
#  ['donors', 'rare', 'blood', 'type', 'sought', 'save', 'miami', 'toddler'],
#  ['cook', 'week'],
#  ['martha', 'shulman', 'robert', 'israel'],
#  ['belgium',
#   'bans',
#   'religious',
#   'slaughtering',
#   'practices',
#   'drawing',
#   'praise',
#   'protest'],
#  ['fratricide', 'full', 'bloom', 'israeli', 'election', 'campaign', 'heats'],
#  ['golden', 'globes', 'surprise', 'wins', 'arent', 'surprising'],
#  ['bold', 'question', 'precedes', 'proposal'],
#  ['whats', 'tv', 'sunday', 'mollys', 'game', 'annihilation'],
#  ['globalfest', 'world', 'music', 'costumes', 'messages'],
#  ['2018', 'best', 'year', 'human', 'history'],
#  ['turning', 'curse', 'ham', 'blessing'],
#  ['week', 'business', 'wanted', 'slow', 'start', 'new', 'year', 'anyway'],
#  ['21', 'savage', 'repeats', '1', 'sluggish', 'postholiday', 'week'],
#  ['airstrike', 'kills', 'plotter', 'deadly', 'bombing', 'uss', 'cole'],
#  ['trumps', 'merrygoround', 'north', 'korea'],
#  ['lived', 'love', 'nest'],
#  ['wants', 'market', 'downturn', 'investors', 'actually'],
#  ['david', 'chase', 'sopranos', 'trump', 'yes', 'ending'],
#  ['xinjiang', 'us', 'shutdown', 'golden', 'globes', 'monday', 'briefing'],
#  ['sorry', 'canada', 'parity', 'reshapes', 'world', 'junior', 'championship'],
#  ['elizabeth', 'dean', 'erin', 'marie', 'randall'],
#  ['arrest', 'jazmine', 'barness', 'killing', 'allays', 'hatecrime', 'fears'],
#  ['lebron', 'james', 'expected', 'miss', 'least', 'another', 'week'],
#  ['chargers', 'defense', 'stifles', 'ravens', 'wildcard', 'playoff', 'win'],
#  ['legal', 'abortions', 'begin', 'ireland', 'solidarity', 'small', 'protests'],
#  ['elites', 'ever', 'done', 'fox'],
#  ['trump',
#   'raises',
#   'possibility',
#   'declaring',
#   'national',
#   'emergency',
#   'border'],
#  ['golden',
#   'globes',
#   '2019',
#   'sandra',
#   'oh',
#   'gets',
#   'emotional',
#   'hollywood',
#   'diversity'],
#  ['thirst', 'literature', 'meets', 'thirst', 'beer'],
#  ['mavericks', 'key', 'keeping', 'players', 'fresh', 'blood', 'samples'],
#  ['could', 'immunotherapy', 'offer', 'cure', 'cancer'],
#  ['golden',
#   'globes',
#   '2019',
#   'carol',
#   'burnett',
#   'says',
#   'show',
#   'couldnt',
#   'done',
#   'today'],
#  ['shutdown', 'golden', 'globes', 'whales', 'monday', 'evening', 'briefing'],
#  ['aquaman', 'leads', 'box', 'office', 'new', 'year'],
#  ['518', 'inmates', 'sleep', 'space', '170', 'gangs', 'hold', 'together'],
#  ['would',
#   'pursue',
#   'career',
#   'knew',
#   'likely',
#   'would',
#   'make',
#   'much',
#   'money'],
#  ['graceann', 'caramico', 'alfonse', 'muglia'],
#  ['jailing',
#   'wrong',
#   'man',
#   'mug',
#   'shot',
#   'searches',
#   'persist',
#   'new',
#   'york',
#   'despite',
#   'serious',
#   'risks'],
#  ['4yearold', 'cant', 'sit', 'father', 'devotes', 'care'],
#  ['skate', 'feels', 'free'],
#  ['mint', 'tea', 'morocco'],
#  ['saw', 'london', 'fashion', 'week', 'mens'],
#  ['quiet',
#   'revolution',
#   'women',
#   'seek',
#   'divorces',
#   'conservative',
#   'west',
#   'africa'],
#  ['gavin',
#   'newsom',
#   'takes',
#   'california',
#   'governor',
#   'pledges',
#   'fight',
#   'equality'],
#  ['toll',
#   'science',
#   'research',
#   'mounts',
#   'government',
#   'shutdown',
#   'continues'],
#  ['peter', 'meldrum', 'lost', 'fight', 'patent', 'genes', 'dies', '71'],
#  ['expect', 'gavin', 'newsoms', 'inauguration'],
#  ['two', 'marines', 'navy', 'sailor', 'investigated', 'contractors', 'death'],
#  ['biden', '2020', 'allies', 'say', 'sees', 'democrats', 'best', 'hope'],
#  ['shutdown', 'according', 'trump'],
#  ['american',
#   'isis',
#   'member',
#   'caught',
#   'syrian',
#   'battlefield',
#   'militia',
#   'says'],
#  ['bowling',
#   'alley',
#   'shooting',
#   'california',
#   'leaves',
#   '3',
#   'dead',
#   '4',
#   'injured'],
#  ['like', 'game', 'designer', 'new', 'york', 'times'],
#  ['justice',
#   'ruth',
#   'bader',
#   'ginsburg',
#   'misses',
#   'supreme',
#   'court',
#   'arguments'],
#  ['cyntoia', 'brown', 'granted', 'clemency', '15', 'years', 'prison'],
#  ['shutdown', 'isnt', 'politics', 'bills', 'groceries'],
#  ['leadership', 'profanity'],
#  ['france',
#   'debates',
#   'teach',
#   'arabic',
#   'public',
#   'school',
#   'local',
#   'mosque'],
#  ['broadway', 'actors', 'pushing', 'profitsharing', 'creation', 'shows'],
#  ['moved', 'window', 'seat', 'offered', 'handshake', 'apology'],
#  ['malaysias', 'king', 'unusual', 'monarch', 'abruptly', 'leaves', 'job'],
#  ['simple', 'way', 'better', 'remember', 'things', 'draw', 'picture'],
#  ['golden', 'globe', 'winners', '2019', 'complete', 'list'],
#  ['yankees', 'zach', 'britton', 'agree', '3year', 'deal'],
#  ['trump',
#   'administration',
#   'freezes',
#   'raises',
#   'pence',
#   'cabinet',
#   'members'],
#  ['danced', 'royalty', 'mostly', 'leering', 'men'],
#  ['moral',
#   'dilemma',
#   'las',
#   'vegas',
#   'massacre',
#   'sell',
#   'gunmans',
#   'weapons',
#   'destroy'],
#  ['rosenda', 'monteros', 'actress', 'magnificent', 'seven', 'dies'],
#  ['elizabeth',
#   'warren',
#   'visit',
#   'iowans',
#   'get',
#   'first',
#   'taste',
#   '2020',
#   'im',
#   'ready',
#   'convinced'],
#  ['trump', 'offers', 'steel', 'barrier', 'democrats', 'unmoved'],
#  ['top',
#   'cancer',
#   'doctor',
#   'forced',
#   'ties',
#   'drug',
#   'makers',
#   'joins',
#   'ranks'],
#  ['able', 'take', 'facebook', 'court'],
#  ['apples', 'biggest', 'problem', 'mom'],
#  ['judge',
#   'extends',
#   'term',
#   'grand',
#   'jury',
#   'hearing',
#   'evidence',
#   'mueller'],
#  ['variety', 'acrostic'],
#  ['breaking', 'news'],
#  ['another',
#   'day',
#   'another',
#   'exoplanet',
#   'nasas',
#   'tess',
#   'keeps',
#   'counting'],
#  ['speaker', 'pelosi', 'returns'],
#  ['trump', 'cannot', 'declare', 'emergency', 'build', 'wall'],
#  ['bears', 'hopes', 'beating', 'eagles', 'end', 'thunkthunkthud'],
#  ['taiwans',
#   'president',
#   'defying',
#   'xi',
#   'jinping',
#   'calls',
#   'unification',
#   'offer',
#   'impossible'],
#  ['spring', 'coming'],
#  ['surviving',
#   'r',
#   'kelly',
#   'documentary',
#   'lifetime',
#   'details',
#   'sex',
#   'abuse',
#   'accusations'],
#  ['fires',
#   'ravaged',
#   'california',
#   'utilities',
#   'lobbied',
#   'lawmakers',
#   'protection'],
#  ['trump',
#   'says',
#   'much',
#   'headway',
#   'talks',
#   'shutdown',
#   'enters',
#   'third',
#   'week'],
#  ['disparaged', 'police', 'facebook', 'arrested'],
#  ['taiwanese', 'favorites', 'chelsea'],
#  ['noisy', 'houseguests', 'upstairs', 'airbnb'],
#  ['brian', 'garfield', 'prolific', 'author', 'death', 'wish', 'dies', '79'],
#  ['whats', 'tv', 'saturday', 'winter', 'castle', 'twilight'],
#  ['clemson',
#   'leaves',
#   'doubt',
#   'national',
#   'championship',
#   'thrashing',
#   'alabama'],
#  ['violence',
#   'surges',
#   'yellow',
#   'vests',
#   'attack',
#   'french',
#   'government',
#   'ministry'],
#  ['whats', 'tv', 'monday', 'bachelor', 'friday', 'night', 'lights'],
#  ['theodore', 'roosevelt', 'cared', 'deeply', 'sick', 'knew'],
#  ['latest', 'front', 'civil', 'rights'],
#  ['rocky', '2018', 'populism', 'far', 'west'],
#  ['trump', 'vulnerable'],
#  ['mens',
#   'team',
#   'tennis',
#   'events',
#   'rise',
#   'coed',
#   'hopman',
#   'cup',
#   'left',
#   'limbo'],
#  ['california', 'knows', 'wine', 'cheese', 'party'],
#  ['trump', 'make', 'broadbased', 'public', 'appeal', 'border', 'wall'],
#  ['20', 'best', 'soups', 'stews'],
#  ['national', 'emergency', 'powers', 'trumps', 'border', 'wall', 'explained'],
#  ['babs',
#   'simpson',
#   'tastemaking',
#   'fashion',
#   'editor',
#   'vogue',
#   'dead',
#   '105'],
#  ['los', 'angeles', 'braces', 'major', 'teachers', 'strike'],
#  ['illness', 'mystery', 'patients', 'turn', 'detectives'],
#  ['11yearold',
#   'boys',
#   'death',
#   'brooklyn',
#   'may',
#   'caused',
#   'airborne',
#   'fish',
#   'proteins'],
#  ['economics', 'soaking', 'rich'],
#  ['whales', 'serenaders', 'seas', 'quite', 'racket'],
#  ['cataclysmic', 'suffering', 'sprawls', 'prototype', 'festival'],
#  ['dangerously', 'deep', 'sleep', 'contagious', 'dreamers'],
#  ['amos', 'ozs', 'rebuke', 'cowardice'],
#  ['congress',
#   'examining',
#   'decision',
#   'lift',
#   'sanctions',
#   'russians',
#   'firms'],
#  ['homes', 'sold', 'around', '1000000'],
#  ['start', 'running', 'routine'],
#  ['netflixs', 'bow', 'saudi', 'censors', 'comes', 'cost', 'free', 'speech'],
#  ['free', 'lunch', 'office'],
#  ['immigrants', 'el', 'salvador', 'hopeful', 'fearful', 'future'],
#  ['sandra', 'oh', 'hosts', 'also', 'wins', 'golden', 'globes'],
#  ['poland', 'cracks', 'escape', 'rooms', 'deadly', 'fire'],
#  ['review', 'confident', 'debut', 'young', 'singer', 'turns', 'schubert'],
#  ['price',
#   'trumps',
#   'migrant',
#   'deterrence',
#   'strategy',
#   'new',
#   'chaos',
#   'border'],
#  ['weeks', 'wedding', 'announcements'],
#  ['stephanie', 'formas', 'stephen', 'carter'],
#  ['us',
#   'accuses',
#   'peru',
#   'violating',
#   'agreement',
#   'protect',
#   'rain',
#   'forest'],
#  ['workers', 'corporate', 'boards', 'germanys', 'decades'],
#  ['quotation', 'day', 'cry', 'impeach', 'upsets', 'agenda', 'democrats'],
#  ['wales',
#   'nuclear',
#   'plant',
#   'would',
#   'mean',
#   'new',
#   'jobs',
#   'uk',
#   'may',
#   'mean'],
#  ['california', 'dream', 'paid', 'leave', 'old', 'problem', 'pay'],
#  ['tsa', 'screeners', 'working', 'without', 'pay', 'calling', 'sick'],
#  ['cocktail', 'writers', 'life', 'pentagon', 'day', 'barstool', 'night'],
#  ['lady', 'gaga', 'golden', 'globes', 'parties'],
#  ['sonys', 'chief', 'plans', 'make', 'entertainment', 'assets', 'priority'],
#  ['review', 'edge', 'anarchy', 'offers', 'lessons', 'gilded', 'age'],
#  ['bolton',
#   'puts',
#   'conditions',
#   'syria',
#   'withdrawal',
#   'suggesting',
#   'delay',
#   'months',
#   'years'],
#  ['golden', 'globes', '2019', 'diverse', 'slate', 'winners'],
#  ['whats', 'going', 'picture', 'jan', '7', '2019'],
#  ['stuff'],
#  ['extravagant', 'life', 'hector', 'xtravaganza'],
#  ['russia', 'highrise', 'collapse', 'emblem', 'hardships', 'hinterlands'],
#  ['ny',
#   'today',
#   'federal',
#   'government',
#   'shutdown',
#   'affects',
#   'new',
#   'york',
#   'region'],
#  ['pentagon',
#   'chief',
#   'staff',
#   'resigns',
#   'weeks',
#   'former',
#   'bosss',
#   'pointed',
#   'departure'],
#  ['hate', 'hope', 'healing', 'radar'],
#  ['word', 'quiz', 'agape'],
#  ['new', 'york', 'firefighter', 'dies', 'falling', '50', 'feet', 'overpass'],
#  ['alexandria', 'ocasiocortez', 'dancing'],
#  ['bears', 'loss', 'particularly', 'soulcrushing', 'lets', 'count', 'ways'],
#  ['corrections', 'january', '7', '2019'],
#  ['bangkok', 'philippines', 'us', 'shutdown', 'tuesday', 'briefing'],
#  ['ukrainian', 'orthodox', 'christians', 'formally', 'break', 'russia'],
#  ['japans',
#   'king',
#   'tuna',
#   'pays',
#   'record',
#   '3',
#   'million',
#   'bluefin',
#   'new',
#   'tokyo',
#   'fish',
#   'market'],
#  ['treating', 'fetus', 'person'],
#  ['hearing',
#   'divorce',
#   'cases',
#   'sidewalk',
#   'niger',
#   'women',
#   'assert',
#   'power'],
#  ['make', 'bucking', 'bull', 'good', 'breeding', 'maybe', 'cows', 'love'],
#  ['cook', 'right'],
#  ['golden', 'globes', 'sets', 'thermometer', 'warm'],
#  ['tom', 'thibodeau', 'fired', 'timberwolves', '22point', 'win'],
#  ['saudi', 'woman', 'tried', 'flee', 'family', 'says', 'kill'],
#  ['games', 'animals', 'play'],
#  ['times', 'shows', 'pins', 'bracelets', 'golden', 'globes'],
#  ['virus', 'even', 'dangerous', 'zika', 'pregnant', 'women'],
#  ['world', 'bank', 'president', 'abruptly', 'resigns'],
#  ['migrants', 'tijuana', 'know', 'trump', 'doesnt', 'want', 'arent', 'giving'],
#  ['shutdown', 'yellow', 'vests', 'golden', 'globes', 'monday', 'briefing'],
#  ['sylvia', 'chase', 'pioneering', 'television', 'newswoman', 'dead', '80'],
#  ['democrats',
#   'faked',
#   'online',
#   'push',
#   'outlaw',
#   'alcohol',
#   'alabama',
#   'race'],
#  ['susan',
#   'zirinsky',
#   'cbs',
#   'veteran',
#   'first',
#   'woman',
#   'lead',
#   'networks',
#   'news',
#   'division'],
#  ['protesting', 'slave', 'law', 'thousands', 'take', 'streets', 'hungary'],
#  ['free', 'trees', 'many', 'detroit', 'residents', 'say', 'thanks'],
#  ['former',
#   'uber',
#   'driver',
#   'pleads',
#   'guilty',
#   'killing',
#   '6',
#   'michigan',
#   'shooting',
#   'rampage'],
#  ['harold',
#   'brown',
#   'defense',
#   'secretary',
#   'carter',
#   'administration',
#   'dies',
#   '91'],
#  ['quotation',
#   'day',
#   'harold',
#   'brown',
#   '91',
#   'former',
#   'defense',
#   'secretary',
#   'dies'],
#  ['erdogan', 'trump', 'right', 'syria', 'turkey', 'get', 'job', 'done'],
#  ['psychotherapists', 'plea', 'louis', 'ck'],
#  ['deconstructing',
#   'wall',
#   'teaching',
#   'symbolism',
#   'politics',
#   'reality',
#   'usmexico',
#   'border'],
#  ['us', 'leave', 'afghanistan'],
#  ['bohemian',
#   'rhapsody',
#   'green',
#   'book',
#   'share',
#   'spotlight',
#   'golden',
#   'globes'],
#  ['michelle',
#   'yeoh',
#   'elsie',
#   'fisher',
#   'red',
#   'carpet',
#   'stars',
#   'golden',
#   'globes'],
#  ['alabamas', 'toughest', 'competition', 'might', 'second', 'string', 'third'],
#  ['moshe',
#   'arens',
#   'israeli',
#   'statesman',
#   'exdefense',
#   'minister',
#   'dies',
#   '93'],
#  ['number', 'reported', 'rapes', 'climb', 'mayor', 'points', 'metoo'],
#  ['heck'],
#  ['trumps', 'plan', 'withdraw', 'troops', 'syria'],
#  ['passive', 'health', 'approach', 'produce', 'action'],
#  ['battle', 'wall', 'drags'],
#  ['border', 'wall', 'boxing', 'trump'],
#  ['2019', 'want', 'selfimprovement', 'invest', 'adventure'],
#  ['golden', 'globes', 'red', 'carpet', 'retreat'],
#  ['pegi', 'young', '66', 'musician', 'started', 'school', 'disabled', 'dies'],
#  ['middleclass', 'shame', 'decide', 'america', 'headed'],
#  ['portraits', 'regulars', 'place', 'everyone', 'knows', 'nickname'],
#  ['dealbook', 'briefing', 'trump', 'tariffs', 'threaten', 'us', 'jobs'],
#  ['metoo', 'era', 'st', 'patricks', 'group', 'rethinks', 'menonly', 'ritual'],
#  ['different', 'kind', 'comfort', 'food', 'italian', 'chef'],
#  ['howell', 'begle', 'defender', 'rb', 'artists', 'rights', 'dead', '74'],
#  ['chappelles', 'show', 'boondocks', 'kept', 'us', 'laughing', 'r', 'kelly'],
#  ['glenn',
#   'close',
#   'upsets',
#   'lady',
#   'gaga',
#   'taking',
#   'best',
#   'actress',
#   'golden',
#   'globes'],
#  ['fleeing',
#   'saudi',
#   'woman',
#   'facing',
#   'deportation',
#   'allowed',
#   'remain',
#   'thailand'],
#  ['white', 'supremacy', 'genetics', 'dr', 'james', 'watson'],
#  ['boogie', 'bronx', 'girl'],
#  ['eureka', 'moment', 'subway'],
#  ['golden',
#   'globes',
#   '2019',
#   'watch',
#   'roma',
#   'americans',
#   'big',
#   'winners',
#   'nominees'],
#  ['color', 'lady', 'gagas', 'dress', 'golden', 'globes'],
#  ['elizabeth', 'warren', 'party', 'ideas'],
#  ['jerry', 'brown', 'means', 'california'],
#  ['pay', 'writer'],
#  ['joe', 'caselyhayford', 'iconoclastic', 'fashion', 'designer', 'dies', '62'],
#  ['hollywoods', 'obsession', 'cartels'],
#  ['coup', 'attempt', 'gabon', 'thwarted', 'government', 'says'],
#  ['11', 'best', 'weekend', 'reads'],
#  ...]

# %%
keywords_texts = [[word for word in document.lower().split() if word not in stopwords] for document in keywords]

# %%
keywords_texts
# Out:
# [['love',
#   'emotion',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'health',
#   'insurance',
#   'managed',
#   'care',
#   'children',
#   'childhood',
#   'global',
#   'warming'],
#  ['documentary',
#   'films',
#   'programs',
#   'muslims',
#   'islam',
#   'rohingya',
#   'ethnic',
#   'group',
#   'buddhism',
#   'discrimination'],
#  ['yellow',
#   'vests',
#   'movement',
#   'demonstrations',
#   'protests',
#   'riots',
#   'politics',
#   'government'],
#  [],
#  ['art'],
#  ['poetry', 'poets', 'airports'],
#  ['dancing'],
#  ['comedy', 'humor'],
#  ['moon', 'space', 'astronomy'],
#  ['united', 'states', 'politics', 'government'],
#  ['soccer', 'mergers', 'acquisitions', 'divestitures'],
#  ['defense', 'military', 'forces'],
#  ['illegal',
#   'immigration',
#   'identification',
#   'devices',
#   'foreign',
#   'workers',
#   'immigration',
#   'emigration',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['politics',
#   'government',
#   'governors',
#   'us',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['united', 'states', 'politics', 'government'],
#  ['shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'border',
#   'barriers',
#   'government',
#   'employees'],
#  ['railroad',
#   'accidents',
#   'safety',
#   'deaths',
#   'fatalities',
#   'bridges',
#   'tunnels',
#   'rescues'],
#  ['traffic',
#   'accidents',
#   'safety',
#   'deaths',
#   'fatalities',
#   'oil',
#   'petroleum',
#   'gasoline'],
#  [],
#  ['law',
#   'legislation',
#   'pets',
#   'dogs',
#   'cats',
#   'state',
#   'legislatures',
#   'animal',
#   'abuse',
#   'rights',
#   'welfare',
#   'breeding',
#   'animals'],
#  ['movies', 'blacks', 'black', 'people'],
#  ['pop', 'rock', 'music', 'jazz'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'illegal',
#   'immigration',
#   'presidential',
#   'election',
#   '2020',
#   'united',
#   'states',
#   'defense',
#   'military',
#   'forces'],
#  [],
#  ['united',
#   'states',
#   'economy',
#   'recession',
#   'depression',
#   'new',
#   'year',
#   'labor',
#   'jobs',
#   'democracy',
#   'theory',
#   'philosophy',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'veterans',
#   'violence',
#   'women',
#   'act',
#   '1994',
#   'air',
#   'traffic',
#   'control',
#   'national',
#   'parks',
#   'monuments',
#   'seashores',
#   'postal',
#   'service',
#   'post',
#   'offices',
#   'medicare',
#   'food',
#   'aid',
#   'social',
#   'security',
#   'us'],
#  ['elections',
#   'house',
#   'representatives',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'frauds',
#   'swindling',
#   'absentee',
#   'voting'],
#  ['subways', 'transit', 'systems', 'fines', 'penalties'],
#  ['stocks',
#   'bonds',
#   'economic',
#   'conditions',
#   'trends',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'factories',
#   'manufacturing'],
#  ['divorce', 'separations', 'annulments', 'marriages', 'legal', 'profession'],
#  ['moon', 'rocket', 'science', 'propulsion'],
#  ['deaths', 'obituaries', 'pop', 'rock', 'music'],
#  ['united',
#   'states',
#   'defense',
#   'military',
#   'forces',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'appointments',
#   'executive',
#   'changes',
#   'afghanistan',
#   'war',
#   '2001'],
#  ['music',
#   'politics',
#   'government',
#   'political',
#   'advertising',
#   'online',
#   'advertising',
#   'elections',
#   'governors',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'vice',
#   'presidents',
#   'vice',
#   'presidency',
#   'us'],
#  ['smoking', 'tobacco', 'addiction', 'psychology'],
#  ['books', 'literature', 'writing', 'writers'],
#  ['movies', 'actors', 'actresses'],
#  ['movies', 'actors', 'actresses'],
#  ['mergers', 'acquisitions', 'divestitures', 'drugs', 'pharmaceuticals'],
#  ['demonstrations',
#   'protests',
#   'riots',
#   'discrimination',
#   'metoo',
#   'movement',
#   'women',
#   'girls',
#   'sexual',
#   'harassment'],
#  ['meteors', 'meteorites', 'space', 'astronomy'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'political',
#   'action',
#   'committees',
#   'watergate',
#   'affair'],
#  ['embargoes', 'sanctions', 'posters'],
#  ['airlines', 'airplanes', 'budget', 'travel'],
#  ['rain', 'global', 'warming'],
#  ['united', 'states', 'politics', 'government'],
#  [],
#  ['uighurs',
#   'chinese',
#   'ethnic',
#   'group',
#   'political',
#   'prisoners',
#   'human',
#   'rights',
#   'human',
#   'rights',
#   'violations'],
#  ['moon',
#   'space',
#   'astronomy',
#   'solar',
#   'system',
#   'telescopes',
#   'observatories'],
#  ['basketball', 'college', 'basketball'],
#  ['forprofit',
#   'schools',
#   'student',
#   'loans',
#   'colleges',
#   'universities',
#   'consumer',
#   'protection',
#   'attorneys',
#   'general'],
#  ['search',
#   'engines',
#   'computer',
#   'security',
#   'research',
#   'women',
#   'girls',
#   'biographical',
#   'information'],
#  ['movies', 'academy', 'awards', 'oscars'],
#  ['politics', 'government', 'marriages', 'women', 'girls'],
#  ['art'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['letters',
#   'united',
#   'states',
#   'international',
#   'relations',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'nuclear',
#   'weapons'],
#  [],
#  ['heart', 'sjogrens', 'syndrome', 'lungs', 'autoimmune', 'diseases'],
#  ['defectors',
#   'political',
#   'diplomatic',
#   'service',
#   'embassies',
#   'consulates'],
#  [],
#  ['soccer'],
#  ['international', 'relations', 'soccer', 'politics', 'government'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['emotions', 'yourfeedselfcare'],
#  ['united', 'states', 'politics', 'government'],
#  ['movies'],
#  ['movies'],
#  ['baseball', 'free', 'agents', 'sports'],
#  ['deaths',
#   'fatalities',
#   'buildings',
#   'structures',
#   'accidents',
#   'safety',
#   'rescues'],
#  ['books', 'literature', 'poetry', 'poets'],
#  ['politics', 'government', 'redistricting', 'reapportionment'],
#  ['restaurants'],
#  ['presidential',
#   'election',
#   '2020',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'primaries',
#   'caucuses'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'elections',
#   'house',
#   'representatives'],
#  ['parkland', 'fla', 'shooting', '2018'],
#  ['shoes', 'boots', 'fashion', 'apparel', 'shopping', 'retail'],
#  [],
#  ['presidential',
#   'election',
#   '2020',
#   'primaries',
#   'caucuses',
#   'campaign',
#   'finance',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['books', 'literature', 'parenting'],
#  ['family', 'leaves', 'pregnancy', 'childbirth'],
#  ['priests', 'sex', 'crimes', 'child', 'abuse', 'neglect'],
#  ['fashion',
#   'apparel',
#   'pearls',
#   'coats',
#   'jackets',
#   'wool',
#   'woolen',
#   'goods',
#   'knitting',
#   'knit',
#   'goods'],
#  [],
#  ['football', 'playoff', 'games'],
#  ['bathing', 'showering', 'bath', 'salts', 'social', 'media'],
#  ['traffic',
#   'accidents',
#   'safety',
#   'murders',
#   'attempted',
#   'murders',
#   'homicides'],
#  ['new', 'year', 'parties', 'social', 'philanthropy'],
#  ['hotels',
#   'travel',
#   'lodgings',
#   'decisions',
#   'verdicts',
#   'fourth',
#   'amendment',
#   'us',
#   'constitution'],
#  ['arts',
#   'antiquities',
#   'looting',
#   'holocaust',
#   'nazi',
#   'era',
#   'museums',
#   'world',
#   'war',
#   'ii',
#   '193945',
#   'robberies',
#   'thefts'],
#  ['world', 'war', '191418'],
#  ['restaurants'],
#  [],
#  ['politics',
#   'government',
#   'discrimination',
#   'minorities',
#   'constitutions',
#   'race',
#   'ethnicity',
#   'pentecostal',
#   'churches',
#   'demonstrations',
#   'protests',
#   'riots'],
#  ['inaugurations',
#   'speeches',
#   'statements',
#   'immigration',
#   'emigration',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['united',
#   'states',
#   'international',
#   'relations',
#   'espionage',
#   'intelligence',
#   'services'],
#  ['television'],
#  ['football', 'draft', 'recruitment', 'sports'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'illegal',
#   'immigration',
#   'immigration',
#   'emigration',
#   'shutdowns',
#   'institutional',
#   'border',
#   'barriers',
#   'dream',
#   'act',
#   'development',
#   'relief',
#   'education',
#   'minors',
#   'act',
#   'deferred',
#   'action',
#   'childhood',
#   'arrivals'],
#  ['art', 'museums', 'pittsburgh', 'pa', 'shooting', '2018'],
#  ['football',
#   'college',
#   'rose',
#   'bowl',
#   'football',
#   'game',
#   'coaches',
#   'managers'],
#  ['cancer', 'weight', 'esophageal', 'cancer', 'liver', 'cancer'],
#  ['roads', 'traffic'],
#  ['orderliness',
#   'clutter',
#   'procrastination',
#   'psychology',
#   'psychologists',
#   'cortisol',
#   'hormone',
#   'anxiety',
#   'stress'],
#  ['movies'],
#  ['sun', 'earth', 'seasons', 'months'],
#  ['holocaust', 'nazi', 'era'],
#  ['art', 'sculpture'],
#  ['books',
#   'literature',
#   'civil',
#   'war',
#   'us',
#   '186165',
#   'slavery',
#   'historical',
#   'fugitives',
#   'constitution',
#   'us'],
#  ['united',
#   'states',
#   'international',
#   'relations',
#   'espionage',
#   'intelligence',
#   'services'],
#  [],
#  ['graphic', 'novels', 'music', 'blacks', 'black', 'people'],
#  ['space', 'astronomy'],
#  ['united', 'states', 'politics', 'government'],
#  ['politics',
#   'government',
#   'united',
#   'states',
#   'international',
#   'relations',
#   'international',
#   'relations'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['ears', 'hearing'],
#  ['football', 'domestic', 'violence', 'firearms'],
#  [],
#  ['firearms',
#   'second',
#   'amendment',
#   'us',
#   'constitution',
#   'gun',
#   'control',
#   'courts',
#   'judiciary'],
#  ['murders', 'attempted', 'murders', 'homicides'],
#  ['shopping', 'retail', 'deaths', 'obituaries'],
#  ['football', 'social', 'media'],
#  ['initial', 'public', 'offerings', 'stocks', 'bonds'],
#  [],
#  ['impeachment', 'united', 'states', 'politics', 'government'],
#  ['foreign',
#   'students',
#   'us',
#   'colleges',
#   'universities',
#   'education',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'united',
#   'states',
#   'economy',
#   'visas'],
#  ['united',
#   'states',
#   'economy',
#   'economic',
#   'conditions',
#   'trends',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'stocks',
#   'bonds'],
#  ['real',
#   'estate',
#   'housing',
#   'residential',
#   'renting',
#   'leasing',
#   'real',
#   'estate'],
#  ['subways', 'shutdowns', 'institutional', 'transit', 'systems'],
#  ['cancer',
#   'children',
#   'childhood',
#   'hazardous',
#   'toxic',
#   'substances',
#   'chemicals',
#   'regulation',
#   'deregulation',
#   'industry',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  [],
#  ['cholesterol', 'holidays', 'special', 'occasions'],
#  ['children', 'childhood'],
#  ['deaths', 'obituaries', 'wrestling', 'television'],
#  [],
#  [],
#  ['drug', 'cartels'],
#  ['metrocard',
#   'nyc',
#   'prices',
#   'fares',
#   'fees',
#   'rates',
#   'subways',
#   'transit',
#   'systems',
#   'income',
#   'inequality',
#   'poverty'],
#  ['banking', 'financial', 'institutions'],
#  ['shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'federal',
#   'budget',
#   'us'],
#  ['basketball',
#   'college',
#   'draft',
#   'recruitment',
#   'sports',
#   'coaches',
#   'managers'],
#  ['economic',
#   'conditions',
#   'trends',
#   'politics',
#   'government',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'consumer',
#   'behavior'],
#  ['indigenous', 'people', 'land', 'use', 'policies', 'politics', 'government'],
#  ['yourfeedselfcare',
#   'travel',
#   'vacations',
#   'hotels',
#   'travel',
#   'lodgings',
#   'bathrooms',
#   'toilets'],
#  ['middle',
#   'east',
#   'africa',
#   'migrant',
#   'crisis',
#   'refugees',
#   'displaced',
#   'persons',
#   'immigration',
#   'emigration',
#   'wildfires',
#   'citizenship',
#   'naturalization',
#   'rescues',
#   'awards',
#   'decorations',
#   'honors'],
#  ['children', 'childhood', 'emotions'],
#  [],
#  ['movies', 'golden', 'globes', 'awards'],
#  ['exercise', 'calories', 'weight', 'obesity'],
#  ['draft',
#   'recruitment',
#   'military',
#   'united',
#   'states',
#   'defense',
#   'military',
#   'forces',
#   'urban',
#   'areas',
#   'advertising',
#   'marketing'],
#  [],
#  ['labor', 'jobs', 'careers', 'professions', 'hiring', 'promotion'],
#  ['united',
#   'states',
#   'international',
#   'relations',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'nuclear',
#   'weapons',
#   'global',
#   'warming'],
#  ['books', 'literature', 'writing', 'writers'],
#  ['bourbon', 'whiskey', 'whiskey', 'luxury', 'goods', 'services'],
#  ['pop', 'rock', 'music', 'movies'],
#  ['censorship', 'computers', 'internet', 'politics', 'government'],
#  ['subways', 'buses', 'transit', 'systems'],
#  ['marijuana', 'drug', 'abuse', 'traffic', 'black', 'markets', 'taxation'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['chineseamericans',
#   'photography',
#   'politics',
#   'government',
#   'foreign',
#   'workers',
#   'immigration',
#   'emigration',
#   'yourfeedonlyinnewyork'],
#  ['midwives',
#   'doulas',
#   'immigration',
#   'emigration',
#   'foreign',
#   'workers',
#   'translation',
#   'interpreters',
#   'hospitals'],
#  ['immigration',
#   'emigration',
#   'border',
#   'barriers',
#   'illegal',
#   'immigration',
#   'citizenship',
#   'naturalization',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['united', 'states', 'politics', 'government'],
#  ['travel', 'vacations', 'hotels', 'travel', 'lodgings'],
#  [],
#  ['movies'],
#  ['gun',
#   'control',
#   'firearms',
#   'law',
#   'legislation',
#   'school',
#   'shootings',
#   'armed',
#   'attacks',
#   'states',
#   'us',
#   'referendums'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'presidential',
#   'election',
#   '2020',
#   'discrimination'],
#  ['exploration', 'explorers', 'glaciers'],
#  ['customs', 'etiquette', 'manners', 'luxury', 'goods', 'services'],
#  ['baseball', 'free', 'agents', 'sports'],
#  ['attacks',
#   'police',
#   'murders',
#   'attempted',
#   'murders',
#   'homicides',
#   'illegal',
#   'immigration'],
#  [],
#  ['drug',
#   'abuse',
#   'traffic',
#   'prisons',
#   'prisoners',
#   'murders',
#   'attempted',
#   'murders',
#   'homicides'],
#  ['books', 'literature'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['television', 'golden', 'globes', 'awards'],
#  ['iraq', 'war', '200311', 'united', 'states', 'international', 'relations'],
#  ['apartheid', 'policy', 'race', 'ethnicity', 'photography'],
#  [],
#  ['animals', 'movies', 'cats', 'dogs', 'actors', 'actresses'],
#  ['tear',
#   'gas',
#   'immigration',
#   'emigration',
#   'united',
#   'states',
#   'international',
#   'relations'],
#  ['theater'],
#  [],
#  ['computers',
#   'internet',
#   'driverless',
#   'semiautonomous',
#   'vehicles',
#   'wireless',
#   'communications',
#   'computer',
#   'security',
#   'home',
#   'automation',
#   'smart',
#   'homes',
#   'smartphones',
#   'speakers',
#   'audio',
#   'international',
#   'consumer',
#   'electronics',
#   'show',
#   'virtual',
#   'reality',
#   'computers',
#   'innovation'],
#  ['vagina', 'hair', 'sexually', 'transmitted', 'diseases'],
#  ['tango', 'dancing'],
#  ['disasters',
#   'emergencies',
#   'newspapers',
#   'social',
#   'media',
#   'text',
#   'messaging',
#   'hurricanes',
#   'tropical',
#   'storms',
#   'wildfires',
#   'computers',
#   'internet'],
#  ['presidential',
#   'election',
#   '2020',
#   'science',
#   'technology',
#   'social',
#   'media',
#   'income',
#   'inequality',
#   'united',
#   'states',
#   'economy',
#   'wages',
#   'salaries',
#   'labor',
#   'jobs',
#   'new',
#   'year',
#   'conservatism',
#   'us',
#   'politics',
#   'republican',
#   'national',
#   'convention',
#   'comedy',
#   'humor'],
#  ['united', 'states', 'politics', 'government'],
#  ['space', 'astronomy', 'new', 'horizons', 'spacecraft'],
#  ['innovation',
#   'smartphones',
#   'driverless',
#   'semiautonomous',
#   'vehicles',
#   'iphone'],
#  ['palestinians', 'women', 'girls', 'fashion', 'apparel'],
#  ['united', 'states', 'economy', 'stocks', 'bonds', 'recession', 'depression'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['race', 'ethnicity', 'blacks', 'black', 'people', 'crayons'],
#  ['shutdowns',
#   'institutional',
#   'illegal',
#   'immigration',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['smartphones',
#   'iphone',
#   'computer',
#   'chips',
#   'company',
#   'reports',
#   'stocks',
#   'bonds'],
#  ['theater'],
#  ['politics', 'government'],
#  ['theater', 'music', 'dancing', 'spoleto', 'festival', 'usa', 'opera'],
#  ['united', 'states', 'politics', 'government'],
#  ['cooking', 'cookbooks', 'recipes'],
#  ['global', 'warming'],
#  ['new', 'horizons', 'spacecraft', 'space', 'astronomy', 'solar', 'system'],
#  ['correction', 'stories'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'united',
#   'states',
#   'defense',
#   'military',
#   'forces',
#   'united',
#   'states',
#   'international',
#   'relations',
#   'afghanistan',
#   'war',
#   '2001',
#   'iraq',
#   'war',
#   '200311',
#   'appointments',
#   'executive',
#   'changes'],
#  ['crossword', 'puzzles'],
#  ['health', 'insurance', 'managed', 'care'],
#  ['women', 'girls', 'sex', 'education'],
#  ['iphone', 'company', 'reports'],
#  ['diet',
#   'nutrition',
#   'dating',
#   'relationships',
#   'medicine',
#   'health',
#   'yourfeedselfcare',
#   'exercise'],
#  ['movies'],
#  ['crossword', 'puzzles'],
#  ['discrimination',
#   'birth',
#   'control',
#   'family',
#   'planning',
#   'women',
#   'girls',
#   'poverty',
#   'income',
#   'inequality',
#   'sterilization',
#   'reproductive'],
#  ['television', 'movies'],
#  ['television'],
#  ['movies'],
#  ['deaths',
#   'obituaries',
#   'education',
#   'k12',
#   'private',
#   'sectarian',
#   'schools'],
#  ['books', 'literature'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'shutdowns',
#   'institutional',
#   'border',
#   'barriers'],
#  ['assassinations', 'attempted', 'assassinations', 'royal', 'families'],
#  ['movies', 'social', 'media'],
#  [],
#  ['deaths',
#   'obituaries',
#   'blacks',
#   'black',
#   'people',
#   'courts',
#   'judiciary',
#   'state',
#   'legislatures'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'women',
#   'girls',
#   'womens',
#   'rights',
#   'metoo',
#   'movement'],
#  ['deaths', 'obituaries', 'movies'],
#  ['football', 'rugby', 'concussions'],
#  [],
#  ['art', 'museums'],
#  ['pizza', 'barbecue', 'recipes', 'cooking', 'cookbooks'],
#  ['deaths',
#   'obituaries',
#   'holocaust',
#   'nazi',
#   'era',
#   'writing',
#   'writers',
#   'books',
#   'literature',
#   'jews',
#   'judaism'],
#  ['shutdowns',
#   'institutional',
#   'national',
#   'parks',
#   'monuments',
#   'seashores',
#   'museums',
#   'travel',
#   'vacations',
#   'historic',
#   'buildings',
#   'sites',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['photography'],
#  [],
#  ['television', 'metoo', 'movement', 'sexual', 'harassment'],
#  [],
#  ['classical', 'music', 'opera'],
#  ['cooking', 'cookbooks', 'restaurants'],
#  ['actors', 'actresses', 'movies', 'theater'],
#  ['women', 'girls', 'movies'],
#  ['silicone',
#   'plastic',
#   'surgery',
#   'murders',
#   'attempted',
#   'murders',
#   'homicides'],
#  ['pop', 'rock', 'music'],
#  ['assassinations', 'attempted', 'assassinations'],
#  ['football'],
#  ['orderliness', 'clutter', 'reality', 'television'],
#  ['united', 'states', 'politics', 'government', 'law', 'legislation'],
#  ['greenhouse',
#   'gas',
#   'emissions',
#   'global',
#   'warming',
#   'campaign',
#   'finance',
#   'gasoline',
#   'tax',
#   'us',
#   'lobbying',
#   'lobbyists'],
#  ['sexual',
#   'harassment',
#   'women',
#   'girls',
#   'discrimination',
#   'presidential',
#   'election',
#   '2016',
#   'presidential',
#   'election',
#   '2020'],
#  ['fashion', 'apparel', 'shopping', 'retail'],
#  ['theater', 'bathrooms', 'toilets', 'women', 'girls'],
#  ['airport', 'security', 'airports', 'social', 'media', 'luggage', 'packing'],
#  ['deaths',
#   'obituaries',
#   'comedy',
#   'humor',
#   'television',
#   'stunts',
#   'stuntmen'],
#  ['television', 'movies'],
#  ['deaths', 'obituaries', 'pop', 'rock', 'music'],
#  ['movies'],
#  ['electric',
#   'hybrid',
#   'vehicles',
#   'company',
#   'reports',
#   'prices',
#   'fares',
#   'fees',
#   'rates',
#   'factories',
#   'manufacturing'],
#  ['hiring', 'promotion', 'women', 'girls', 'labor', 'jobs'],
#  ['arts', 'antiquities', 'looting', 'museums'],
#  ['ethics',
#   'personal',
#   'social',
#   'media',
#   'divorce',
#   'separations',
#   'annulments',
#   'crowdfunding',
#   'internet'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['movies', 'transgender', 'transsexuals'],
#  ['movies'],
#  ['gifts',
#   'public',
#   'officials',
#   'corruption',
#   'institutional',
#   'bribery',
#   'kickbacks'],
#  ['stocks',
#   'bonds',
#   'united',
#   'states',
#   'economy',
#   'iphone',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['united',
#   'states',
#   'economy',
#   'banking',
#   'financial',
#   'institutions',
#   'united',
#   'states',
#   'international',
#   'relations',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'stocks',
#   'bonds'],
#  ['automobiles', 'speakers', 'audio'],
#  ['politics',
#   'government',
#   'economic',
#   'conditions',
#   'trends',
#   'refugees',
#   'displaced',
#   'persons',
#   'relocation',
#   'business',
#   'immigration',
#   'emigration'],
#  ['book', 'clubs', 'books', 'literature', 'heart'],
#  ['politics', 'government', 'international', 'relations'],
#  ['movies'],
#  ['television'],
#  ['income',
#   'inequality',
#   'presidential',
#   'election',
#   '2020',
#   'labor',
#   'jobs',
#   'wages',
#   'salaries',
#   'united',
#   'states',
#   'economy',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'consumer',
#   'protection'],
#  ['politics',
#   'government',
#   'inaugurations',
#   'defense',
#   'military',
#   'forces',
#   'economic',
#   'conditions',
#   'trends'],
#  ['theater'],
#  ['discrimination',
#   'affirmative',
#   'action',
#   'admissions',
#   'standards',
#   'race',
#   'ethnicity',
#   'minorities',
#   'colleges',
#   'universities'],
#  ['commuting', 'stations', 'terminals', 'passenger', 'budgets', 'budgeting'],
#  ['books', 'literature'],
#  ['subways'],
#  ['moon', 'space', 'astronomy'],
#  [],
#  ['travel', 'vacations'],
#  ['ultimate', 'frisbee', 'athletics', 'sports'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['real', 'estate', 'housing', 'residential'],
#  [],
#  ['real', 'estate', 'housing', 'residential'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['new', 'year', 'parties', 'social'],
#  ['united', 'states', 'politics', 'government'],
#  ['womens',
#   'rights',
#   'women',
#   'girls',
#   'demonstrations',
#   'protests',
#   'riots',
#   'hinduism'],
#  ['crossword', 'puzzles'],
#  ['documentary',
#   'films',
#   'programs',
#   'muslims',
#   'islam',
#   'rohingya',
#   'ethnic',
#   'group',
#   'buddhism',
#   'discrimination'],
#  ['yellow',
#   'vests',
#   'movement',
#   'demonstrations',
#   'protests',
#   'riots',
#   'politics',
#   'government'],
#  ['art'],
#  ['weddings', 'engagements', 'flowers', 'plants', 'marriages'],
#  ['government',
#   'employees',
#   'shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'labor',
#   'jobs',
#   'border',
#   'barriers'],
#  ['subways',
#   'renting',
#   'leasing',
#   'real',
#   'estate',
#   'real',
#   'estate',
#   'housing',
#   'residential',
#   'transit',
#   'systems',
#   'commuting',
#   'yourfeedonlyinnewyork'],
#  ['presidential',
#   'election',
#   '2020',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'primaries',
#   'caucuses',
#   'voting',
#   'voters'],
#  ['poetry', 'poets', 'airports'],
#  ['dancing'],
#  ['comedy', 'humor'],
#  ['theater', 'slavery', 'historical'],
#  ['colon', 'digestive', 'tract', 'diverticulosis', 'antibiotics', 'sepsis'],
#  ['moon', 'space', 'astronomy'],
#  ['illegal',
#   'immigration',
#   'identification',
#   'devices',
#   'foreign',
#   'workers',
#   'immigration',
#   'emigration',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['politics',
#   'government',
#   'governors',
#   'us',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['drug',
#   'abuse',
#   'traffic',
#   'cocaine',
#   'crack',
#   'cocaine',
#   'pregnancy',
#   'childbirth'],
#  ['presidential',
#   'election',
#   '2020',
#   'women',
#   'girls',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['basketball'],
#  ['thai', 'food', 'cuisine', 'restaurants'],
#  ['traffic',
#   'accidents',
#   'safety',
#   'deaths',
#   'fatalities',
#   'oil',
#   'petroleum',
#   'gasoline'],
#  ['books',
#   'literature',
#   'writing',
#   'writers',
#   'book',
#   'trade',
#   'publishing',
#   'metoo',
#   'movement',
#   'sexual',
#   'harassment',
#   'social',
#   'media',
#   'censorship',
#   'magazines'],
#  [],
#  ['movies', 'blacks', 'black', 'people', 'women', 'girls', 'research'],
#  ['marijuana',
#   'mental',
#   'health',
#   'disorders',
#   'drug',
#   'abuse',
#   'traffic',
#   'opioids',
#   'opiates',
#   'cannabis',
#   'foods',
#   'products'],
#  ['pop', 'rock', 'music', 'jazz'],
#  ['blacks', 'black', 'people', 'mortgages', 'millennial', 'generation'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'illegal',
#   'immigration',
#   'presidential',
#   'election',
#   '2020',
#   'united',
#   'states',
#   'defense',
#   'military',
#   'forces'],
#  [],
#  ['united',
#   'states',
#   'economy',
#   'recession',
#   'depression',
#   'new',
#   'year',
#   'labor',
#   'jobs',
#   'democracy',
#   'theory',
#   'philosophy',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['transgender', 'transsexuals', 'men', 'boys', 'books', 'literature'],
#  ['abuse', 'disabled', 'sex', 'crimes'],
#  ['computers',
#   'internet',
#   'smartphones',
#   'iphone',
#   'luxury',
#   'goods',
#   'services'],
#  ['movies',
#   'awards',
#   'decorations',
#   'honors',
#   'academy',
#   'awards',
#   'oscars',
#   'golden',
#   'globes',
#   'awards'],
#  ['books',
#   'literature',
#   'politics',
#   'government',
#   'capitalism',
#   'theory',
#   'philosophy'],
#  ['elections',
#   'house',
#   'representatives',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'frauds',
#   'swindling',
#   'absentee',
#   'voting'],
#  ['elections', 'public', 'advocate', 'campaign', 'finance'],
#  ['hispanicamericans', 'presidential', 'election', '2020'],
#  ['divorce', 'separations', 'annulments', 'marriages', 'legal', 'profession'],
#  ['moon', 'rocket', 'science', 'propulsion'],
#  ['music',
#   'politics',
#   'government',
#   'political',
#   'advertising',
#   'online',
#   'advertising',
#   'elections',
#   'governors',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'vice',
#   'presidents',
#   'vice',
#   'presidency',
#   'us'],
#  ['political',
#   'prisoners',
#   'politics',
#   'government',
#   'uighurs',
#   'chinese',
#   'ethnic',
#   'group',
#   'muslims',
#   'islam'],
#  ['smoking', 'tobacco', 'addiction', 'psychology'],
#  ['books', 'literature', 'writing', 'writers'],
#  ['automobiles',
#   'united',
#   'states',
#   'economy',
#   'factories',
#   'manufacturing',
#   'consumer',
#   'behavior'],
#  ['movies', 'actors', 'actresses'],
#  ['movies', 'actors', 'actresses'],
#  ['demolition', 'bombs', 'explosives', 'yourfeedonlyinnewyork'],
#  ['education',
#   'k12',
#   'teachers',
#   'school',
#   'employees',
#   'real',
#   'estate',
#   'housing',
#   'residential',
#   'affordable',
#   'housing',
#   'gentrification'],
#  ['mergers', 'acquisitions', 'divestitures', 'drugs', 'pharmaceuticals'],
#  ['jews',
#   'judaism',
#   'religion',
#   'belief',
#   'synagogues',
#   'zionism',
#   'palestinians'],
#  ['economic',
#   'conditions',
#   'trends',
#   'banking',
#   'financial',
#   'institutions',
#   'politics',
#   'government'],
#  ['meteors', 'meteorites', 'space', 'astronomy'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'political',
#   'action',
#   'committees',
#   'watergate',
#   'affair'],
#  ['embargoes', 'sanctions', 'posters'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'shutdowns',
#   'institutional',
#   'border',
#   'barriers'],
#  ['prisons',
#   'prisoners',
#   'sexual',
#   'harassment',
#   'prison',
#   'guards',
#   'corrections',
#   'officers',
#   'workplace',
#   'hazards',
#   'violations',
#   'metoo',
#   'movement'],
#  ['airlines', 'airplanes', 'budget', 'travel'],
#  ['united',
#   'states',
#   'economy',
#   'economic',
#   'conditions',
#   'trends',
#   'labor',
#   'jobs',
#   'united',
#   'states',
#   'international',
#   'relations'],
#  ['rain', 'global', 'warming'],
#  ['subways'],
#  ['united', 'states', 'politics', 'government'],
#  ['impeachment',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'russian',
#   'interference',
#   '2016',
#   'us',
#   'elections',
#   'ties',
#   'trump',
#   'associates'],
#  ['moon',
#   'space',
#   'astronomy',
#   'solar',
#   'system',
#   'telescopes',
#   'observatories'],
#  ['basketball', 'college', 'basketball'],
#  ['baseball', 'coaches', 'managers'],
#  ['forprofit',
#   'schools',
#   'student',
#   'loans',
#   'colleges',
#   'universities',
#   'consumer',
#   'protection',
#   'attorneys',
#   'general'],
#  ['ethics', 'personal', 'psychology', 'psychologists', 'social', 'media'],
#  ['television', 'movies', 'innovation'],
#  ['movies', 'academy', 'awards', 'oscars'],
#  ['apples', 'photography'],
#  [],
#  ['art'],
#  ['defense',
#   'military',
#   'forces',
#   'draft',
#   'recruitment',
#   'military',
#   'advertising',
#   'marketing',
#   'millennial',
#   'generation',
#   'labor',
#   'jobs'],
#  ['letters',
#   'united',
#   'states',
#   'international',
#   'relations',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'nuclear',
#   'weapons'],
#  [],
#  ['afghanistan',
#   'war',
#   '2001',
#   'defense',
#   'military',
#   'forces',
#   'international',
#   'relations',
#   'united',
#   'states',
#   'international',
#   'relations'],
#  ['defectors',
#   'political',
#   'diplomatic',
#   'service',
#   'embassies',
#   'consulates'],
#  ['elections', 'senate'],
#  ['elderly', 'nursing', 'homes'],
#  ['federal',
#   'budget',
#   'us',
#   'national',
#   'debt',
#   'us',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'shutdowns',
#   'institutional',
#   'illegal',
#   'immigration',
#   'immigration',
#   'emigration',
#   'government',
#   'employees'],
#  ['books', 'literature'],
#  ['design'],
#  ['metoo',
#   'movement',
#   'sexual',
#   'harassment',
#   'womens',
#   'rights',
#   'social',
#   'media'],
#  ['international', 'relations', 'soccer', 'politics', 'government'],
#  ['prices',
#   'fares',
#   'fees',
#   'rates',
#   'metrocard',
#   'nyc',
#   'income',
#   'inequality',
#   'poverty',
#   'subways',
#   'buses'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['pop', 'rock', 'music'],
#  ['united', 'states', 'politics', 'government'],
#  ['movies'],
#  ['movies'],
#  ['baseball', 'free', 'agents', 'sports'],
#  ['espionage',
#   'intelligence',
#   'services',
#   'united',
#   'states',
#   'international',
#   'relations',
#   'classified',
#   'information',
#   'state',
#   'secrets',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['stocks',
#   'bonds',
#   'united',
#   'states',
#   'economy',
#   'recession',
#   'depression',
#   'interest',
#   'rates'],
#  [],
#  ['restaurants'],
#  ['presidential',
#   'election',
#   '2016',
#   'russian',
#   'interference',
#   '2016',
#   'us',
#   'elections',
#   'ties',
#   'trump',
#   'associates',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'campaign',
#   'finance',
#   'conflicts',
#   'interest',
#   'constitution',
#   'us',
#   'personal',
#   'finances',
#   'corruption',
#   'institutional',
#   'watergate',
#   'affair',
#   'presidents',
#   'presidency',
#   'us',
#   'impeachment',
#   'lying',
#   'gifts',
#   'public',
#   'officials'],
#  ['united', 'states', 'politics', 'government'],
#  ['classical', 'music', 'meditation'],
#  ['child',
#   'abuse',
#   'neglect',
#   'government',
#   'contracts',
#   'procurement',
#   'immigration',
#   'emigration',
#   'illegal',
#   'immigration',
#   'fingerprinting',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'nonprofit',
#   'organizations',
#   'refugees',
#   'displaced',
#   'persons'],
#  ['united',
#   'states',
#   'economy',
#   'interest',
#   'rates',
#   'labor',
#   'jobs',
#   'inflation',
#   'economics',
#   'stocks',
#   'bonds'],
#  ['united', 'states', 'defense', 'military', 'forces', 'bread'],
#  ['basketball', 'politics', 'government'],
#  ['luggage',
#   'packing',
#   'travel',
#   'vacations',
#   'airlines',
#   'airplanes',
#   'yourfeedwirecutter'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'law',
#   'legislation',
#   'campaign',
#   'finance',
#   'elections',
#   'house',
#   'representatives',
#   'voting',
#   'rights',
#   'act',
#   '1965',
#   'redistricting',
#   'reapportionment',
#   'ethics',
#   'official',
#   'misconduct'],
#  ['defense',
#   'military',
#   'forces',
#   'politics',
#   'government',
#   'television',
#   'news',
#   'news',
#   'media'],
#  ['las',
#   'vegas',
#   'nev',
#   'shooting',
#   'october',
#   '2017',
#   'thousand',
#   'oaks',
#   'calif',
#   'shooting',
#   '2018',
#   'terrorism'],
#  ['sleep', 'insomnia', 'dreams'],
#  ['priests', 'sex', 'crimes', 'child', 'abuse', 'neglect'],
#  ['fashion',
#   'apparel',
#   'pearls',
#   'coats',
#   'jackets',
#   'wool',
#   'woolen',
#   'goods',
#   'knitting',
#   'knit',
#   'goods'],
#  [],
#  ['united',
#   'states',
#   'international',
#   'relations',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'assassinations',
#   'attempted',
#   'assassinations',
#   'human',
#   'rights',
#   'human',
#   'rights',
#   'violations'],
#  ['football', 'playoff', 'games'],
#  ['traffic',
#   'accidents',
#   'safety',
#   'murders',
#   'attempted',
#   'murders',
#   'homicides'],
#  ['pop', 'rock', 'music', 'rap', 'hiphop', 'jazz'],
#  ['classical', 'music'],
#  ['sexual', 'harassment', 'metoo', 'movement', 'art', 'magazines'],
#  ['hurricane',
#   'florence',
#   '2018',
#   'floods',
#   'drownings',
#   'mental',
#   'health',
#   'disorders',
#   'police',
#   'brutality',
#   'misconduct',
#   'shootings'],
#  [],
#  ['hotels',
#   'travel',
#   'lodgings',
#   'decisions',
#   'verdicts',
#   'fourth',
#   'amendment',
#   'us',
#   'constitution'],
#  ['politics', 'government', 'cyberattacks', 'hackers'],
#  ['world', 'war', '191418'],
#  ['restaurants'],
#  ['travel', 'vacations', 'scotch', 'whiskey'],
#  ['animal',
#   'abuse',
#   'rights',
#   'welfare',
#   'muslims',
#   'islam',
#   'jews',
#   'judaism',
#   'halal',
#   'foods',
#   'products',
#   'freedom',
#   'religion',
#   'discrimination'],
#  ['politics', 'government', 'elections'],
#  [],
#  ['weddings', 'engagements'],
#  ['two', 'thousand', 'eighteen', 'poverty', 'population'],
#  ['civilian', 'casualties', 'afghanistan', 'war', '2001'],
#  ['united',
#   'states',
#   'economy',
#   'labor',
#   'jobs',
#   'interest',
#   'rates',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'consumer',
#   'confidence',
#   'economic',
#   'indicator'],
#  ['politics',
#   'government',
#   'discrimination',
#   'minorities',
#   'constitutions',
#   'race',
#   'ethnicity',
#   'pentecostal',
#   'churches',
#   'demonstrations',
#   'protests',
#   'riots'],
#  ['united',
#   'states',
#   'international',
#   'relations',
#   'espionage',
#   'intelligence',
#   'services'],
#  ['crossword', 'puzzles'],
#  ['television'],
#  ['football', 'draft', 'recruitment', 'sports'],
#  ['drug', 'abuse', 'traffic'],
#  ['hockey', 'ice'],
#  ['basketball', 'sports', 'injuries'],
#  ['abortion', 'law', 'legislation', 'referendums'],
#  ['dancing', 'race', 'ethnicity'],
#  ['music'],
#  ['news', 'news', 'media', 'united', 'states', 'politics', 'government'],
#  ['smartphones',
#   'computers',
#   'internet',
#   'iphone',
#   'android',
#   'operating',
#   'system',
#   'mobile',
#   'commerce',
#   'payments'],
#  ['shutdowns',
#   'institutional',
#   'border',
#   'barriers',
#   'illegal',
#   'immigration',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['books', 'literature', 'beer', 'small', 'business'],
#  ['deaths', 'obituaries', 'movies'],
#  ['academy',
#   'awards',
#   'oscars',
#   'television',
#   'movies',
#   'homosexuality',
#   'bisexuality'],
#  ['roads', 'traffic'],
#  ['orderliness',
#   'clutter',
#   'procrastination',
#   'psychology',
#   'psychologists',
#   'cortisol',
#   'hormone',
#   'anxiety',
#   'stress'],
#  ['books', 'literature', 'children', 'childhood'],
#  ['holocaust', 'nazi', 'era'],
#  ['art', 'sculpture'],
#  ['united', 'states', 'politics', 'government'],
#  ['food', 'allergies'],
#  ['united',
#   'states',
#   'international',
#   'relations',
#   'espionage',
#   'intelligence',
#   'services'],
#  ['witnesses',
#   'false',
#   'arrests',
#   'convictions',
#   'imprisonments',
#   'crime',
#   'criminals',
#   'mug',
#   'shots'],
#  ['football',
#   'college',
#   'rose',
#   'bowl',
#   'football',
#   'game',
#   'college',
#   'football',
#   'playoff',
#   'national',
#   'championship'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['ears', 'hearing'],
#  ['ice',
#   'skating',
#   'women',
#   'girls',
#   'figure',
#   'skating',
#   'yourfeedphotojournalism',
#   'yourfeedonlyinnewyork'],
#  ['football', 'domestic', 'violence', 'firearms'],
#  ['firearms',
#   'second',
#   'amendment',
#   'us',
#   'constitution',
#   'gun',
#   'control',
#   'courts',
#   'judiciary'],
#  ['shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'research',
#   'science',
#   'technology'],
#  ['books', 'literature', 'united', 'states', 'politics', 'government'],
#  ['shopping', 'retail', 'deaths', 'obituaries'],
#  ['books', 'literature'],
#  ['football', 'social', 'media'],
#  [],
#  ['shutdowns', 'institutional'],
#  ['murders', 'attempted', 'murders', 'homicides', 'bowling'],
#  ['impeachment', 'united', 'states', 'politics', 'government'],
#  ['crossword',
#   'puzzles',
#   'design',
#   'puzzles',
#   'tests',
#   'examinations',
#   'innovation'],
#  ['foreign',
#   'students',
#   'us',
#   'colleges',
#   'universities',
#   'education',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'united',
#   'states',
#   'economy',
#   'visas'],
#  ['deaths',
#   'obituaries',
#   'airlines',
#   'airplanes',
#   'prices',
#   'fares',
#   'fees',
#   'rates'],
#  ['united',
#   'states',
#   'economy',
#   'economic',
#   'conditions',
#   'trends',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'stocks',
#   'bonds'],
#  ['real',
#   'estate',
#   'housing',
#   'residential',
#   'renting',
#   'leasing',
#   'real',
#   'estate'],
#  ['arabic', 'language', 'education', 'k12', 'muslims', 'islam', 'mosques'],
#  ['deaths',
#   'obituaries',
#   'holocaust',
#   'nazi',
#   'era',
#   'world',
#   'war',
#   'ii',
#   '193945',
#   'rescues',
#   'children',
#   'childhood'],
#  ['books', 'literature'],
#  ['subways', 'shutdowns', 'institutional', 'transit', 'systems'],
#  ['amnesties', 'commutations', 'pardons', 'prostitution'],
#  ['elderly', 'nursing', 'homes'],
#  ['children', 'childhood'],
#  ['politics', 'government'],
#  ['stocks',
#   'bonds',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'economic',
#   'conditions',
#   'trends',
#   'united',
#   'states',
#   'international',
#   'relations'],
#  [],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'veterans',
#   'september',
#   '11',
#   '2001'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'wages',
#   'salaries',
#   'shutdowns',
#   'institutional',
#   'government',
#   'employees'],
#  ['racewalking',
#   'marriages',
#   'age',
#   'chronological',
#   'records',
#   'achievements'],
#  ['dancing', 'women', 'girls', 'prostitution', 'muslims', 'islam'],
#  [],
#  ['deaths', 'obituaries', 'pop', 'rock', 'music', 'women', 'girls'],
#  ['drug', 'cartels'],
#  ['metrocard',
#   'nyc',
#   'prices',
#   'fares',
#   'fees',
#   'rates',
#   'subways',
#   'transit',
#   'systems',
#   'income',
#   'inequality',
#   'poverty'],
#  ['executive', 'compensation', 'automobiles', 'courts', 'judiciary'],
#  ['datamining',
#   'database',
#   'marketing',
#   'mobile',
#   'applications',
#   'weather',
#   'consumer',
#   'protection',
#   'suits',
#   'litigation',
#   'civil',
#   'privacy',
#   'advertising',
#   'marketing'],
#  ['native',
#   'americans',
#   'discrimination',
#   'education',
#   'k12',
#   'school',
#   'discipline',
#   'students',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'civil',
#   'rights',
#   'liberties'],
#  ['basketball',
#   'college',
#   'draft',
#   'recruitment',
#   'sports',
#   'coaches',
#   'managers'],
#  ['women', 'girls', 'metoo', 'movement'],
#  ['economic',
#   'conditions',
#   'trends',
#   'politics',
#   'government',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'consumer',
#   'behavior'],
#  ['ios',
#   'operating',
#   'system',
#   'smartphones',
#   'iphone',
#   'consumer',
#   'behavior'],
#  ['russian',
#   'interference',
#   '2016',
#   'us',
#   'elections',
#   'ties',
#   'trump',
#   'associates',
#   'special',
#   'prosecutors',
#   'independent',
#   'counsel',
#   'presidential',
#   'election',
#   '2016',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['middle',
#   'east',
#   'africa',
#   'migrant',
#   'crisis',
#   'refugees',
#   'displaced',
#   'persons',
#   'immigration',
#   'emigration',
#   'wildfires',
#   'citizenship',
#   'naturalization',
#   'rescues',
#   'awards',
#   'decorations',
#   'honors'],
#  ['children', 'childhood', 'emotions'],
#  [],
#  ['crossword', 'puzzles'],
#  ['shutdowns', 'institutional', 'united', 'states', 'politics', 'government'],
#  ['art'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'elections',
#   'house',
#   'representatives',
#   'immigration',
#   'emigration',
#   'border',
#   'barriers'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'united',
#   'states',
#   'defense',
#   'military',
#   'forces',
#   'constitution',
#   'us',
#   'immigration',
#   'emigration',
#   'border',
#   'barriers',
#   'illegal',
#   'immigration'],
#  ['water', 'pollution', 'waste', 'materials', 'disposal', 'plastics'],
#  ['cooking', 'cookbooks', 'vegetables', 'grain', 'broccoli'],
#  ['football',
#   'college',
#   'college',
#   'football',
#   'playoff',
#   'national',
#   'championship'],
#  ['football', 'college', 'colleges', 'universities', 'football'],
#  [],
#  ['international',
#   'relations',
#   'speeches',
#   'statements',
#   'politics',
#   'government'],
#  ['new',
#   'year',
#   'seasons',
#   'months',
#   'gardens',
#   'gardening',
#   'flowers',
#   'plants',
#   'birds'],
#  ['documentary',
#   'films',
#   'programs',
#   'sex',
#   'crimes',
#   'women',
#   'girls',
#   'discrimination',
#   'music',
#   'blacks',
#   'black',
#   'people'],
#  ['wildfires',
#   'electric',
#   'light',
#   'power',
#   'politics',
#   'government',
#   'state',
#   'legislatures',
#   'campaign',
#   'finance',
#   'lobbying',
#   'lobbyists'],
#  ['television'],
#  ['crickets',
#   'biology',
#   'biochemistry',
#   'diplomatic',
#   'service',
#   'embassies',
#   'consulates',
#   'brain',
#   'acoustics'],
#  ['shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'government',
#   'employees'],
#  ['books', 'literature', 'writing', 'writers'],
#  ['state', 'legislatures', 'alcohol', 'abuse', 'therapy', 'rehabilitation'],
#  ['real',
#   'estate',
#   'housing',
#   'residential',
#   'threeoneone',
#   '311',
#   'nyc',
#   'hot',
#   'line',
#   'noise'],
#  ['ecommerce',
#   'ebooks',
#   'readers',
#   'amazon',
#   'kindle',
#   'customer',
#   'relations',
#   'organized',
#   'labor',
#   'antitrust',
#   'laws',
#   'competition',
#   'issues'],
#  ['subways', 'buses', 'transit', 'systems'],
#  ['movies', 'television'],
#  ['soccer'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['wages', 'salaries', 'minimum', 'wage', 'labor', 'jobs'],
#  ['social', 'media', 'video', 'recordings', 'downloads', 'streaming'],
#  ['politics', 'government', 'social', 'media'],
#  ['yellow',
#   'vests',
#   'movement',
#   'demonstrations',
#   'protests',
#   'riots',
#   'politics',
#   'government',
#   'taxation'],
#  ['books', 'literature'],
#  ['immigration',
#   'emigration',
#   'border',
#   'barriers',
#   'illegal',
#   'immigration',
#   'citizenship',
#   'naturalization',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['united', 'states', 'politics', 'government'],
#  ['travel', 'vacations', 'hotels', 'travel', 'lodgings'],
#  [],
#  ['dogs'],
#  ['united', 'states', 'politics', 'government', 'shutdowns', 'institutional'],
#  ['minorities',
#   'discrimination',
#   'fair',
#   'housing',
#   'act',
#   '1968',
#   'real',
#   'estate',
#   'housing',
#   'residential',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'civil',
#   'rights',
#   'liberties'],
#  ['immigration',
#   'emigration',
#   'politics',
#   'government',
#   'polls',
#   'public',
#   'opinion',
#   'voting',
#   'voters',
#   'shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['movies'],
#  ['tennis', 'hopman', 'cup', 'tennis'],
#  [],
#  ['shutdowns',
#   'institutional',
#   'illegal',
#   'immigration',
#   'courts',
#   'judiciary',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'border',
#   'barriers'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'presidential',
#   'election',
#   '2020',
#   'discrimination'],
#  ['deaths', 'obituaries', 'pop', 'rock', 'music'],
#  ['exploration', 'explorers', 'glaciers'],
#  ['customs', 'etiquette', 'manners', 'luxury', 'goods', 'services'],
#  ['television', 'movies'],
#  ['classical', 'music'],
#  ['jazz'],
#  ['allergies', 'asthma', 'seafood', 'proteins'],
#  ['attacks',
#   'police',
#   'murders',
#   'attempted',
#   'murders',
#   'homicides',
#   'illegal',
#   'immigration'],
#  [],
#  ['united',
#   'states',
#   'economy',
#   'income',
#   'tax',
#   'income',
#   'inequality',
#   'economics',
#   'theory',
#   'philosophy',
#   'high',
#   'net',
#   'worth',
#   'individuals',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['drug',
#   'abuse',
#   'traffic',
#   'prisons',
#   'prisoners',
#   'murders',
#   'attempted',
#   'murders',
#   'homicides'],
#  ['united',
#   'states',
#   'economy',
#   'interest',
#   'rates',
#   'inflation',
#   'economics'],
#  ['yoga'],
#  ['books', 'literature'],
#  ['nuclear',
#   'weapons',
#   'nuclear',
#   'tests',
#   'embargoes',
#   'sanctions',
#   'satellites',
#   'united',
#   'states',
#   'international',
#   'relations',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'missiles',
#   'missile',
#   'defense',
#   'systems'],
#  [],
#  ['jews', 'judaism', 'palestinians'],
#  ['russian',
#   'interference',
#   '2016',
#   'us',
#   'elections',
#   'ties',
#   'trump',
#   'associates',
#   'embargoes',
#   'sanctions',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'presidential',
#   'election',
#   '2016'],
#  ['subways',
#   'transit',
#   'systems',
#   'bridges',
#   'tunnels',
#   'yourfeedonlyinnewyork'],
#  ['television', 'golden', 'globes', 'awards'],
#  ['running', 'exercise', 'new', 'year', 'sneakers'],
#  ['apartheid', 'policy', 'race', 'ethnicity', 'photography'],
#  [],
#  [],
#  ['united', 'states', 'international', 'relations'],
#  ['wearable',
#   'computing',
#   'smartphones',
#   'iphone',
#   'company',
#   'reports',
#   'customs',
#   'tariff',
#   'innovation',
#   'international',
#   'trade',
#   'world',
#   'market'],
#  ['tear',
#   'gas',
#   'immigration',
#   'emigration',
#   'united',
#   'states',
#   'international',
#   'relations'],
#  ['poetry', 'poets'],
#  [],
#  ['computers',
#   'internet',
#   'driverless',
#   'semiautonomous',
#   'vehicles',
#   'wireless',
#   'communications',
#   'computer',
#   'security',
#   'home',
#   'automation',
#   'smart',
#   'homes',
#   'smartphones',
#   'speakers',
#   'audio',
#   'international',
#   'consumer',
#   'electronics',
#   'show',
#   'virtual',
#   'reality',
#   'computers',
#   'innovation'],
#  ['vagina', 'hair', 'sexually', 'transmitted', 'diseases'],
#  ['tango', 'dancing'],
#  ['aztecs', 'archaeology', 'anthropology'],
#  ['books', 'literature'],
#  ['fossils',
#   'mammals',
#   'dinosaurs',
#   'paleontology',
#   'endangered',
#   'extinct',
#   'species'],
#  ['immigration',
#   'emigration',
#   'immigration',
#   'detention',
#   'asylum',
#   'right',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['movies'],
#  ['presidential',
#   'election',
#   '2020',
#   'science',
#   'technology',
#   'social',
#   'media',
#   'income',
#   'inequality',
#   'united',
#   'states',
#   'economy',
#   'wages',
#   'salaries',
#   'labor',
#   'jobs',
#   'new',
#   'year',
#   'conservatism',
#   'us',
#   'politics',
#   'republican',
#   'national',
#   'convention',
#   'comedy',
#   'humor'],
#  ['united', 'states', 'politics', 'government'],
#  ['golf'],
#  ['space', 'astronomy', 'new', 'horizons', 'spacecraft'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'forests',
#   'forestry',
#   'north',
#   'american',
#   'free',
#   'trade',
#   'agreement',
#   'logging',
#   'industry'],
#  ['redistricting',
#   'reapportionment',
#   'constitution',
#   'us',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['innovation',
#   'smartphones',
#   'driverless',
#   'semiautonomous',
#   'vehicles',
#   'iphone'],
#  ['palestinians', 'women', 'girls', 'fashion', 'apparel'],
#  ['united', 'states', 'economy', 'stocks', 'bonds', 'recession', 'depression'],
#  [],
#  ['television', 'united', 'states', 'politics', 'government'],
#  ['airport',
#   'security',
#   'shutdowns',
#   'institutional',
#   'airports',
#   'labor',
#   'jobs'],
#  ['government',
#   'employees',
#   'banking',
#   'financial',
#   'institutions',
#   'customer',
#   'relations',
#   'credit',
#   'unions',
#   'personal',
#   'finances',
#   'shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['maritime',
#   'accidents',
#   'safety',
#   'ships',
#   'shipping',
#   'freight',
#   'cargo',
#   'hazardous',
#   'toxic',
#   'substances'],
#  ['race', 'ethnicity', 'blacks', 'black', 'people', 'crayons'],
#  ['passports',
#   'cyberwarfare',
#   'defense',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'hotels',
#   'travel',
#   'lodgings'],
#  ['shutdowns',
#   'institutional',
#   'illegal',
#   'immigration',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['smartphones',
#   'iphone',
#   'computer',
#   'chips',
#   'company',
#   'reports',
#   'stocks',
#   'bonds'],
#  ['great', 'britain', 'withdrawal', 'eu', 'brexit'],
#  ['theater'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'primaries',
#   'caucuses',
#   'presidential',
#   'election',
#   '2020',
#   'liberalism',
#   'us',
#   'politics',
#   'united',
#   'states',
#   'economy'],
#  ['great',
#   'britain',
#   'withdrawal',
#   'eu',
#   'brexit',
#   'international',
#   'trade',
#   'world',
#   'market'],
# ...
#   'drug',
#   'abuse',
#   'traffic'],
#  [],
#  ['weddings', 'engagements'],
#  ['witnesses',
#   'false',
#   'arrests',
#   'convictions',
#   'imprisonments',
#   'crime',
#   'criminals',
#   'mug',
#   'shots'],
#  [],
#  ['ice',
#   'skating',
#   'women',
#   'girls',
#   'figure',
#   'skating',
#   'yourfeedphotojournalism',
#   'yourfeedonlyinnewyork'],
#  ['tea', 'cooking', 'cookbooks'],
#  ['fashion',
#   'apparel',
#   'coats',
#   'jackets',
#   'mens',
#   'fashion',
#   'week',
#   'london',
#   'fashion',
#   'week',
#   'fashion',
#   'shows',
#   'yourfeedfashion'],
#  ['divorce',
#   'separations',
#   'annulments',
#   'women',
#   'girls',
#   'social',
#   'conditions',
#   'trends',
#   'womens',
#   'rights',
#   'marriages',
#   'families',
#   'family',
#   'life'],
#  ['inaugurations', 'budgets', 'budgeting', 'governors', 'us'],
#  ['shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'research',
#   'science',
#   'technology'],
#  ['biotechnology',
#   'bioengineering',
#   'genetics',
#   'heredity',
#   'inventions',
#   'patents',
#   'deaths',
#   'obituaries'],
#  [],
#  ['united',
#   'states',
#   'defense',
#   'military',
#   'forces',
#   'civilian',
#   'casualties',
#   'ethics',
#   'official',
#   'misconduct'],
#  ['presidential',
#   'election',
#   '2020',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'voting',
#   'voters',
#   'primaries',
#   'caucuses'],
#  ['shutdowns', 'institutional'],
#  ['terrorism',
#   'defense',
#   'military',
#   'forces',
#   'united',
#   'states',
#   'international',
#   'relations'],
#  ['murders', 'attempted', 'murders', 'homicides', 'bowling'],
#  ['crossword',
#   'puzzles',
#   'design',
#   'puzzles',
#   'tests',
#   'examinations',
#   'innovation'],
#  ['surgery', 'surgeons'],
#  ['amnesties',
#   'commutations',
#   'pardons',
#   'murders',
#   'attempted',
#   'murders',
#   'homicides',
#   'probation',
#   'parole'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'shutdowns',
#   'institutional',
#   'presidential',
#   'election',
#   '2020'],
#  ['united', 'states', 'politics', 'government'],
#  ['arabic', 'language', 'education', 'k12', 'muslims', 'islam', 'mosques'],
#  ['theater', 'actors', 'actresses'],
#  [],
#  [],
#  ['memory'],
#  ['golden', 'globes', 'awards', 'movies', 'television', 'actors', 'actresses'],
#  ['baseball'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'wages',
#   'salaries',
#   'shutdowns',
#   'institutional',
#   'government',
#   'employees'],
#  ['dancing', 'women', 'girls', 'prostitution', 'muslims', 'islam'],
#  ['wills',
#   'estates',
#   'gun',
#   'control',
#   'las',
#   'vegas',
#   'nev',
#   'shooting',
#   'october',
#   '2017'],
#  ['deaths', 'obituaries', 'actors', 'actresses', 'movies'],
#  ['presidential',
#   'election',
#   '2020',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'border',
#   'barriers',
#   'federal',
#   'budget',
#   'us'],
#  ['drugs',
#   'pharmaceuticals',
#   'conflicts',
#   'interest',
#   'cancer',
#   'appointments',
#   'executive',
#   'changes'],
#  ['law',
#   'legislation',
#   'privacy',
#   'social',
#   'media',
#   'computers',
#   'internet',
#   'suits',
#   'litigation',
#   'civil'],
#  ['ios',
#   'operating',
#   'system',
#   'smartphones',
#   'iphone',
#   'consumer',
#   'behavior'],
#  ['russian',
#   'interference',
#   '2016',
#   'us',
#   'elections',
#   'ties',
#   'trump',
#   'associates',
#   'special',
#   'prosecutors',
#   'independent',
#   'counsel',
#   'presidential',
#   'election',
#   '2016',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  [],
#  ['crossword', 'puzzles'],
#  ['space',
#   'astronomy',
#   'stars',
#   'galaxies',
#   'extraterrestrial',
#   'life',
#   'planets',
#   'transiting',
#   'exoplanet',
#   'survey',
#   'satellite',
#   'spacecraft',
#   'telescopes',
#   'observatories'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'elections',
#   'house',
#   'representatives',
#   'immigration',
#   'emigration',
#   'border',
#   'barriers'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'united',
#   'states',
#   'defense',
#   'military',
#   'forces',
#   'constitution',
#   'us',
#   'immigration',
#   'emigration',
#   'border',
#   'barriers',
#   'illegal',
#   'immigration'],
#  ['football', 'playoff', 'games'],
#  ['international',
#   'relations',
#   'speeches',
#   'statements',
#   'politics',
#   'government'],
#  ['new',
#   'year',
#   'seasons',
#   'months',
#   'gardens',
#   'gardening',
#   'flowers',
#   'plants',
#   'birds'],
#  ['documentary',
#   'films',
#   'programs',
#   'sex',
#   'crimes',
#   'women',
#   'girls',
#   'discrimination',
#   'music',
#   'blacks',
#   'black',
#   'people'],
#  ['wildfires',
#   'electric',
#   'light',
#   'power',
#   'politics',
#   'government',
#   'state',
#   'legislatures',
#   'campaign',
#   'finance',
#   'lobbying',
#   'lobbyists'],
#  ['shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'government',
#   'employees'],
#  ['suits',
#   'litigation',
#   'civil',
#   'libel',
#   'slander',
#   'freedom',
#   'speech',
#   'expression',
#   'first',
#   'amendment',
#   'us',
#   'constitution'],
#  ['restaurants'],
#  ['real',
#   'estate',
#   'housing',
#   'residential',
#   'threeoneone',
#   '311',
#   'nyc',
#   'hot',
#   'line',
#   'noise'],
#  ['deaths', 'obituaries', 'writing', 'writers', 'books', 'literature'],
#  ['movies', 'television'],
#  ['college',
#   'football',
#   'playoff',
#   'national',
#   'championship',
#   'football',
#   'college',
#   'bowl',
#   'games'],
#  ['yellow',
#   'vests',
#   'movement',
#   'demonstrations',
#   'protests',
#   'riots',
#   'politics',
#   'government',
#   'taxation'],
#  ['television', 'movies'],
#  ['health', 'insurance', 'managed', 'care', 'medicine', 'health'],
#  ['minorities',
#   'discrimination',
#   'fair',
#   'housing',
#   'act',
#   '1968',
#   'real',
#   'estate',
#   'housing',
#   'residential',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'civil',
#   'rights',
#   'liberties'],
#  ['immigration',
#   'emigration',
#   'politics',
#   'government',
#   'polls',
#   'public',
#   'opinion',
#   'voting',
#   'voters',
#   'shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['presidential',
#   'election',
#   '2020',
#   'midterm',
#   'elections',
#   '2018',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'polls',
#   'public',
#   'opinion',
#   'voting',
#   'voters',
#   'elections',
#   'senate',
#   'states',
#   'us',
#   'shutdowns',
#   'institutional'],
#  ['tennis', 'hopman', 'cup', 'tennis'],
#  ['cheese', 'wines'],
#  ['shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'border',
#   'barriers'],
#  [],
#  ['war',
#   'emergency',
#   'powers',
#   'us',
#   'border',
#   'barriers',
#   'law',
#   'legislation',
#   'shutdowns',
#   'institutional',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'immigration',
#   'emigration',
#   'presidents',
#   'presidency',
#   'us',
#   'disasters',
#   'emergencies'],
#  ['fashion', 'apparel', 'magazines', 'deaths', 'obituaries'],
#  ['education',
#   'k12',
#   'private',
#   'sectarian',
#   'schools',
#   'organized',
#   'labor',
#   'teachers',
#   'school',
#   'employees'],
#  ['tests',
#   'medical',
#   'genetics',
#   'heredity',
#   'dna',
#   'deoxyribonucleic',
#   'acid',
#   'research',
#   'meningitis',
#   'pain'],
#  ['allergies', 'asthma', 'seafood', 'proteins'],
#  ['united',
#   'states',
#   'economy',
#   'income',
#   'tax',
#   'income',
#   'inequality',
#   'economics',
#   'theory',
#   'philosophy',
#   'high',
#   'net',
#   'worth',
#   'individuals',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['whales',
#   'whaling',
#   'animal',
#   'behavior',
#   'research',
#   'music',
#   'acoustics',
#   'oceans',
#   'seas'],
#  ['music', 'opera'],
#  ['books', 'literature'],
#  ['jews', 'judaism', 'palestinians'],
#  ['russian',
#   'interference',
#   '2016',
#   'us',
#   'elections',
#   'ties',
#   'trump',
#   'associates',
#   'embargoes',
#   'sanctions',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'presidential',
#   'election',
#   '2016'],
#  ['real', 'estate', 'housing', 'residential'],
#  ['running', 'exercise', 'new', 'year', 'sneakers'],
#  ['freedom', 'speech', 'expression', 'censorship'],
#  ['employee',
#   'fringe',
#   'benefits',
#   'food',
#   'cafeterias',
#   'snack',
#   'foods',
#   'workplace',
#   'environment',
#   'health',
#   'foods'],
#  [],
#  ['golden', 'globes', 'awards', 'actors', 'actresses', 'movies'],
#  ['escape',
#   'room',
#   'game',
#   'fires',
#   'firefighters',
#   'deaths',
#   'fatalities',
#   'regulation',
#   'deregulation',
#   'industry',
#   'accidents',
#   'safety'],
#  ['classical', 'music'],
#  ['immigration',
#   'emigration',
#   'immigration',
#   'detention',
#   'asylum',
#   'right',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['weddings', 'engagements'],
#  ['weddings', 'engagements'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'forests',
#   'forestry',
#   'north',
#   'american',
#   'free',
#   'trade',
#   'agreement',
#   'logging',
#   'industry'],
#  ['organized',
#   'labor',
#   'boards',
#   'directors',
#   'labor',
#   'jobs',
#   'wages',
#   'salaries',
#   'economic',
#   'conditions',
#   'trends',
#   'united',
#   'states',
#   'economy',
#   'income',
#   'inequality'],
#  [],
#  ['nuclear',
#   'energy',
#   'electric',
#   'light',
#   'power',
#   'alternative',
#   'renewable',
#   'energy'],
#  ['family', 'leaves', 'parenting', 'paid', 'time', 'pregnancy', 'childbirth'],
#  ['airport',
#   'security',
#   'shutdowns',
#   'institutional',
#   'airports',
#   'labor',
#   'jobs'],
#  ['cocktails',
#   'mixed',
#   'drinks',
#   'united',
#   'states',
#   'defense',
#   'military',
#   'forces',
#   'writing',
#   'writers',
#   'bars',
#   'nightclubs'],
#  ['parties', 'social', 'golden', 'globes', 'awards'],
#  ['international',
#   'consumer',
#   'electronics',
#   'show',
#   'playstation',
#   'video',
#   'game',
#   'system',
#   'movies',
#   'television',
#   'computer',
#   'video',
#   'games'],
#  ['united',
#   'states',
#   'economy',
#   'productivity',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'labor',
#   'jobs',
#   'organized',
#   'labor',
#   'railroads',
#   'antitrust',
#   'laws',
#   'competition',
#   'issues',
#   'boycotts'],
#  ['united',
#   'states',
#   'international',
#   'relations',
#   'united',
#   'states',
#   'defense',
#   'military',
#   'forces',
#   'kurds'],
#  ['golden',
#   'globes',
#   'awards',
#   'blacks',
#   'black',
#   'people',
#   'egyptianamericans'],
#  [],
#  ['crossword', 'puzzles'],
#  ['homosexuality',
#   'bisexuality',
#   'models',
#   'professional',
#   'dancing',
#   'acquired',
#   'immune',
#   'deficiency',
#   'syndrome',
#   'fashion',
#   'apparel',
#   'transgender',
#   'transsexuals',
#   'transvestism'],
#  ['buildings',
#   'structures',
#   'accidents',
#   'safety',
#   'infrastructure',
#   'public',
#   'works',
#   'politics',
#   'government'],
#  ['historic',
#   'buildings',
#   'sites',
#   'shutdowns',
#   'institutional',
#   'air',
#   'traffic',
#   'control'],
#  ['united',
#   'states',
#   'defense',
#   'military',
#   'forces',
#   'appointments',
#   'executive',
#   'changes',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['theater', 'radar', 'festival'],
#  [],
#  ['falls', 'deaths', 'fatalities'],
#  ['united', 'states', 'politics', 'government'],
#  ['football', 'playoff', 'games'],
#  [],
#  [],
#  ['russian', 'orthodox', 'church', 'international', 'relations'],
#  ['sushi', 'tuna', 'japanese', 'food', 'cuisine'],
#  ['womens', 'rights', 'law', 'legislation', 'abortion'],
#  ['divorce',
#   'separations',
#   'annulments',
#   'child',
#   'marriages',
#   'fistulas',
#   'womens',
#   'rights',
#   'women',
#   'girls',
#   'social',
#   'conditions',
#   'trends',
#   'poverty'],
#  ['rodeos',
#   'cattle',
#   'breeding',
#   'animals',
#   'bull',
#   'riding',
#   'cowboys',
#   'cowgirls'],
#  ['cooking', 'cookbooks', 'recipes'],
#  ['movies', 'television', 'golden', 'globes', 'awards'],
#  ['basketball', 'coaches', 'managers'],
#  ['women', 'girls', 'asylum', 'right', 'refugees', 'displaced', 'persons'],
#  ['animals'],
#  ['metoo', 'movement', 'golden', 'globes', 'awards'],
#  ['zika', 'virus', 'pregnancy', 'childbirth', 'epidemics'],
#  ['appointments',
#   'executive',
#   'changes',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'foreign',
#   'aid'],
#  ['immigration',
#   'emigration',
#   'illegal',
#   'immigration',
#   'asylum',
#   'right',
#   'labor',
#   'jobs'],
#  [],
#  ['news',
#   'news',
#   'media',
#   'television',
#   'women',
#   'girls',
#   'deaths',
#   'obituaries'],
#  ['rumors',
#   'misinformation',
#   'elections',
#   'senate',
#   'russian',
#   'interference',
#   '2016',
#   'us',
#   'elections',
#   'ties',
#   'trump',
#   'associates',
#   'social',
#   'media',
#   'political',
#   'advertising',
#   'alcoholic',
#   'beverages'],
#  ['news', 'news', 'media', 'television'],
#  ['demonstrations',
#   'protests',
#   'riots',
#   'politics',
#   'government',
#   'labor',
#   'jobs',
#   'law',
#   'legislation'],
#  ['trees',
#   'shrubs',
#   'nonprofit',
#   'organizations',
#   'flowers',
#   'plants',
#   'air',
#   'pollution'],
#  ['murders', 'attempted', 'murders', 'homicides'],
#  ['deaths',
#   'obituaries',
#   'united',
#   'states',
#   'defense',
#   'military',
#   'forces',
#   'arms',
#   'control',
#   'limitation',
#   'disarmament'],
#  [],
#  ['terrorism', 'united', 'states', 'defense', 'military', 'forces', 'kurds'],
#  ['parkland', 'fla', 'shooting', '2018', 'comedy', 'humor'],
#  [],
#  ['afghanistan',
#   'war',
#   '2001',
#   'united',
#   'states',
#   'international',
#   'relations',
#   'united',
#   'states',
#   'defense',
#   'military',
#   'forces'],
#  ['movies', 'television', 'golden', 'globes', 'awards'],
#  ['movies', 'golden', 'globes', 'awards'],
#  ['football', 'college', 'draft', 'recruitment', 'sports'],
#  ['arabisraeli',
#   'war',
#   '1948',
#   'politics',
#   'government',
#   'deaths',
#   'obituaries'],
#  ['metoo', 'movement', 'crime', 'criminals', 'sex', 'crimes'],
#  ['crossword', 'puzzles'],
#  ['united',
#   'states',
#   'defense',
#   'military',
#   'forces',
#   'kurds',
#   'afghanistan',
#   'war',
#   '2001',
#   'terrorism',
#   'united',
#   'states',
#   'international',
#   'relations'],
#  ['preventive',
#   'medicine',
#   'tax',
#   'credits',
#   'deductions',
#   'exemptions',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['shutdowns', 'institutional', 'united', 'states', 'politics', 'government'],
#  ['illegal',
#   'immigration',
#   'border',
#   'barriers',
#   'united',
#   'states',
#   'politics',
#   'government',
#   'shutdowns',
#   'institutional',
#   'deferred',
#   'action',
#   'childhood',
#   'arrivals'],
#  ['personal', 'finances'],
#  ['fashion',
#   'apparel',
#   'advertising',
#   'marketing',
#   'golden',
#   'globes',
#   'awards',
#   'yourfeedfashion'],
#  ['deaths',
#   'obituaries',
#   'special',
#   'education',
#   'disabilities',
#   'pop',
#   'rock',
#   'music'],
#  ['voting',
#   'voters',
#   'presidential',
#   'election',
#   '2016',
#   'personal',
#   'bankruptcies',
#   'credit',
#   'debt',
#   'united',
#   'states',
#   'politics',
#   'government'],
#  ['photography',
#   'bars',
#   'nightclubs',
#   'restaurants',
#   'yourfeedphotojournalism',
#   'yourfeedonlyinnewyork'],
#  ['united',
#   'states',
#   'economy',
#   'politics',
#   'government',
#   'international',
#   'trade',
#   'world',
#   'market',
#   'united',
#   'states',
#   'international',
#   'relations',
#   'banking',
#   'financial',
#   'institutions',
#   'labor',
#   'jobs'],
#  ['st',
#   'patricks',
#   'day',
#   'irishamericans',
#   'women',
#   'girls',
#   'metoo',
#   'movement',
#   'philanthropy',
#   'parades',
#   'organizations',
#   'societies',
#   'clubs'],
#  ['cooking', 'cookbooks', 'recipes', 'spices'],
#  ['music', 'royalties', 'deaths', 'obituaries'],
#  ['television', 'blacks', 'black', 'people', 'women', 'girls'],
#  ['movies', 'golden', 'globes', 'awards', 'actors', 'actresses'],
#  ['asylum', 'right', 'immigration', 'emigration'],
#  ['race', 'ethnicity', 'genetics', 'heredity'],
#  [],
#  ['subways', 'transit', 'systems'],
#  ['movies',
#   'television',
#   'golden',
#   'globes',
#   'awards',
#   'video',
#   'recordings',
#   'downloads',
#   'streaming'],
#  ['golden', 'globes', 'awards'],
#  ['united',
#   'states',
#   'politics',
#   'government',
#   'presidential',
#   'election',
#   '2020'],
#  ['politics', 'government', 'united', 'states', 'politics', 'government'],
#  ['books', 'literature', 'writing', 'writers', 'book', 'trade', 'publishing'],
#  ['fashion', 'apparel', 'deaths', 'obituaries', 'yourfeedfashion'],
#  ['drug',
#   'abuse',
#   'traffic',
#   'movies',
#   'drug',
#   'cartels',
#   'hispanicamericans',
#   'golden',
#   'globes',
#   'awards'],
#  ['coups', 'detat', 'attempted', 'coups', 'detat'],
#  ['elections', 'house', 'representatives'],
#  ...]

# %%
lead_texts = [[word for word in document.lower().split() if word not in stopwords] for document in lead]

# %%
lead_texts
# Out:
# [['define',
#   'hope',
#   'state',
#   'mind',
#   'plan',
#   'action',
#   'simply',
#   'act',
#   'grateful'],
#  ['film',
#   'completes',
#   'director',
#   'barbet',
#   'schroeder',
#   'calls',
#   'trilogy',
#   'evil',
#   'subject',
#   'first',
#   'documentary',
#   'informal',
#   'series',
#   'ugandan',
#   'dictator',
#   'idi',
#   'amin',
#   'dada',
#   'enthusiastic',
#   'participant',
#   'project',
#   '1976',
#   'result',
#   'wound',
#   'titled',
#   'general',
#   'idi',
#   'amin',
#   'dada',
#   'self',
#   'portrait'],
#  ['paris',
#   'french',
#   'police',
#   'arrested',
#   'prominent',
#   'leader',
#   'yellow',
#   'vest',
#   'movement',
#   'second',
#   'time',
#   'clear',
#   'sign',
#   'government',
#   'following',
#   'pledge',
#   'crack',
#   'protests',
#   'shaken',
#   'france',
#   'much',
#   'past',
#   'six',
#   'weeks'],
#  ['reading', 'article'],
#  ['art',
#   'galleries',
#   'especially',
#   'lower',
#   'east',
#   'side',
#   'environs',
#   'sometimes',
#   'resemble',
#   'found',
#   'objects',
#   'art',
#   'dealers',
#   'shoestring',
#   'budgets',
#   'take',
#   'spaces',
#   'close',
#   'time',
#   'artists',
#   'often',
#   'simply',
#   'show',
#   'work',
#   'tweak',
#   'execute',
#   'substantial',
#   'makeovers',
#   'temporarily',
#   'turn',
#   'galleries',
#   'part',
#   'art',
#   'shows',
#   'nearly',
#   'always',
#   'view',
#   'somewhere',
#   'new',
#   'yorks',
#   'sprawling',
#   'gallery',
#   'scene',
#   'moment',
#   'three',
#   'fine',
#   'examples',
#   'within',
#   'short',
#   'distance',
#   'one',
#   'another',
#   'downtown',
#   'manhattan'],
#  ['poem',
#   'sto',
#   'ris',
#   'nasser',
#   'hussains',
#   'sky',
#   'wri',
#   'tei',
#   'ngs',
#   'coach',
#   'house',
#   'books',
#   '2018',
#   'page',
#   '19',
#   'hussain',
#   'lecturer',
#   'leeds',
#   'beckett',
#   'university',
#   'also',
#   'author',
#   'boldface'],
#  ['guide', 'dance', 'performances', 'happening', 'weekend', 'week', 'ahead'],
#  ['guide',
#   'standup',
#   'improv',
#   'variety',
#   'shows',
#   'happening',
#   'weekend',
#   'week',
#   'ahead'],
#  ['beijing',
#   'hours',
#   'space',
#   'probe',
#   'china',
#   'made',
#   'humanitys',
#   'first',
#   'landing',
#   'far',
#   'side',
#   'moon',
#   'sending',
#   'images',
#   'surroundings',
#   'back',
#   'earth',
#   'spacecraft',
#   'deployed',
#   'rover',
#   'thursday',
#   'take',
#   'still',
#   'photographs',
#   'scan',
#   'surface',
#   'terrain',
#   'never',
#   'traversed'],
#  ['washington',
#   'six',
#   'years',
#   'lessthanheartfelt',
#   'endorsements',
#   'bitter',
#   'parting',
#   'ways',
#   'momentary',
#   'rapprochement',
#   'relationship',
#   'mitt',
#   'romney',
#   'president',
#   'trump',
#   'returned',
#   'wednesday',
#   'began',
#   'awkward',
#   'transactional',
#   'lingering',
#   'uneasily',
#   'friend',
#   'foe'],
#  ['chelsea',
#   'paid',
#   'borussia',
#   'dortmund',
#   '73',
#   'million',
#   'complete',
#   'signing',
#   'christian',
#   'pulisic',
#   'making',
#   '20yearold',
#   'expensive',
#   'american',
#   'player',
#   'history',
#   'distance'],
#  ['saudi',
#   'arabia',
#   'denied',
#   'wednesday',
#   'issued',
#   'americanmade',
#   'weapons',
#   'sudanese',
#   'soldiers',
#   'yemen',
#   'disputing',
#   'statements',
#   'made',
#   'five',
#   'soldiers',
#   'reported',
#   'last',
#   'week',
#   'new',
#   'york',
#   'times'],
#  ['former',
#   'employee',
#   'trump',
#   'national',
#   'golf',
#   'club',
#   'new',
#   'jersey',
#   'said',
#   'name',
#   'removed',
#   'list',
#   'workers',
#   'vetted',
#   'secret',
#   'service',
#   'reminded',
#   'management',
#   'unlawfully',
#   'united',
#   'states',
#   'latest',
#   'worker',
#   'assert',
#   'supervisors',
#   'elite',
#   'resort',
#   'aware',
#   'members',
#   'work',
#   'force',
#   'undocumented'],
#  ['williams',
#   'calif',
#   'time',
#   'add',
#   'another',
#   'name',
#   'farewell',
#   'tour',
#   'circuit',
#   'year',
#   'elton',
#   'john',
#   'joan',
#   'baez',
#   'paul',
#   'simon',
#   'ozzy',
#   'osbourne',
#   'edmund',
#   'g',
#   'brown',
#   'jr',
#   'governor',
#   'california'],
#  ['listen',
#   'subscribe',
#   'podcast',
#   'mobile',
#   'device',
#   'via',
#   'apple',
#   'podcasts',
#   'via',
#   'radiopublic',
#   'via',
#   'stitcher'],
#  ['sense',
#   'true',
#   'cost',
#   'government',
#   'shutdown',
#   'deep',
#   'second',
#   'week',
#   'president',
#   'trump',
#   'spend',
#   'less',
#   'time',
#   'ragetweeting',
#   'venting',
#   'spleen',
#   'cabinet',
#   'meetings',
#   'democrats',
#   'refusal',
#   'throw',
#   'money',
#   'away',
#   'wasteful',
#   'border',
#   'wall',
#   'time',
#   'perusing',
#   'shutdownstories',
#   'making',
#   'rounds'],
#  ['copenhagen',
#   'least',
#   'six',
#   'people',
#   'killed',
#   'accident',
#   'involving',
#   'two',
#   'trains',
#   'denmark',
#   'wednesday',
#   'morning',
#   'shutting',
#   'primary',
#   'artery',
#   'linking',
#   'countrys',
#   'two',
#   'main',
#   'islands',
#   'several',
#   'hours'],
#  ['five',
#   'children',
#   'way',
#   'walt',
#   'disney',
#   'world',
#   'two',
#   'adults',
#   'killed',
#   'fiery',
#   'multivehicle',
#   'crash',
#   'northern',
#   'florida',
#   'thursday',
#   'authorities',
#   'said',
#   'least',
#   'nine',
#   'others',
#   'injured'],
#  ['corrections', 'appeared', 'print', 'wednesday', 'january', '2', '2019'],
#  ['california',
#   'week',
#   'became',
#   'first',
#   'state',
#   'nation',
#   'bar',
#   'pet',
#   'stores',
#   'selling',
#   'dogs',
#   'cats',
#   'rabbits',
#   'unless',
#   'come',
#   'animal',
#   'shelters',
#   'rescue',
#   'groups'],
#  ['wrapped',
#   'reviewing',
#   'duties',
#   '2018',
#   'chief',
#   'film',
#   'critics',
#   'manohla',
#   'dargis',
#   'scott',
#   'look',
#   'back',
#   'year',
#   'rage',
#   'silliness',
#   'sublimity',
#   'movies',
#   'ahead',
#   '91st',
#   'academy',
#   'awards'],
#  ['guide',
#   'pop',
#   'rock',
#   'shows',
#   'best',
#   'live',
#   'jazz',
#   'happening',
#   'weekend',
#   'week',
#   'ahead'],
#  ['washington', 'president', 'trump', 'things', 'say', 'start', 'new', 'year'],
#  ['note',
#   'teachers',
#   'please',
#   'preview',
#   'entire',
#   'film',
#   'sharing',
#   'students',
#   'make',
#   'sure',
#   'appropriate',
#   'class'],
#  ['article',
#   'part',
#   'opinion',
#   'today',
#   'newsletter',
#   'sign',
#   'receive',
#   'newsletter',
#   'weekday'],
#  ['updated', 'jan', '10'],
#  ['gone',
#   'hoped',
#   'mark',
#   'harris',
#   'would',
#   'sworn',
#   'house',
#   'representatives',
#   'thursday',
#   'new',
#   'member',
#   'north',
#   'carolinas',
#   'ninth',
#   'congressional',
#   'district'],
#  ['editor'],
#  ['new',
#   'year',
#   'began',
#   'another',
#   'round',
#   'choppy',
#   'trading',
#   'wall',
#   'street',
#   'stocks',
#   'opened',
#   'sharply',
#   'lower',
#   'recouped',
#   'losses',
#   'rise',
#   'oil',
#   'prices',
#   'lifted',
#   'shares',
#   'energy',
#   'producers'],
#  ['unhitched',
#   'couples',
#   'tell',
#   'stories',
#   'relationships',
#   'romance',
#   'vows',
#   'divorce',
#   'life',
#   'afterward'],
#  ['beijing',
#   'china',
#   'reached',
#   'milestone',
#   'space',
#   'exploration',
#   'thursday',
#   'landing',
#   'vehicle',
#   'far',
#   'side',
#   'moon',
#   'first',
#   'time',
#   'history',
#   'countrys',
#   'space',
#   'agency',
#   'announced'],
#  ['ray',
#   'sawyer',
#   'cut',
#   'distinctive',
#   'figure',
#   'member',
#   'band',
#   'dr',
#   'hook',
#   'medicine',
#   'show',
#   'thanks',
#   'flamboyant',
#   'style',
#   'attentiondrawing',
#   'eye',
#   'patch',
#   'sang',
#   'lead',
#   'one',
#   'groups',
#   'bestknown',
#   'songs',
#   'cover',
#   'rolling',
#   'stone',
#   'died',
#   'monday',
#   'daytona',
#   'fla',
#   '81'],
#  ['president',
#   'trump',
#   'said',
#   'wednesday',
#   'essentially',
#   'fired',
#   'defense',
#   'secretary',
#   'jim',
#   'mattis',
#   'last',
#   'month',
#   'dissatisfied',
#   'mr',
#   'mattiss',
#   'performance',
#   'top',
#   'civilian',
#   'job',
#   'pentagon'],
#  ['sydney',
#   'australia',
#   'thrashing',
#   'guitar',
#   'rock',
#   'music',
#   'words',
#   'different',
#   'lyrics',
#   'twisted',
#   'sisters',
#   'hit',
#   'song',
#   'band',
#   'impressed'],
#  ['editor'],
#  ['grew',
#   'family',
#   'reading',
#   'wasnt',
#   'simply',
#   'regular',
#   'activity',
#   'public',
#   'one',
#   'books',
#   'everywhere',
#   'lying',
#   'brokenspined',
#   'kitchen',
#   'counters',
#   'bathroom',
#   'radiators',
#   'unmade',
#   'beds',
#   'splayed',
#   'chair',
#   'arms',
#   'passed',
#   'one',
#   'us',
#   'another',
#   'volumes',
#   'agatha',
#   'christie',
#   'cs',
#   'lewis',
#   'georgette',
#   'heyer',
#   'jane',
#   'austen',
#   'george',
#   'eliot',
#   'charles',
#   'dickens',
#   'discussed',
#   'dinner',
#   'table',
#   'car',
#   'walks',
#   'keeping',
#   'tabs',
#   'peoples',
#   'reading',
#   'form',
#   'checkin',
#   'way',
#   'showing',
#   'love'],
#  ['often',
#   'actors',
#   'directors',
#   'oscar',
#   'contenders',
#   'sit',
#   'opposite',
#   'carpetbagger',
#   'sense',
#   'barely',
#   'concealed',
#   'anxiety',
#   'underneath',
#   'brave',
#   'faces',
#   'many',
#   'yearend',
#   'movies',
#   'jostling',
#   'awardseason',
#   'attention',
#   'possible',
#   'passion',
#   'projects',
#   'could',
#   'get',
#   'lost',
#   'scrum'],
#  ['michelle',
#   'yeoh',
#   'established',
#   'martial',
#   'arts',
#   'star',
#   'asia',
#   'time',
#   'western',
#   'audiences',
#   'came',
#   'know',
#   'first',
#   'bond',
#   'girl',
#   'balletic',
#   'warrior',
#   '2000',
#   'hit',
#   'crouching',
#   'tiger',
#   'hidden',
#   'dragon',
#   'yeohs',
#   'actionhero',
#   'days',
#   'performed',
#   'stunts',
#   'like',
#   'launching',
#   'motorcycle',
#   'riding',
#   'onto',
#   'moving',
#   'train',
#   'one',
#   'point',
#   'said',
#   'uninsurable',
#   'little',
#   'wonder',
#   'yeohs',
#   'portrayal',
#   'imperious',
#   'mother',
#   'eleanor',
#   'young',
#   'summer',
#   'smash',
#   'crazy',
#   'rich',
#   'asians',
#   'ferocious',
#   'costars',
#   'nominated',
#   'top',
#   'prize',
#   'outstanding',
#   'performance',
#   'cast',
#   'screen',
#   'actors',
#   'guild',
#   'awards',
#   'jan',
#   '27',
#   'film',
#   'also',
#   'golden',
#   'globe',
#   'best',
#   'musical',
#   'comedy',
#   'sundays',
#   'ceremony'],
#  ['bristolmyers',
#   'squibb',
#   'said',
#   'thursday',
#   'would',
#   'buy',
#   'celgene',
#   'maker',
#   'cancerfighting',
#   'drugs',
#   'cashandstock',
#   'deal',
#   'valued',
#   '74',
#   'billion',
#   'first',
#   'major',
#   'pharmaceutical',
#   'deal',
#   '2019'],
#  ['new',
#   'delhi',
#   'two',
#   'women',
#   'accompanied',
#   'plainclothes',
#   'police',
#   'officers',
#   'cover',
#   'darkness',
#   'early',
#   'wednesday',
#   'morning',
#   'entered',
#   'centuriesold',
#   'hindu',
#   'shrine',
#   'southern',
#   'india',
#   'long',
#   'barred',
#   'women',
#   'childbearing',
#   'age',
#   'effort',
#   'part',
#   'continuing',
#   'push',
#   'womens',
#   'equality',
#   'country'],
#  ['year',
#   'long',
#   'earth',
#   'revolves',
#   'around',
#   'sun',
#   'passes',
#   'streams',
#   'cosmic',
#   'debris',
#   'resulting',
#   'meteor',
#   'showers',
#   'light',
#   'night',
#   'skies',
#   'dusk',
#   'dawn',
#   'youre',
#   'lucky',
#   'might',
#   'able',
#   'catch',
#   'glimpse'],
#  ['fortyfour',
#   'years',
#   'ago',
#   'another',
#   'year',
#   'national',
#   'crisis',
#   'scandalridden',
#   'presidency',
#   'election',
#   'sent',
#   '91',
#   'new',
#   'members',
#   'house',
#   '1974',
#   'wave',
#   'didnt',
#   'shift',
#   'partisan',
#   'control',
#   'create',
#   'one',
#   'widest',
#   'democratic',
#   'congressional',
#   'advantages',
#   'halfcentury'],
#  ['washington',
#   'political',
#   'props',
#   'go',
#   'one',
#   'middle',
#   'conference',
#   'table',
#   'president',
#   'trumps',
#   'cabinet',
#   'meeting',
#   'wednesday',
#   'hard',
#   'miss',
#   'baffling'],
#  ['london',
#   'travel',
#   'bargain',
#   'hunters',
#   'first',
#   'day',
#   '2019',
#   'spectacular',
#   'one'],
#  ['want', 'get', 'new', 'york', 'today', 'email', 'heres', 'signup'],
#  ['nan'],
#  ['good', 'morning'],
#  ['one',
#   'darkest',
#   'episodes',
#   '20th',
#   'century',
#   'gulag',
#   'soviet',
#   'system',
#   'forced',
#   'labor',
#   'camps',
#   'dissidents',
#   'imprisoned',
#   'terrible',
#   'conditions',
#   'often',
#   'perish',
#   'camps',
#   'established',
#   'lenin',
#   'expanded',
#   'stalin',
#   'finally',
#   'exposed',
#   'world',
#   'great',
#   'russian',
#   'author',
#   'aleksandr',
#   'solzhenitsyn',
#   '1973',
#   'masterpiece',
#   'gulag',
#   'archipelago'],
#  ['spaceflight',
#   'first',
#   'chinas',
#   'change4',
#   'landed',
#   'spacecraft',
#   'touched',
#   'one',
#   'piece',
#   'far',
#   'side',
#   'moon'],
#  ['washington',
#   'trey',
#   'mourning',
#   'one',
#   'foot',
#   'door',
#   'georgetown',
#   'uncle',
#   'patrick',
#   'became',
#   'coach',
#   'ewing',
#   'turned',
#   'around',
#   'went',
#   'team',
#   'meeting'],
#  ['nearly',
#   '180000',
#   'former',
#   'students',
#   'forprofit',
#   'schools',
#   'run',
#   'career',
#   'education',
#   'repay',
#   '494',
#   'million',
#   'owed',
#   'company',
#   'group',
#   '49',
#   'state',
#   'attorneys',
#   'general',
#   'announced',
#   'thursday'],
#  ['since',
#   '1851',
#   'obituaries',
#   'new',
#   'york',
#   'times',
#   'dominated',
#   'white',
#   'men',
#   'overlooked',
#   'adding',
#   'stories',
#   'remarkable',
#   'people',
#   'whose',
#   'deaths',
#   'went',
#   'unreported',
#   'times'],
#  ['pop',
#   'music',
#   'diva',
#   'wins',
#   'oscar',
#   'bigscreen',
#   'breakthrough',
#   'performer',
#   'overcomes',
#   'doubts',
#   'looks',
#   'become',
#   'superstar',
#   'happens',
#   'lady',
#   'gaga',
#   'whose',
#   'turn',
#   'rising',
#   'singersongwriter',
#   'star',
#   'born',
#   'made',
#   'leading',
#   'contender',
#   'best',
#   'actress',
#   '2019',
#   'academy',
#   'awards',
#   'history',
#   'repeated',
#   'nearly',
#   '50',
#   'years',
#   'ago',
#   'barbra',
#   'streisand',
#   'took',
#   'home',
#   'honor',
#   'funny',
#   'girl',
#   'jawdropping',
#   'twist',
#   'tied',
#   'katharine',
#   'hepburn',
#   'lion',
#   'winter'],
#  ['london',
#   'punishing',
#   'coda',
#   'already',
#   'awful',
#   'ordeal',
#   'british',
#   'women',
#   'survive',
#   'forced',
#   'marriages',
#   'abroad',
#   'rescued',
#   'help',
#   'foreign',
#   'office',
#   'repay',
#   'government',
#   'escape'],
#  ['helen',
#   'mirras',
#   'marvelous',
#   'soho',
#   'show',
#   'small',
#   'vibrant',
#   'weavings',
#   'evocatively',
#   'titled',
#   'bones',
#   'spaces',
#   'rebalances',
#   'visual',
#   'intellectual',
#   'elements',
#   'work',
#   'two',
#   'decades',
#   'american',
#   'artist',
#   'assiduously',
#   'imbued',
#   'modest',
#   'lowlying',
#   'sculptures',
#   'wall',
#   'pieces',
#   'handmade',
#   'assorted',
#   'found',
#   'materials',
#   'dissected',
#   'objects',
#   'occasionally',
#   'borrowed',
#   'texts',
#   'complex',
#   'reverberations',
#   'literature',
#   'history',
#   'philosophy',
#   'times',
#   'complexities',
#   'remained',
#   'obscure',
#   'unless',
#   'clarified',
#   'gallerys',
#   'news',
#   'release',
#   'making',
#   'work',
#   'feel',
#   'hermetic',
#   'precious'],
#  ['one',
#   'relatively',
#   'rare',
#   'victorians',
#   'minneapolis',
#   'type',
#   'common',
#   'neighboring',
#   'st',
#   'paul',
#   'property',
#   'designed',
#   'harry',
#   'wild',
#   'jones',
#   'prolific',
#   'local',
#   'architect',
#   'whose',
#   'clients',
#   'included',
#   'founders',
#   'cream',
#   'wheat',
#   'hormel',
#   'companies',
#   'kenwood',
#   'neighborhood',
#   'couple',
#   'blocks',
#   'cedar',
#   'lake',
#   'west',
#   'lake',
#   'isles',
#   'east',
#   'mary',
#   'tyler',
#   'moore',
#   'house',
#   'building',
#   '2104',
#   'kenwood',
#   'parkway',
#   'whose',
#   'exterior',
#   'represented',
#   'home',
#   'mary',
#   'richards',
#   '1970s',
#   'sitcom',
#   'block',
#   'away'],
#  ['washington',
#   'become',
#   'favorite',
#   'parlor',
#   'trick',
#   'president',
#   'trumps',
#   'wednesday',
#   'brandishing',
#   'latest',
#   'letter',
#   'north',
#   'korean',
#   'dictator',
#   'kim',
#   'jongun'],
#  ['welcome',
#   'first',
#   '2019',
#   'edition',
#   'teenagers',
#   'times',
#   'roundup',
#   'news',
#   'feature',
#   'stories',
#   'young',
#   'people',
#   'recently',
#   'appeared',
#   'across',
#   'sections',
#   'nytimescom',
#   'appears',
#   'first',
#   'thursday',
#   'month',
#   'school',
#   'year'],
#  ['werent',
#   'looking',
#   'diagnosis',
#   'middleaged',
#   'woman',
#   'explained',
#   'husband',
#   'diagnosis',
#   'wanted',
#   'help',
#   'figuring',
#   'even',
#   'treatments',
#   'getting',
#   'wasnt',
#   'getting',
#   'better'],
#  ['tokyo',
#   'north',
#   'koreas',
#   'acting',
#   'ambassador',
#   'italy',
#   'disappeared',
#   'embassy',
#   'rome',
#   'november',
#   'apparently',
#   'defection',
#   'attempt',
#   'according',
#   'south',
#   'korean',
#   'lawmaker',
#   'briefed',
#   'intelligence',
#   'officials'],
#  ['want', 'get', 'briefing', 'email', 'heres', 'signup'],
#  ['manchester',
#   'england',
#   'weeks',
#   'ago',
#   'manchester',
#   'citys',
#   'serene',
#   'season',
#   'hit',
#   'unexpected',
#   'turbulence',
#   'david',
#   'silva',
#   'ran',
#   'parents',
#   'clubs',
#   'bright',
#   'midfield',
#   'hope',
#   'phil',
#   'foden',
#   'yet',
#   'another',
#   'routine',
#   'premier',
#   'league',
#   'win'],
#  ['london',
#   'diplomatic',
#   'standoff',
#   'qatar',
#   'arab',
#   'neighbors',
#   'spilled',
#   'sports',
#   'world',
#   'thursday',
#   'qatari',
#   'vice',
#   'president',
#   'asias',
#   'soccer',
#   'confederation',
#   'barred',
#   'traveling',
#   'united',
#   'arab',
#   'emirates',
#   'ahead',
#   'regions',
#   'top',
#   'tournament'],
#  ['need', 'know', 'start', 'day', 'get', 'new', 'york', 'today', 'inbox'],
#  ['ever',
#   'held',
#   'grudge',
#   'years',
#   'unrelated',
#   'scorpio',
#   'chance',
#   'grudges',
#   'good',
#   'actually',
#   'hold',
#   'onto',
#   'like',
#   'petty',
#   'tamagotchis',
#   'emotional',
#   'pocket',
#   'dont',
#   'often',
#   'associate',
#   'holding',
#   'grudges',
#   'virtuous',
#   'people',
#   '2019',
#   'new',
#   'year',
#   'new'],
#  ['good',
#   'thursday',
#   'morning',
#   'stories',
#   'making',
#   'news',
#   'washington',
#   'politics',
#   'today'],
#  ['many',
#   'keepers',
#   'lost',
#   'mind',
#   'quicksilver',
#   'warns',
#   'james',
#   'gerard',
#   'butler',
#   'donald',
#   'connor',
#   'swindells',
#   'trainee',
#   'lighthouse',
#   'keeper',
#   'dabbles',
#   'gloved',
#   'hand',
#   'puddle',
#   'mercury',
#   '1938',
#   'men',
#   'accompanied',
#   'veteran',
#   'keeper',
#   'named',
#   'thomas',
#   'peter',
#   'mullan',
#   'arrived',
#   '6week',
#   'shift',
#   'barren',
#   'lump',
#   'rock',
#   'coast',
#   'scotland',
#   'mercury',
#   'leak',
#   'first',
#   'sign',
#   'many',
#   'troubles',
#   'come'],
#  ['horror',
#   'movies',
#   'head',
#   'woods',
#   'titles',
#   'may',
#   'vary',
#   'spit',
#   'grave',
#   'wolf',
#   'creek',
#   'central',
#   'dynamic',
#   'often',
#   'point',
#   'attractively',
#   'trembling',
#   'woman',
#   'forced',
#   'run',
#   'like',
#   'dickens',
#   'yokel',
#   'butchers',
#   'meat'],
#  ['david',
#   'robertson',
#   'made',
#   'first',
#   'major',
#   'league',
#   'appearance',
#   'june',
#   '29',
#   '2008',
#   'earliest',
#   'yankees',
#   'debut',
#   'anyone',
#   'last',
#   'years',
#   'team',
#   'went',
#   'pitch',
#   '500',
#   'regularseason',
#   'games',
#   'yankees',
#   'two',
#   'pitchers',
#   'mariano',
#   'rivera',
#   'dave',
#   'righetti',
#   'made',
#   'appearances',
#   'team'],
#  ['moscow',
#   'number',
#   'people',
#   'killed',
#   'apartment',
#   'building',
#   'central',
#   'russia',
#   'partly',
#   'collapsed',
#   'explosion',
#   'rose',
#   '38',
#   'thursday',
#   'hope',
#   'dwindled',
#   'people',
#   'remain',
#   'missing',
#   'would',
#   'found'],
#  ['flame',
#   'poems',
#   'notebooks',
#   'lyrics',
#   'drawings',
#   'leonard',
#   'cohen',
#   'edited',
#   'robert',
#   'faggen',
#   'alexandra',
#   'pleshoyano',
#   '277',
#   'pp',
#   'farrar',
#   'straus',
#   'giroux',
#   '28'],
#  ['voting',
#   'rights',
#   'partisan',
#   'gerrymandering',
#   'traditionally',
#   'preoccupation',
#   'wonky',
#   'party',
#   'strategists',
#   'goodgovernment',
#   'groups',
#   'become',
#   'major',
#   'flash',
#   'points',
#   'debate',
#   'integrity',
#   'american',
#   'elections',
#   'signaling',
#   'high',
#   'stakes',
#   'battles',
#   'voter',
#   'suppression',
#   'politically',
#   'engineered',
#   'districts',
#   'ahead',
#   '2020',
#   'presidential',
#   'race'],
#  ['jarrahdale',
#   'western',
#   'australia',
#   'narrative',
#   'irresistible',
#   'chef',
#   'grows',
#   'almost',
#   'every',
#   'ingredient',
#   'plate',
#   'saves',
#   'seeds',
#   'year',
#   'year',
#   'coaxes',
#   'beautiful',
#   'meals',
#   'verdant',
#   'land',
#   'gaze',
#   'upon',
#   'eat'],
#  ['mitt',
#   'romney',
#   'incoming',
#   'senator',
#   'utah',
#   'former',
#   'republican',
#   'presidential',
#   'nominee',
#   'revived',
#   'rivalry',
#   'president',
#   'trump',
#   'tuesday',
#   'oped',
#   'essay',
#   'washington',
#   'post',
#   'said',
#   'mr',
#   'trump',
#   'risen',
#   'mantle',
#   'office'],
#  ['recently',
#   'elected',
#   'chairman',
#   'house',
#   'democratic',
#   'caucus',
#   'fifthranking',
#   'position',
#   'party',
#   'leadership',
#   '48',
#   'youre',
#   'basically',
#   'teenager',
#   'democrat',
#   'world',
#   'top',
#   'house',
#   'democrats',
#   'close',
#   '80',
#   'giving',
#   'advice',
#   'youngpeople',
#   'stuff',
#   'well',
#   'nancy',
#   'pelosi',
#   'steny',
#   'hoyer',
#   'jim',
#   'clyburn',
#   'extremely',
#   'hip',
#   'right',
#   'dont',
#   'believe',
#   'need',
#   'advice'],
#  ['editor'],
#  ['people', 'buy', 'shoes', 'comfort', 'cops'],
#  ['think',
#   'illustration',
#   'saying',
#   'relate',
#   'comment',
#   'new',
#   'year',
#   'connect',
#   'message',
#   'personally',
#   'way'],
#  ['new',
#   'year',
#   'begun',
#   'nomination',
#   'process',
#   'next',
#   'years',
#   'presidential',
#   'election',
#   'candidates',
#   'actually',
#   'point',
#   'iowa',
#   'caucuses',
#   'still',
#   '13',
#   'months',
#   'away'],
#  ['americans',
#   'supposedly',
#   'little',
#   'patience',
#   'expertise',
#   'days',
#   'except',
#   'seems',
#   'comes',
#   'parenting',
#   'experts',
#   'continue',
#   'churn',
#   'guides',
#   'quickly',
#   'audience',
#   'consume',
#   'appetite',
#   'counsel',
#   'inevitably',
#   'reflects',
#   'deeper',
#   'often',
#   'unspoken',
#   'middleclass',
#   'aspirations',
#   'anxieties',
#   'psychoanalyst',
#   'essayist',
#   'adam',
#   'phillips',
#   'observed',
#   'appeal',
#   'books',
#   'goes',
#   'beyond',
#   'immediate',
#   'need',
#   'deal',
#   'sullen',
#   'teenager',
#   'sleepless',
#   'newborn',
#   'obsession',
#   'child',
#   'development',
#   'socalled',
#   'parenting',
#   'skills',
#   'wrote',
#   'become',
#   'code',
#   'forlorn',
#   'attempt',
#   'find',
#   'sanity'],
#  ['editor'],
#  ['rome',
#   'pope',
#   'francis',
#   'told',
#   'united',
#   'states',
#   'bishops',
#   'thursday',
#   'set',
#   'aside',
#   'differences',
#   'could',
#   'confront',
#   'widespread',
#   'crisis',
#   'credibility',
#   'stemming',
#   'sexual',
#   'abuse',
#   'scandal'],
#  ['long',
#   'winter',
#   'months',
#   'ground',
#   'icy',
#   'sun',
#   'shows',
#   'little',
#   'sign',
#   'appearing',
#   'english',
#   'honed',
#   'triedandtrue',
#   'approach',
#   'imaginative',
#   'coldweather',
#   'dressing',
#   'channeled',
#   'recently',
#   'brands',
#   'including',
#   'gucci',
#   'chloé',
#   'look',
#   'artful',
#   'balance',
#   'practical',
#   'outdoorsy',
#   'pieces',
#   'quilted',
#   'jackets',
#   'tweed',
#   'suiting',
#   'sturdy',
#   'sweaters',
#   'whimsical',
#   'touches',
#   'laura',
#   'ashley',
#   'florals',
#   'oversize',
#   'velvet',
#   'hair',
#   'bows',
#   'taking',
#   'cues',
#   'recent',
#   'collections',
#   'break',
#   '10',
#   'ways',
#   'reimagine',
#   'winter',
#   'wardrobe',
#   'romantic',
#   'distinctly',
#   'british',
#   'light'],
#  ['note',
#   'sixth',
#   'annual',
#   '15second',
#   'vocabulary',
#   'video',
#   'challenge',
#   'run',
#   'jan',
#   '17',
#   'feb',
#   '18',
#   'information',
#   'visit',
#   'learning',
#   'network',
#   'jan',
#   '17',
#   'announce',
#   'rules',
#   'begin',
#   'accepting',
#   'submissions',
#   'meantime',
#   'check',
#   'last',
#   'years',
#   'rules',
#   'winners',
#   'one',
#   'shown'],
#  ['race',
#   'finish',
#   'teams',
#   'like',
#   'colts',
#   'ravens',
#   'eagles',
#   'time',
#   'celebrate',
#   'back',
#   'nfl',
#   'playoff',
#   'positions',
#   'trying',
#   'beat',
#   'fierce',
#   'competition',
#   'weekends',
#   'wildcard',
#   'matchups',
#   'spread',
#   'two',
#   'days',
#   'trip',
#   'divisional',
#   'round',
#   'line'],
#  ['call', 'oldfashioned'],
#  ['14yearold',
#   'texas',
#   'boy',
#   'said',
#   'throwing',
#   'eggs',
#   'cars',
#   'charged',
#   'murder',
#   'crashed',
#   'pickup',
#   'truck',
#   'killed',
#   'woman',
#   'chased',
#   'another',
#   'driver',
#   'authorities',
#   'said',
#   'wednesday'],
#  ['dont',
#   'know',
#   'anything',
#   'turn',
#   'youve',
#   'got',
#   'much',
#   'rain',
#   'said',
#   'ryan',
#   'seacrest',
#   'cold',
#   'water',
#   'sluiced',
#   'gelled',
#   'hair',
#   'angular',
#   'chin'],
#  ['need', 'know', 'start', 'day', 'get', 'new', 'york', 'today', 'inbox'],
#  ['rome',
#   'museums',
#   'usually',
#   'known',
#   'online',
#   'trolling',
#   'one',
#   'worlds',
#   'great',
#   'art',
#   'institutions',
#   'uses',
#   'provocative',
#   'hashtags',
#   'like',
#   'nazis',
#   'wehrmacht',
#   'make',
#   'digital',
#   'demands',
#   'germany',
#   'return',
#   'stolen',
#   'painting',
#   'bound',
#   'draw',
#   'attention'],
#  ['editor'],
#  ['rhode',
#   'island',
#   'may',
#   'smallest',
#   'state',
#   'culinary',
#   'scene',
#   'anything',
#   'small',
#   'cambodia',
#   'cape',
#   'verde',
#   'providence',
#   'ri',
#   'restaurants',
#   'span',
#   'globe',
#   'big',
#   'way'],
#  ['want', 'get', 'briefing', 'email', 'heres', 'signup'],
#  ['abiy',
#   'ahmed',
#   '42yearold',
#   'prime',
#   'minister',
#   'ethiopia',
#   'dazzled',
#   'africa',
#   'volley',
#   'political',
#   'reforms',
#   'since',
#   'appointment',
#   'april',
#   'mr',
#   'abiy',
#   'ended',
#   '20year',
#   'border',
#   'war',
#   'eritrea',
#   'released',
#   'political',
#   'prisoners',
#   'removed',
#   'bans',
#   'dissident',
#   'groups',
#   'allowed',
#   'members',
#   'return',
#   'exile',
#   'declared',
#   'press',
#   'freedom',
#   'granted',
#   'diverse',
#   'political',
#   'groups',
#   'freedom',
#   'mobilize',
#   'organize'],
#  ['need', 'know', 'start', 'day', 'get', 'new', 'york', 'today', 'inbox'],
#  ['washington',
#   'loved',
#   'travel',
#   'around',
#   'russia',
#   'train',
#   'collected',
#   'tea',
#   'glass',
#   'holders',
#   'stamped',
#   'russian',
#   'historical',
#   'scenes',
#   'maintained',
#   'social',
#   'media',
#   'friendships',
#   'ordinary',
#   'russians',
#   'hairstylist',
#   'retired',
#   'members',
#   'countrys',
#   'military'],
#  ['winter',
#   'television',
#   'season',
#   'combination',
#   'words',
#   'ever',
#   'stop',
#   'sounding',
#   'strange',
#   'upon',
#   'us',
#   'abundance',
#   'abundant',
#   'ever',
#   '21',
#   'new',
#   'returning',
#   'shows',
#   'keep',
#   'eye',
#   'next',
#   'months',
#   'course',
#   'thats',
#   'anyone',
#   'watch',
#   'cases',
#   'early',
#   'tell',
#   'shows',
#   'pan',
#   'nailed',
#   'tree',
#   'id',
#   'tell',
#   'definitely',
#   'make',
#   'time',
#   'high',
#   'maintenance',
#   'shrill',
#   'parts',
#   'documentary',
#   'especially',
#   'episodes',
#   'titled',
#   'original',
#   'cast',
#   'album',
#   'coop',
#   'waiting',
#   'artist',
#   'children',
#   'coview',
#   'carmen',
#   'sandiego'],
#  ['lake',
#   'forest',
#   'ill',
#   'practice',
#   'last',
#   'thursday',
#   'afternoon',
#   'tarik',
#   'cohen',
#   'caught',
#   'punt',
#   'still',
#   'clutching',
#   'ball',
#   'proceeded',
#   'catch',
#   'another',
#   'another',
#   'another',
#   'another',
#   'another'],
#  ['washington',
#   'america',
#   'get',
#   'first',
#   'taste',
#   'divided',
#   'government',
#   'president',
#   'trump',
#   'week',
#   'democratic',
#   'house',
#   'tries',
#   'wrest',
#   'control',
#   'political',
#   'agenda',
#   'mr',
#   'trump',
#   'appears',
#   'determined',
#   'keep',
#   'focus',
#   'border',
#   'security',
#   'immigration',
#   'big',
#   'beautiful',
#   'wall'],
#  ['art',
#   'world',
#   'biggest',
#   'news',
#   'coming',
#   'pittsburgh',
#   'last',
#   'year',
#   'opening',
#   '57th',
#   'edition',
#   'carnegie',
#   'international',
#   'oldest',
#   'survey',
#   'exhibition',
#   'visual',
#   'art',
#   'united',
#   'states',
#   'instead',
#   'news',
#   'exhibition',
#   'eclipsed',
#   'october',
#   'shooting',
#   'progressive',
#   'tree',
#   'life',
#   'synagogue',
#   'squirrel',
#   'hill',
#   'neighborhood',
#   'pittsburgh',
#   'killed',
#   '11',
#   'people',
#   'wounded',
#   'six'],
#  ['pasadena',
#   'calif',
#   'colleague',
#   'advised',
#   'urban',
#   'meyer',
#   'find',
#   'moment',
#   'amid',
#   'game',
#   'savor',
#   'ohio',
#   'state',
#   'regimented',
#   'coach',
#   'customarily',
#   'would',
#   'remove',
#   'headset',
#   'third',
#   'fourth',
#   'quarters',
#   'soak',
#   'university',
#   'marching',
#   'band',
#   'blasting',
#   'vintage',
#   'rock',
#   'tune',
#   'hang',
#   'sloopy'],
#  ['7',
#   'percent',
#   'cancer',
#   'cases',
#   'united',
#   'states',
#   'attributable',
#   'excess',
#   'body',
#   'weight',
#   'new',
#   'study',
#   'reports'],
#  ['live',
#   'always',
#   'someone',
#   'driving',
#   'slowly',
#   'road',
#   'ahead',
#   'sea',
#   'english',
#   'countryside',
#   'roads',
#   'narrow',
#   'burrowlike',
#   'high',
#   'hedges',
#   'either',
#   'side',
#   'protect',
#   'fields',
#   'coastal',
#   'winds',
#   'roads',
#   'digressive',
#   'character',
#   'rarely',
#   'traveling',
#   'directly',
#   'specific',
#   'location',
#   'branch',
#   'across',
#   'flat',
#   'fields',
#   'like',
#   'veins',
#   'hard',
#   'see',
#   'whats',
#   'coming',
#   'arent',
#   'many',
#   'vantage',
#   'points',
#   'easy',
#   'get',
#   'lost',
#   'still',
#   'nothing',
#   'requires',
#   'excessive',
#   'caution',
#   'theres',
#   'particular',
#   'reason',
#   'alarm',
#   'fact',
#   'quite',
#   'reverse',
#   'yet',
#   'people',
#   'drive',
#   '15',
#   '20',
#   '30',
#   'miles',
#   'hour',
#   'matter',
#   'many',
#   'get',
#   'past',
#   'theres',
#   'always',
#   'another',
#   'one',
#   'around',
#   'next',
#   'bend'],
#  ['clutter', 'problem'],
#  ['la',
#   'religieuse',
#   'nun',
#   'second',
#   'feature',
#   'new',
#   'wave',
#   'director',
#   'jacques',
#   'rivette',
#   'ignited',
#   'firstclass',
#   'scandal',
#   'preview',
#   'french',
#   'upheaval',
#   'come'],
#  ['story', 'updated', 'reflect', '2020s', 'perihelion'],
#  ['berlin',
#   'director',
#   'steven',
#   'spielberg',
#   'cited',
#   'renewed',
#   'cycle',
#   'hate',
#   'society',
#   'behind',
#   'decision',
#   'bring',
#   'schindlers',
#   'list',
#   'back',
#   'movie',
#   'theaters',
#   'around',
#   'world',
#   'hoping',
#   'would',
#   'provoke',
#   'discussion'],
#  ['new',
#   'york',
#   'gone',
#   'dogs',
#   'rabbits',
#   'rhinos',
#   'arent',
#   'far',
#   'behind',
#   'assault'],
#  ['war',
#   'war',
#   'fugitive',
#   'slaves',
#   'struggle',
#   'americas',
#   'soul',
#   'revolution',
#   'civil',
#   'war',
#   'andrew',
#   'delbanco',
#   'illustrated',
#   '453',
#   'pp',
#   'penguin',
#   'press',
#   '30'],
#  ['american',
#   'arrested',
#   'russia',
#   'suspicion',
#   'spying',
#   'met',
#   'united',
#   'states',
#   'ambassador',
#   'wednesday',
#   'secretary',
#   'state',
#   'said',
#   'would',
#   'demand',
#   'mans',
#   'return',
#   'detention',
#   'appropriate'],
#  ['want', 'get', 'briefing', 'email', 'heres', 'signup'],
#  ['graphic',
#   'novel',
#   'showtime',
#   'apollo',
#   'epic',
#   'tale',
#   'harlems',
#   'legendary',
#   'theater',
#   'like',
#   'sprawling',
#   'hollywood',
#   'biopic',
#   'sea',
#   'boldface',
#   'names',
#   'james',
#   'brown',
#   'jackson',
#   'five',
#   'dionne',
#   'warwick',
#   'countless',
#   'others',
#   'make',
#   'way',
#   'theater'],
#  ['laurel',
#   'md',
#   'ultima',
#   'thule',
#   'icy',
#   'world',
#   '4',
#   'billion',
#   'miles',
#   'sun',
#   'looks',
#   'like',
#   'big',
#   'snowman'],
#  ['article',
#   'part',
#   'opinion',
#   'today',
#   'newsletter',
#   'sign',
#   'receive',
#   'newsletter',
#   'weekday'],
#  ['beijing',
#   'chinas',
#   'president',
#   'xi',
#   'jinping',
#   'warned',
#   'taiwan',
#   'unification',
#   'must',
#   'ultimate',
#   'goal',
#   'talks',
#   'future',
#   'efforts',
#   'assert',
#   'full',
#   'independence',
#   'could',
#   'met',
#   'armed',
#   'force',
#   'laying',
#   'unyielding',
#   'position',
#   'wednesday',
#   'first',
#   'major',
#   'speech',
#   'contested',
#   'island',
#   'democracy'],
#  ['zoe',
#   'spencer',
#   'pepper',
#   'met',
#   'preschool',
#   'growing',
#   'neighboring',
#   'long',
#   'island',
#   'towns',
#   'years',
#   'later',
#   'reconnected',
#   'undergraduates',
#   'cornell',
#   'university'],
#  ['editor'],
#  ['washington',
#   'redskins',
#   'linebacker',
#   'reuben',
#   'foster',
#   'center',
#   'criticism',
#   'domestic',
#   'violence',
#   'nfl',
#   'escaped',
#   'prosecution'],
#  ['im',
#   'working',
#   'family',
#   'im',
#   'working',
#   'jesus',
#   '5',
#   'two',
#   'us',
#   'three',
#   'others'],
#  ['specter',
#   'haunting',
#   'supreme',
#   'court',
#   'disrespect',
#   'second',
#   'amendment',
#   'perhaps',
#   'havent',
#   'realized',
#   'supreme',
#   'courts',
#   'disinclination',
#   'expand',
#   'landmark',
#   '2008',
#   'decision',
#   'creating',
#   'individual',
#   'right',
#   'gun',
#   'ownership',
#   'means',
#   'justices',
#   'treating',
#   'second',
#   'amendment',
#   'secondclass',
#   'right',
#   'watereddown',
#   'right',
#   'disfavored',
#   'right'],
#  ['days',
#   'jazmine',
#   'barnes',
#   '7',
#   'fatally',
#   'shot',
#   'inside',
#   'moving',
#   'car',
#   'near',
#   'walmart',
#   'outside',
#   'houston',
#   'sunday',
#   'morning',
#   'police',
#   'released',
#   'one',
#   'concrete',
#   'clue',
#   'killer',
#   'image',
#   'red',
#   'pickup',
#   'truck',
#   'recorded',
#   'surveillance',
#   'camera',
#   'near',
#   'scene',
#   'shooting'],
#  ['blake',
#   'w',
#   'nordstrom',
#   'copresident',
#   'nordstrom',
#   'chain',
#   'upscale',
#   'clothing',
#   'shoe',
#   'stores',
#   'grew',
#   'single',
#   'establishment',
#   'founded',
#   'greatgrandfather',
#   'died',
#   'wednesday',
#   'seattle',
#   '58'],
#  ['obviously', 'usual', 'business'],
#  ['get',
#   'dealbook',
#   'newsletter',
#   'make',
#   'sense',
#   'major',
#   'business',
#   'policy',
#   'headlines',
#   'powerbrokers',
#   'shape',
#   'them__________'],
#  ['updated', 'jan', '10', '2019'],
#  ['editor'],
#  ['mere',
#   'coincidence',
#   'jeffrey',
#   'r',
#   'brown',
#   'dean',
#   'gies',
#   'college',
#   'business',
#   'university',
#   'illinois',
#   'urbanachampaign',
#   'also',
#   'scholar',
#   'risk',
#   'management',
#   'first',
#   'faculty',
#   'meeting',
#   'four',
#   'years',
#   'ago',
#   'brown',
#   'fretted',
#   'school',
#   'become',
#   'like',
#   'many',
#   'american',
#   'universities',
#   'overly',
#   'dependent',
#   'single',
#   'source',
#   'money',
#   'roughly',
#   'fifth',
#   'tuition',
#   'revenue',
#   'came',
#   'chinese',
#   'students',
#   'saw',
#   'reliance',
#   'china',
#   'risk',
#   'says',
#   'brown',
#   'noting',
#   '800',
#   'universitys',
#   'nearly',
#   '5800',
#   'chinese',
#   'students',
#   'attend',
#   'business',
#   'school',
#   'time',
#   'concerned',
#   'china',
#   'could',
#   'pull',
#   'plug',
#   'students',
#   'coming',
#   'america',
#   'us',
#   'political',
#   'landscape',
#   'shifted',
#   'vulnerable',
#   'changing',
#   'visa',
#   'immigration',
#   'policies',
#   'threats',
#   'could',
#   'control'],
#  ['good', 'thursday', 'morning', 'want', 'email', 'sign'],
#  ['theres',
#   'good',
#   'chance',
#   'monthly',
#   'rent',
#   'checks',
#   'write',
#   'year',
#   'larger',
#   'last',
#   'year',
#   'surprise',
#   'rents'],
#  ['read', 'latest', 'story', 'cancellation', 'l', 'train', 'shutdown'],
#  ['johnson',
#   'county',
#   'ind',
#   'children',
#   'fell',
#   'ill',
#   'one',
#   'one',
#   'cancers',
#   'families',
#   'suburban',
#   'indianapolis',
#   'community',
#   'ever',
#   'heard',
#   'avid',
#   'swimmer',
#   'struck',
#   'glioblastoma',
#   'grew',
#   'tumor',
#   'brain',
#   'four',
#   'children',
#   'ewings',
#   'sarcoma',
#   'rare',
#   'bone',
#   'cancer',
#   'fifteen',
#   'children',
#   'acute',
#   'lymphocytic',
#   'leukemia',
#   'including',
#   'three',
#   'cases',
#   'diagnosed',
#   'past',
#   'year'],
#  ['margaret',
#   'lovell',
#   'lee',
#   'raised',
#   'family',
#   'simple',
#   'guidelines',
#   'work',
#   'hard',
#   'education',
#   'employer',
#   'eat',
#   'dinner',
#   'together',
#   'help',
#   'others',
#   'need',
#   'assistance'],
#  ['holiday',
#   'season',
#   'may',
#   'confer',
#   'unwanted',
#   'gift',
#   'higher',
#   'cholesterol'],
#  ['guide',
#   'cultural',
#   'events',
#   'new',
#   'york',
#   'city',
#   'children',
#   'teenagers',
#   'happening',
#   'weekend',
#   'week',
#   'ahead'],
#  ['gene',
#   'okerlund',
#   'ringside',
#   'interviewer',
#   'commentator',
#   'served',
#   'decades',
#   'straight',
#   'man',
#   'outsize',
#   'personalities',
#   'suffuse',
#   'world',
#   'professional',
#   'wrestling',
#   'died',
#   'wednesday',
#   'hospital',
#   'sarasota',
#   'fla',
#   '76'],
#  ['front', 'page'],
#  ['office',
#   'next',
#   'big',
#   'training',
#   'room',
#   'often',
#   'hear',
#   'surprised',
#   'sounds',
#   'ah',
#   'ah',
#   'ah'],
#  ['need', 'know', 'start', 'day', 'get', 'new', 'york', 'today', 'inbox'],
#  ['need', 'know', 'start', 'day', 'get', 'new', 'york', 'today', 'inbox'],
#  ['frankfurt',
#   'european',
#   'central',
#   'bank',
#   'took',
#   'control',
#   'troubled',
#   'italian',
#   'bank',
#   'wednesday',
#   'unprecedented',
#   'step',
#   'spotlighted',
#   'risks',
#   'eurozones',
#   'financial',
#   'system',
#   'political',
#   'chaos',
#   'rome',
#   'sputtering',
#   'economy'],
#  ['washington',
#   'president',
#   'trump',
#   'democratic',
#   'congressional',
#   'leaders',
#   'dug',
#   'wednesday',
#   'lengthy',
#   'partial',
#   'shutdown',
#   'newly',
#   'divided',
#   'government',
#   'white',
#   'house',
#   'meeting',
#   'first',
#   '22',
#   'days',
#   'could',
#   'break',
#   'impasse',
#   'mr',
#   'trumps',
#   'demands',
#   'billions',
#   'dollars',
#   'border',
#   'wall'],
#  ['shamorie',
#   'ponds',
#   'st',
#   'johns',
#   'red',
#   'storm',
#   'fed',
#   'mustapha',
#   'heron',
#   'rimrattling',
#   'dunk',
#   'capacity',
#   'crowd',
#   'carnesecca',
#   'arena',
#   'queens',
#   'tuesday',
#   'night',
#   'marvin',
#   'clark',
#   'ii',
#   'walked',
#   'center',
#   'court',
#   'stood',
#   'middle',
#   'teams',
#   'red',
#   'logo'],
#  ['hong',
#   'kong',
#   'years',
#   'matter',
#   'happening',
#   'elsewhere',
#   'global',
#   'companies',
#   'bet',
#   'billions',
#   'upon',
#   'billions',
#   'dollars',
#   'chinas',
#   'consumers',
#   'would',
#   'keep',
#   'spending',
#   'money'],
#  ['rio',
#   'de',
#   'janeiro',
#   'president',
#   'jair',
#   'bolsonaro',
#   'brazil',
#   'compared',
#   'indigenous',
#   'communities',
#   'living',
#   'protected',
#   'lands',
#   'animals',
#   'zoos',
#   'took',
#   'major',
#   'step',
#   'toward',
#   'undermining',
#   'rights',
#   'indigenous',
#   'people',
#   'hours',
#   'taking',
#   'office',
#   'tuesday'],
#  ['many',
#   'many',
#   'reasons',
#   'take',
#   'residence',
#   'new',
#   'york',
#   'city',
#   'quality',
#   'apartment',
#   'fixtures',
#   'usually',
#   'register',
#   'within',
#   'top',
#   '5000',
#   'person',
#   'decided',
#   'relocate',
#   'order',
#   'experience',
#   'citys',
#   'constellation',
#   'michelinstarred',
#   'restaurants',
#   'fabulous',
#   'awardwinning',
#   'tap',
#   'water',
#   'odds',
#   'high',
#   'given',
#   'least',
#   'one',
#   'following',
#   'proximity',
#   'workplace',
#   'financial',
#   'ability',
#   'live',
#   'alone',
#   'reliable',
#   'cable',
#   'television',
#   'internet',
#   '10',
#   'square',
#   'feet',
#   'personal',
#   'space',
#   'bathtub',
#   'one',
#   'vaguely',
#   'imagine',
#   'taking',
#   'bath'],
#  ['athens',
#   'wildfire',
#   'winds',
#   'devoured',
#   'greek',
#   'countryside',
#   'last',
#   'summer',
#   'flames',
#   'cut',
#   'escape',
#   'routes',
#   'dozens',
#   'people',
#   'small',
#   'coastal',
#   'town',
#   'one',
#   'option',
#   'remained',
#   'sea'],
#  ['talk',
#   'kids',
#   'people',
#   'feel',
#   'says',
#   'markus',
#   'paulus',
#   'professor',
#   'developmental',
#   'psychology',
#   'ludwig',
#   'maximilian',
#   'university',
#   'munich',
#   'foster',
#   'empathic',
#   'behavior',
#   'like',
#   'sharing',
#   'helping',
#   'comforting',
#   'others',
#   'child',
#   'guide',
#   'inner',
#   'world',
#   'feelings',
#   'others',
#   'paulus',
#   'thinks',
#   'one',
#   'study',
#   'beautifully',
#   'illustrates',
#   'process',
#   'researchers',
#   'watched',
#   'parents',
#   'reading',
#   'picture',
#   'books',
#   'toddlers',
#   'found',
#   'children',
#   'asked',
#   'often',
#   'label',
#   'reflect',
#   'emotions',
#   'pictures',
#   'tended',
#   'share',
#   'quickly',
#   'often'],
#  ['want', 'get', 'briefing', 'email', 'heres', 'signup'],
#  ['golden',
#   'globes',
#   'provide',
#   'highestprofile',
#   'pit',
#   'stop',
#   'way',
#   'academy',
#   'awards',
#   'years',
#   'ceremony',
#   'perhaps',
#   'advantageously',
#   'timed',
#   'edition',
#   'yet',
#   'day',
#   'nbc',
#   'airs',
#   'globes',
#   'sunday',
#   'voting',
#   'begins',
#   'oscar',
#   'nominations',
#   'win',
#   'help',
#   'contenders',
#   'remain',
#   'front',
#   'mind',
#   'academy',
#   'members',
#   'filling',
#   'ballots',
#   'monday',
#   'plenty',
#   'winners',
#   'go',
#   'around',
#   'since',
#   'globes',
#   'spread',
#   'wealth',
#   'splitting',
#   'biggest',
#   'races',
#   'separate',
#   'categories',
#   'dramas',
#   'comedymusicals'],
#  ['us',
#   'resolved',
#   'stand',
#   'sit',
#   'less',
#   'coming',
#   'year',
#   'new',
#   'study',
#   'might',
#   'temper',
#   'expectations',
#   'benefits'],
#  ['seattle',
#   'army',
#   'recruiters',
#   'seattle',
#   'earn',
#   'friday',
#   'new',
#   'soldier',
#   'enlist',
#   'city',
#   'thriving',
#   'tech',
#   'industry',
#   'long',
#   'history',
#   'antiwar',
#   'protests',
#   'recruiters',
#   'havent',
#   'gotten',
#   'many',
#   'long',
#   'weekends'],
#  ['want', 'get', 'briefing', 'email', 'heres', 'signup'],
#  ['things',
#   'gone',
#   'bad',
#   'worse',
#   'job',
#   'maybe',
#   'companys',
#   'showing',
#   'signs',
#   'financial',
#   'trouble',
#   'boss',
#   'given',
#   'couple',
#   'stern',
#   'warnings',
#   'performance',
#   'inkling',
#   'job',
#   'might',
#   'jeopardy',
#   'heres',
#   'prepare'],
#  ['united',
#   'states',
#   'support',
#   'cooperative',
#   'relationship',
#   'china',
#   'evaporating',
#   'fast',
#   'increasingly',
#   'hear',
#   'frustration',
#   'business',
#   'leaders',
#   'structural',
#   'trade',
#   'issues',
#   'military',
#   'concerned',
#   'aggressive',
#   'geopolitical',
#   'moves',
#   'beijing',
#   'prominent',
#   'voices',
#   'political',
#   'parties',
#   'striking',
#   'increasingly',
#   'confrontational',
#   'tone',
#   'legitimate',
#   'concerns',
#   'led',
#   'vicious',
#   'cycle',
#   'negative',
#   'development',
#   'poisoning',
#   'already',
#   'shallow',
#   'well',
#   'good'],
#  ['author',
#   'recently',
#   'novel',
#   'orchestra',
#   'minorities',
#   'hardly',
#   'turned',
#   'considerations',
#   'genre',
#   'found',
#   'even',
#   'manuals',
#   'hunt',
#   'wild',
#   'birds',
#   'west',
#   'africa',
#   'fascinating'],
#  ['september',
#   '2014',
#   'bourbon',
#   'brand',
#   'called',
#   'kentucky',
#   'owl',
#   'began',
#   'appear',
#   'liquorstore',
#   'shelves',
#   'around',
#   'louisville',
#   'american',
#   'whiskey',
#   'market',
#   'booming',
#   'dozens',
#   'new',
#   'bourbons',
#   'showing',
#   'year',
#   'kentucky',
#   'owl',
#   'different',
#   'released',
#   'exclusively',
#   'within',
#   'state',
#   'tiny',
#   'quantities',
#   'produced',
#   'scion',
#   'old',
#   'kentucky',
#   'whiskey',
#   'family',
#   'undeniable',
#   'mystique',
#   'price',
#   'tag',
#   '170'],
#  ['waiting',
#   'subway',
#   'last',
#   'month',
#   'mexico',
#   'city',
#   'figured',
#   'whats',
#   'wrong',
#   'queen',
#   'movie',
#   'mean',
#   'knew',
#   'wrong',
#   'bohemian',
#   'rhapsody',
#   'scared',
#   'tapping',
#   'imagination',
#   'made',
#   'band',
#   'innovative',
#   'powerfully',
#   'addictively',
#   'strange',
#   'thats',
#   'hit',
#   'waiting',
#   'subway'],
#  ['li',
#   'chengzhi',
#   'lot',
#   'learn',
#   'first',
#   'got',
#   'job',
#   'professional',
#   'censor'],
#  ['need', 'know', 'start', 'day', 'get', 'new', 'york', 'today', 'inbox'],
#  ['san',
#   'francisco',
#   'billion',
#   'dollars',
#   'tax',
#   'revenue',
#   'taming',
#   'black',
#   'market',
#   'convenience',
#   'retail',
#   'cannabis',
#   'stores',
#   'throughout',
#   'state',
#   'promises',
#   'made',
#   'proponents',
#   'marijuana',
#   'legalization',
#   'california'],
#  ['click', 'slide', 'show', 'see', 'weeks', 'featured', 'properties'],
#  ['1981',
#   'photographer',
#   'bud',
#   'glick',
#   'began',
#   'documenting',
#   'chinatown',
#   'lower',
#   'manhattan',
#   'pivotal',
#   'time',
#   'history',
#   'waves',
#   'immigrants',
#   'hong',
#   'kong',
#   'taiwan',
#   'china',
#   'arriving',
#   'supporting',
#   'different',
#   'cultures',
#   'linguistic',
#   'backgrounds',
#   'sharing',
#   'dream',
#   'new',
#   'life',
#   'new',
#   'world'],
#  ['halmstad',
#   'sweden',
#   'maria',
#   'hussein',
#   'escaped',
#   'war',
#   'syria',
#   'many',
#   'hours',
#   'labor',
#   'swedish',
#   'hospital',
#   'midwife',
#   'realized',
#   'fetus',
#   'distress',
#   'called',
#   'obstetrician',
#   'help'],
#  ['president',
#   'trump',
#   'seems',
#   'think',
#   'hardline',
#   'immigration',
#   'stance',
#   'political',
#   'winner',
#   'saying',
#   'hes',
#   'willing',
#   'keep',
#   'much',
#   'government',
#   'shut',
#   'order',
#   'get',
#   'funding',
#   'border',
#   'wall',
#   'polls',
#   'suggest',
#   'voters',
#   'dont',
#   'see',
#   'mr',
#   'trumps',
#   'way',
#   'blame',
#   'democrats',
#   'impasse',
#   'democrats',
#   'taking',
#   'control',
#   'house',
#   'representatives',
#   'thursday',
#   'excuse',
#   'needs',
#   'make',
#   'deal'],
#  ['editor'],
#  ['ian',
#   'schrager',
#   'knows',
#   'thing',
#   'two',
#   'creating',
#   'spaces',
#   'people',
#   'clamor',
#   'get',
#   'starting',
#   'studio',
#   '54',
#   'ofthemoment',
#   'new',
#   'york',
#   'hot',
#   'spot',
#   '1970s',
#   'subject',
#   'recent',
#   'documentary',
#   '1980s',
#   'conviction',
#   'felony',
#   'tax',
#   'evasion',
#   'charges',
#   'later',
#   'pardoned',
#   'mr',
#   'schrager',
#   'left',
#   'nightclub',
#   'world',
#   'behind',
#   'struck',
#   'hotel',
#   'business',
#   'creation',
#   'morgans',
#   'hotel',
#   'group',
#   'mr',
#   'schrager',
#   'since',
#   'sold',
#   'hotel',
#   'group',
#   'renovated',
#   'sold',
#   'gramercy',
#   'park',
#   'hotel',
#   'begun',
#   'even',
#   'hospitality',
#   'ventures',
#   'including',
#   'public',
#   'hotels',
#   'collaboration',
#   'marriott',
#   'international',
#   'edition',
#   'line',
#   'hotels'],
#  ['reading', 'article'],
#  ['far',
#   'fantasy',
#   'quite',
#   'nightmare',
#   'state',
#   'like',
#   'sleep',
#   'thriller',
#   'without',
#   'thrills',
#   'every',
#   'setting',
#   'familiar',
#   'become',
#   'loaded',
#   'sense',
#   'dread',
#   'pauses',
#   'turning',
#   'corner',
#   'anticipating',
#   'horrors',
#   'never',
#   'satisfyingly',
#   'arrive'],
#  ['people',
#   '21',
#   'longer',
#   'able',
#   'buy',
#   'semiautomatic',
#   'assault',
#   'rifles',
#   'washington',
#   'jan',
#   '1',
#   'first',
#   'several',
#   'new',
#   'state',
#   'measures',
#   'intended',
#   'reduce',
#   'gun',
#   'violence',
#   'national',
#   'rifle',
#   'association',
#   'already',
#   'filed',
#   'suit'],
#  ['happy',
#   'new',
#   'year',
#   'hope',
#   'youre',
#   'rested',
#   'ready',
#   '2019',
#   'bring',
#   'politics',
#   'guide',
#   'day',
#   'national',
#   'politics',
#   'im',
#   'lisa',
#   'lerer',
#   'host'],
#  ['last',
#   'week',
#   'marathon',
#   'closing',
#   'dash',
#   '775',
#   'miles',
#   '32',
#   'sleepless',
#   'hours',
#   'american',
#   'colin',
#   'obrady',
#   'stormed',
#   'finish',
#   'line',
#   'foot',
#   'leverett',
#   'glacier',
#   'claim',
#   'first',
#   'solo',
#   'unsupported',
#   'traverse',
#   'antarctica',
#   'challenge',
#   'mr',
#   'obrady',
#   'called',
#   'impossible',
#   'first',
#   'two',
#   'days',
#   'later',
#   'culminating',
#   'rivalry',
#   'commentators',
#   'likened',
#   'race',
#   'robert',
#   'falcon',
#   'scott',
#   'roald',
#   'amundsen',
#   'reach',
#   'south',
#   'pole',
#   '191112',
#   'louis',
#   'rudd',
#   'britain',
#   'finished',
#   'arduous',
#   'journey',
#   '920',
#   'miles',
#   'across',
#   'frozen',
#   'continent',
#   'surviving',
#   'brutal',
#   'winds',
#   'whiteouts',
#   'crevasse',
#   'scares',
#   'temperatures',
#   'minus',
#   '40',
#   'degrees',
#   'fahrenheit',
#   'mr',
#   'rudds',
#   'expedition',
#   'conceived',
#   'part',
#   'tribute',
#   'friend',
#   'mentor',
#   'henry',
#   'worsley',
#   'died',
#   'peritonitis',
#   'sledding',
#   '800',
#   'miles',
#   'attempting',
#   'feat',
#   'three',
#   'years',
#   'earlier'],
#  ['let',
#   'daughter',
#   'go',
#   'college',
#   'choice',
#   'got',
#   'many',
#   'state',
#   'private',
#   'schools',
#   'scholarships',
#   'breaks',
#   'expensive',
#   'private',
#   'college',
#   'selected',
#   'loves',
#   'afford',
#   'means',
#   'constant',
#   'sacrifice',
#   'knows',
#   'doesnt',
#   'stop',
#   'regaling',
#   'us',
#   'friends',
#   'pricey',
#   'bling',
#   'fancy',
#   'travel',
#   'finally',
#   'lost',
#   'ignored',
#   'care',
#   'package',
#   'sent',
#   'exams',
#   'telling',
#   'friends',
#   'new',
#   'cartier',
#   'necklace',
#   'instead',
#   'texted',
#   'wasnt',
#   'asking',
#   'one',
#   'replied',
#   'please',
#   'stop',
#   'telling',
#   'rich',
#   'friends',
#   'luxuries',
#   'dont',
#   'want',
#   'hear'],
#  ['time',
#   'yankees',
#   'landing',
#   'troy',
#   'tulowitzki',
#   'would',
#   'trumpeted',
#   'allstar',
#   'shortstop',
#   'treading',
#   'patch',
#   'yankee',
#   'stadium',
#   'dirt',
#   'boyhood',
#   'idol',
#   'derek',
#   'jeter'],
#  ['man',
#   'charged',
#   'murder',
#   'wednesday',
#   'fatally',
#   'shot',
#   'california',
#   'police',
#   'officer',
#   'pulled',
#   'suspicion',
#   'drunken',
#   'driving',
#   'authorities',
#   'said'],
#  ['2019', 'time', 'look', 'crystal', 'ball', 'make', 'predictions'],
#  ['asunción',
#   'paraguay',
#   'allowed',
#   'inside',
#   'paraguay',
#   'jail',
#   'cell',
#   'notorious',
#   'drug',
#   'kingpin',
#   'braced',
#   'intrusive',
#   'pat',
#   'skinny',
#   'guard',
#   'standing',
#   'outside',
#   'bars',
#   'barely',
#   'touched',
#   'briskly',
#   'ran',
#   'hands',
#   'arms',
#   'back'],
#  ['better',
#   'enter',
#   'new',
#   'year',
#   'look',
#   'back',
#   'history',
#   'runs',
#   'many',
#   'weeks',
#   'recommended',
#   'titles',
#   'fall',
#   'rome',
#   'birth',
#   'islam',
#   'michelangelo',
#   '16thcentury',
#   'constantinople',
#   'paris',
#   '1960s',
#   'bag',
#   'patrick',
#   'modiano',
#   'covered',
#   'youre',
#   'interested',
#   'harlem',
#   'renaissance',
#   'never',
#   'read',
#   'jean',
#   'toomers',
#   'seminal',
#   '1923',
#   'novel',
#   'cane',
#   'helped',
#   'catalyze',
#   'movement',
#   'might',
#   'add',
#   'list',
#   'resolutions',
#   'youre',
#   'curious',
#   'philippineamerican',
#   'war',
#   'lasting',
#   'impact',
#   'inescapable',
#   'philippines',
#   'mostly',
#   'ignored',
#   'america',
#   'gina',
#   'apostols',
#   'novel',
#   'insurrecto',
#   'offers',
#   'improbably',
#   'fun',
#   'funny',
#   'guide',
#   'youre',
#   'done',
#   'maybe',
#   'pick',
#   'another',
#   'satire',
#   'asia',
# ...
#   '15second',
#   'vocabulary',
#   'video',
#   'challenge',
#   'run',
#   'jan',
#   '17',
#   'feb',
#   '18',
#   'information',
#   'visit',
#   'learning',
#   'network',
#   'jan',
#   '17',
#   'announce',
#   'rules',
#   'begin',
#   'accepting',
#   'submissions',
#   'meantime',
#   'check',
#   'last',
#   'years',
#   'rules',
#   'winners',
#   'one',
#   'shown'],
#  ['need', 'know', 'start', 'day', 'get', 'new', 'york', 'today', 'inbox'],
#  ['editor'],
#  ['tough',
#   'ways',
#   'lose',
#   'tougher',
#   'ways',
#   'lose',
#   'theres',
#   'bears',
#   'lived',
#   'sunday',
#   'front',
#   'hometown',
#   'fans',
#   'cody',
#   'parkey',
#   'missed',
#   '43yard',
#   'game',
#   'winning',
#   'field',
#   'goal',
#   'dying',
#   'seconds',
#   'wild',
#   'card',
#   'playoff',
#   'game',
#   'eagles'],
#  ['corrections', 'appeared', 'print', 'monday', 'january', '7', '2019'],
#  ['want', 'get', 'briefing', 'email', 'heres', 'signup'],
#  ['istanbul',
#   'spiritual',
#   'leader',
#   'eastern',
#   'orthodox',
#   'christians',
#   'worldwide',
#   'recognized',
#   'independence',
#   'orthodox',
#   'church',
#   'ukraine',
#   'fourhour',
#   'ceremony',
#   'istanbul',
#   'sunday',
#   'formalizing',
#   'split',
#   'russian',
#   'church',
#   'tied',
#   'four',
#   'centuries'],
#  ['first',
#   'tuna',
#   'auction',
#   'year',
#   'tokyos',
#   'new',
#   'fish',
#   'market',
#   'set',
#   'high',
#   'bar',
#   'saturday',
#   'restaurant',
#   'chain',
#   'paid',
#   'record',
#   'price',
#   '3',
#   'million',
#   'giant',
#   'bluefin',
#   'tuna'],
#  ['editor'],
#  ['times',
#   'insider',
#   'delivers',
#   'behindthescenes',
#   'insights',
#   'news',
#   'features',
#   'opinion',
#   'come',
#   'together',
#   'new',
#   'york',
#   'times'],
#  ['year',
#   'bucking',
#   'bulls',
#   'arrive',
#   'madison',
#   'square',
#   'garden',
#   'livestock',
#   'trailers',
#   'pull',
#   '33rd',
#   'street',
#   'back',
#   'ramps',
#   'lead',
#   'five',
#   'floors',
#   'arena'],
#  ['good',
#   'morning',
#   'want',
#   'week',
#   'follow',
#   'tejal',
#   'raos',
#   'new',
#   'recipe',
#   'mallstyle',
#   'barbecue',
#   'chicken',
#   'pizza',
#   'dish',
#   'wrote',
#   'movingly',
#   'times',
#   'day'],
#  ['2019', 'golden', 'globes', 'didnt', 'want', 'trouble'],
#  ['tom',
#   'thibodeau',
#   'minnesota',
#   'timberwolves',
#   'coach',
#   'president',
#   'abruptly',
#   'fired',
#   'sunday',
#   'night',
#   '22point',
#   'victory'],
#  ['update',
#   'woman',
#   'allowed',
#   'enter',
#   'thailand',
#   'request',
#   'refugee',
#   'status',
#   'processed',
#   'read',
#   'latest'],
#  ['many',
#   'immature',
#   'mammals',
#   'practice',
#   'hunting',
#   'fighting',
#   'skills',
#   'preparation',
#   'real',
#   'thing',
#   'anyone',
#   'raised',
#   'litter',
#   'kittens',
#   'observed',
#   'almost',
#   'continuous',
#   'cycles',
#   'pursuit',
#   'evasion',
#   'capture',
#   'attempted',
#   'evisceration',
#   'sometimes',
#   'even',
#   'mock',
#   'version',
#   'killing',
#   'bite',
#   'fortunately',
#   'rules',
#   'game',
#   'seem',
#   'stop',
#   'killer',
#   'kitten',
#   'short',
#   'committing',
#   'real',
#   'bodily',
#   'harm',
#   'littermate'],
#  ['read', 'updates', 'analysis', 'golden', 'globes', 'ceremony'],
#  ['mosquitoborne',
#   'virus',
#   'causes',
#   'rift',
#   'valley',
#   'fever',
#   'may',
#   'severely',
#   'injure',
#   'human',
#   'fetuses',
#   'contracted',
#   'mothers',
#   'pregnancy',
#   'according',
#   'new',
#   'research'],
#  ['washington',
#   'world',
#   'bank',
#   'said',
#   'monday',
#   'president',
#   'jim',
#   'yong',
#   'kim',
#   'would',
#   'step',
#   'post',
#   'february',
#   'join',
#   'private',
#   'infrastructure',
#   'investment',
#   'firm',
#   'unexpected',
#   'departure',
#   'comes',
#   'nearly',
#   'three',
#   'years',
#   'end',
#   'term'],
#  ['tijuana',
#   'life',
#   'tijuanas',
#   'largest',
#   'migrant',
#   'shelter',
#   'begun',
#   'take',
#   'familiar',
#   'rhythms',
#   'sounds',
#   'central',
#   'american',
#   'neighborhood',
#   'early',
#   'morning',
#   'adults',
#   'rise',
#   'get',
#   'ready',
#   'go',
#   'work',
#   'children',
#   'dress',
#   'school',
#   'mothers',
#   'gather',
#   'huge',
#   'bundles',
#   'dirty',
#   'clothes',
#   'days',
#   'wash',
#   'vendors',
#   'hawk',
#   'coffee'],
#  ['nan'],
#  ['sylvia',
#   'chase',
#   'emmy',
#   'awardwinning',
#   'correspondent',
#   'whose',
#   'professionalism',
#   'perseverance',
#   '1970s',
#   'helped',
#   'generation',
#   'women',
#   'infiltrate',
#   'boys',
#   'club',
#   'television',
#   'news',
#   'died',
#   'thursday',
#   'marin',
#   'county',
#   'calif',
#   '80'],
#  ['dry',
#   'alabama',
#   'facebook',
#   'page',
#   'illustrated',
#   'stark',
#   'images',
#   'car',
#   'wrecks',
#   'videos',
#   'families',
#   'ruined',
#   'drink',
#   'blunt',
#   'message',
#   'alcohol',
#   'devils',
#   'work',
#   'state',
#   'ban',
#   'entirely'],
#  ['susan',
#   'zirinsky',
#   'longtime',
#   'producer',
#   '48',
#   'hours',
#   'cbs',
#   'succeed',
#   'david',
#   'rhodes',
#   'president',
#   'networks',
#   'news',
#   'division',
#   'march',
#   'company',
#   'said',
#   'sunday',
#   'night'],
#  ['budapest',
#   'gyula',
#   'radics',
#   'easily',
#   'angered',
#   'prime',
#   'minister',
#   'viktor',
#   'orban',
#   'rewrote',
#   'constitution',
#   'give',
#   'party',
#   'greater',
#   'power',
#   'stayed',
#   'sidelines',
#   'party',
#   'took',
#   'state',
#   'media',
#   'silent',
#   'government',
#   'forced',
#   'internationally',
#   'renowned',
#   'central',
#   'european',
#   'university',
#   'hungary',
#   'join',
#   'protests'],
#  ['deborah',
#   'westbrook',
#   'lifelong',
#   'resident',
#   'detroit',
#   'would',
#   'love',
#   'tree',
#   'front',
#   'home'],
#  ['michigan',
#   'uber',
#   'driver',
#   'accused',
#   'killing',
#   'six',
#   'people',
#   'wounding',
#   'two',
#   'others',
#   '2016',
#   'shooting',
#   'spree',
#   'pleaded',
#   'guilty',
#   'murder',
#   'monday',
#   'trial',
#   'set',
#   'begin'],
#  ['harold',
#   'brown',
#   'brilliant',
#   'scientist',
#   'helped',
#   'develop',
#   'americas',
#   'nuclear',
#   'arsenal',
#   'negotiate',
#   'first',
#   'strategic',
#   'arms',
#   'control',
#   'treaty',
#   'president',
#   'jimmy',
#   'carters',
#   'secretary',
#   'defense',
#   'era',
#   'rising',
#   'soviet',
#   'challenges',
#   'died',
#   'friday',
#   'home',
#   'rancho',
#   'santa',
#   'fe',
#   'calif',
#   '91'],
#  ['believe',
#   'age',
#   'mutual',
#   'deterrence',
#   'still',
#   'age',
#   'mutual',
#   'deterrence',
#   'superpowers',
#   'behave',
#   'way',
#   'hedgehogs',
#   'make',
#   'love',
#   'carefully'],
#  ['president',
#   'trump',
#   'made',
#   'right',
#   'call',
#   'withdraw',
#   'syria',
#   'united',
#   'states',
#   'withdrawal',
#   'however',
#   'must',
#   'planned',
#   'carefully',
#   'performed',
#   'cooperation',
#   'right',
#   'partners',
#   'protect',
#   'interests',
#   'united',
#   'states',
#   'international',
#   'community',
#   'syrian',
#   'people',
#   'turkey',
#   'natos',
#   'second',
#   'largest',
#   'standing',
#   'army',
#   'country',
#   'power',
#   'commitment',
#   'perform',
#   'task'],
#  ['time',
#   'years',
#   'ago',
#   'would',
#   'refer',
#   'new',
#   'psychotherapy',
#   'clients',
#   'video',
#   'clip',
#   'appearance',
#   'comedian',
#   'louis',
#   'ck',
#   'conan',
#   'obriens',
#   'talk',
#   'show',
#   'begins',
#   'funny',
#   'bit',
#   'louis',
#   'ck',
#   'thinks',
#   'cellphones',
#   'bad',
#   'teenagers',
#   'turns',
#   'thoughtful',
#   'rumination',
#   'way',
#   'use',
#   'cellphones',
#   'avoid',
#   'dealing',
#   'pain',
#   'life',
#   'becomes',
#   'touching',
#   'plea',
#   'feeling',
#   'feelings',
#   'youre',
#   'lucky',
#   'live',
#   'sad',
#   'moments',
#   'says',
#   'recounting',
#   'powerful',
#   'experience',
#   'loneliness',
#   'life',
#   'grateful',
#   'feel',
#   'sad',
#   'met',
#   'true',
#   'profound',
#   'happiness'],
#  ['walls',
#   'protect',
#   'walls',
#   'divide',
#   'statements',
#   'true',
#   'yet',
#   'perhaps',
#   'issue',
#   'represents',
#   'deep',
#   'political',
#   'chasm',
#   'separating',
#   'country',
#   'wall',
#   'big',
#   'beautiful',
#   'wall',
#   'words',
#   'president',
#   'trump'],
#  ['editor'],
#  ['bohemian',
#   'rhapsody',
#   'best',
#   'drama',
#   'star',
#   'rami',
#   'malek',
#   'best',
#   'actor',
#   'golden',
#   'globes',
#   'sunday',
#   'night',
#   'green',
#   'book',
#   'took',
#   'home',
#   'three',
#   'awards',
#   'including',
#   'best',
#   'movie',
#   'musical',
#   'comedy',
#   'glenn',
#   'close',
#   'best',
#   'actress',
#   'drama',
#   'award',
#   'many',
#   'expected',
#   'go',
#   'lady',
#   'gaga',
#   'heres',
#   'complete',
#   'list',
#   'winners'],
#  ['outside',
#   'golden',
#   'globes',
#   'weather',
#   'sunny',
#   'mood',
#   'equally',
#   'light',
#   'red',
#   'carpet',
#   'talked',
#   'stars',
#   'filmmakers',
#   'years',
#   'popular',
#   'films',
#   'crazy',
#   'rich',
#   'asians',
#   'spiderman',
#   'spiderverse'],
#  ['san',
#   'jose',
#   'calif',
#   '85',
#   'degrees',
#   'tuscaloosa',
#   'ala',
#   'aug',
#   '18',
#   'nick',
#   'saban',
#   'feeling',
#   'heat'],
#  ['jerusalem',
#   'moshe',
#   'arens',
#   'israeli',
#   'politician',
#   'statesman',
#   'one',
#   'last',
#   'countrys',
#   'founding',
#   'generation',
#   'rightwing',
#   'liberal',
#   'zionists',
#   'held',
#   'top',
#   'posts',
#   'never',
#   'achieved',
#   'greatest',
#   'aspirations',
#   'died',
#   'monday',
#   'home',
#   'savyon',
#   'israel',
#   '93'],
#  ['need', 'know', 'start', 'day', 'get', 'new', 'york', 'today', 'inbox'],
#  ['sabra',
#   'jewish',
#   'person',
#   'born',
#   'israel',
#   'term',
#   'related',
#   'arabic',
#   'word',
#   'sabr',
#   'means',
#   'patience',
#   'perseverance'],
#  ['listen',
#   'subscribe',
#   'podcast',
#   'mobile',
#   'device',
#   'via',
#   'apple',
#   'podcasts',
#   'via',
#   'radiopublic',
#   'via',
#   'stitcher'],
#  ['100',
#   'billion',
#   'dollar',
#   'health',
#   'care',
#   'package',
#   'proposed',
#   'congressional',
#   'republicans',
#   'past',
#   'summer',
#   'afterward',
#   'endorsed',
#   'democrats',
#   'aims',
#   'save',
#   'money',
#   'encouraging',
#   'make',
#   'big',
#   'life',
#   'changes',
#   'package',
#   'probably',
#   'fail',
#   'achieve',
#   'goals',
#   'simple',
#   'reason',
#   'scarcity',
#   'chances',
#   'dont',
#   'time',
#   'money',
#   'bandwidth',
#   'follow'],
#  ['editor'],
#  ['washington',
#   'became',
#   'chief',
#   'sticking',
#   'point',
#   'government',
#   'shutdown',
#   'drama',
#   'threatens',
#   'consume',
#   'presidency',
#   'critical',
#   'moment',
#   'president',
#   'trumps',
#   'promise',
#   'build',
#   'wall',
#   'southwestern',
#   'border',
#   'memory',
#   'trick',
#   'undisciplined',
#   'candidate'],
#  ['familiar',
#   'concept',
#   'mutual',
#   'fund',
#   'right',
#   'mutual',
#   'fund',
#   'box',
#   'put',
#   'money',
#   'side',
#   'comes',
#   'money',
#   'hooray'],
#  ['thus',
#   'promise',
#   'redcarpet',
#   'change',
#   'hovered',
#   'golden',
#   'globes',
#   'year',
#   'ago',
#   'women',
#   'took',
#   'back',
#   'wardrobes',
#   'night',
#   'get',
#   'squandered'],
#  ['pegi',
#   'young',
#   'lateblossoming',
#   'folkrock',
#   'musician',
#   'founder',
#   'school',
#   'children',
#   'severe',
#   'physical',
#   'speech',
#   'impairments',
#   'like',
#   'son',
#   'marriage',
#   'singersongwriter',
#   'neil',
#   'young',
#   'performer',
#   'many',
#   'starstudded',
#   'benefit',
#   'concerts',
#   'died',
#   'tuesday',
#   'mountain',
#   'view',
#   'calif',
#   '66'],
#  ['shalynn',
#   'womack',
#   '60',
#   'years',
#   'old',
#   'lives',
#   'lot',
#   'economic',
#   'uncertainty',
#   'shes',
#   'one',
#   'group',
#   'says',
#   'didnt',
#   'get',
#   'life',
#   'thought',
#   'welleducated',
#   'would',
#   'provide',
#   'ms',
#   'womack',
#   'lives',
#   'tennessee',
#   'still',
#   'plagued',
#   'sense',
#   'must',
#   'done',
#   'something',
#   'terribly',
#   'wrong',
#   'somewhere',
#   'along',
#   'way'],
#  ['pretribeca',
#   'nonolita',
#   'downtown',
#   'manhattan',
#   'mid1970s',
#   'place',
#   'quiet',
#   'darkness',
#   'hidden',
#   'clubs'],
#  ['good', 'monday', 'morning', 'want', 'email', 'sign'],
#  ['need', 'know', 'start', 'day', 'get', 'new', 'york', 'today', 'inbox'],
#  ['one',
#   'good',
#   'meal',
#   'ask',
#   'cookinginclined',
#   'creative',
#   'people',
#   'share',
#   'story',
#   'behind',
#   'favorite',
#   'dish',
#   'actually',
#   'make',
#   'eat',
#   'home',
#   'regular',
#   'basis',
#   'theyre',
#   'trying',
#   'impress'],
#  ['howell',
#   'begle',
#   'washington',
#   'lawyer',
#   'found',
#   'second',
#   'career',
#   'crusading',
#   'behalf',
#   'underpaid',
#   'black',
#   'rb',
#   'stars',
#   '1950s',
#   '60s',
#   'leading',
#   'industrywide',
#   'royalty',
#   'reform',
#   'creation',
#   'charitable',
#   'rhythm',
#   'blues',
#   'foundation',
#   'died',
#   'dec',
#   '30',
#   'hospital',
#   'lebanon',
#   'nh',
#   '74'],
#  ['surviving',
#   'r',
#   'kelly',
#   'sixpart',
#   'documentary',
#   'rb',
#   'singer',
#   'robert',
#   'kelly',
#   'faced',
#   'accusations',
#   'child',
#   'sexual',
#   'abuse',
#   'decades',
#   'underscores',
#   'theme',
#   'accountability',
#   'kelly',
#   'many',
#   'personal',
#   'enablers',
#   'us'],
#  ['read', 'updates', 'analysis', 'golden', 'globes', 'ceremony'],
#  ['bangkok',
#   '18yearold',
#   'saudi',
#   'woman',
#   'expressed',
#   'fear',
#   'would',
#   'killed',
#   'sent',
#   'back',
#   'family',
#   'allowed',
#   'remain',
#   'thailand',
#   'monday',
#   'evening',
#   'ending',
#   'tense',
#   '48hour',
#   'drama',
#   'bangkoks',
#   'main',
#   'international',
#   'airport'],
#  ['please',
#   'sign',
#   'racerelated',
#   'newsletter',
#   'delivered',
#   'weekly',
#   'inbox'],
#  ['washington', 'lucky', 'theres', 'saturday', 'detention', 'capitol'],
#  ['granted', 'strange', 'way', 'run', 'subway'],
#  ['capping',
#   'golden',
#   'globes',
#   'ceremony',
#   'belonged',
#   'audience',
#   'favorites',
#   'critical',
#   'darlings',
#   'bohemian',
#   'rhapsody',
#   'star',
#   'rami',
#   'malek',
#   'played',
#   'spoiler',
#   'star',
#   'born',
#   'battle',
#   'two',
#   'musicals',
#   'competing',
#   'best',
#   'drama',
#   'category',
#   'film',
#   'neither',
#   'however',
#   'currently',
#   'streaming',
#   'major',
#   'movie',
#   'winners',
#   'except',
#   'netflixs',
#   'roma',
#   'prizes',
#   'director',
#   'alfonso',
#   'cuarón',
#   'best',
#   'foreign',
#   'language',
#   'movie'],
#  ['lady',
#   'gaga',
#   'long',
#   'used',
#   'red',
#   'carpet',
#   'independent',
#   'artistic',
#   'medium',
#   'showed',
#   'golden',
#   'globes',
#   'wearing',
#   'vivid',
#   'shade',
#   'light',
#   'purple',
#   'perhaps',
#   'kind',
#   'lunar',
#   'blue',
#   'hair',
#   'dyed',
#   'match'],
#  ['almost',
#   '40',
#   'years',
#   'passed',
#   'since',
#   'daniel',
#   'patrick',
#   'moynihan',
#   'serious',
#   'intellectual',
#   'turned',
#   'influential',
#   'politician',
#   'made',
#   'waves',
#   'declaring',
#   'sudden',
#   'republicans',
#   'become',
#   'party',
#   'ideas',
#   'didnt',
#   'say',
#   'good',
#   'ideas',
#   'gop',
#   'seemed',
#   'open',
#   'new',
#   'thinking',
#   'way',
#   'democrats',
#   'werent'],
#  ['first',
#   'time',
#   'met',
#   'jerry',
#   'brown',
#   'judging',
#   'dutch',
#   'oven',
#   'cookoff',
#   'contest',
#   'colusa',
#   'western',
#   'days',
#   'festival',
#   'sixteen',
#   'teams',
#   'set',
#   'outdoor',
#   'ovens',
#   'fairgrounds',
#   'compete',
#   'best',
#   'main',
#   'dish',
#   'side',
#   'bread',
#   'dessert',
#   'cooked',
#   'open',
#   'fires',
#   'cast',
#   'iron',
#   'pots',
#   'governor',
#   'california',
#   'wife',
#   'anne',
#   'judged',
#   'team',
#   'almost',
#   'everything'],
#  ['writing',
#   'never',
#   'lucrative',
#   'career',
#   'choice',
#   'recent',
#   'study',
#   'authors',
#   'guild',
#   'professional',
#   'organization',
#   'book',
#   'writers',
#   'shows',
#   'may',
#   'even',
#   'livable',
#   'one',
#   'anymore'],
#  ['london',
#   'joseph',
#   'caselyhayford',
#   'one',
#   'first',
#   'black',
#   'british',
#   'fashion',
#   'designers',
#   'win',
#   'international',
#   'acclaim',
#   'whose',
#   'clothes',
#   'worn',
#   'michael',
#   'jackson',
#   'bono',
#   'drake',
#   'died',
#   'thursday',
#   '62'],
#  ['keep',
#   'coming',
#   'armed',
#   'replica',
#   'automatic',
#   'weapons',
#   'firing',
#   'blanks',
#   'gallons',
#   'stage',
#   'blood',
#   'mangled',
#   'mexican',
#   'accents',
#   'cartels',
#   'streaming',
#   'across',
#   'undefended',
#   'border',
#   'multiplexes',
#   'video',
#   'streams'],
#  ['dakar',
#   'senegal',
#   'government',
#   'gabon',
#   'quickly',
#   'beat',
#   'back',
#   'coup',
#   'attempt',
#   'monday',
#   'killing',
#   'two',
#   'suspects',
#   'arresting',
#   'eight',
#   'others',
#   'plotters',
#   'took',
#   'state',
#   'radio',
#   'station',
#   'central',
#   'african',
#   'nation',
#   'announced',
#   'plans',
#   'national',
#   'council',
#   'restoration',
#   'country',
#   'one',
#   'family',
#   'held',
#   'presidency',
#   'almost',
#   'half',
#   'century'],
#  ['welcome',
#   'weekend',
#   'new',
#   'year',
#   'youve',
#   'got',
#   'resolutions',
#   'losing',
#   'weight',
#   'calling',
#   'mom',
#   'often',
#   'making',
#   'new',
#   'friends',
#   'actually',
#   'putting',
#   'laundry',
#   'away',
#   'get',
#   'first',
#   'take',
#   'time',
#   'read',
#   'amazing',
#   'journalism'],
#  ...]

# %% [markdown]
# * Removing less frequent words:

# %%
frequency = defaultdict(int)
for headline_text in headline_texts:
    for token in headline_text:
         frequency[token] += 1
for keywords_text in keywords_texts:
    for token in keywords_text:
         frequency[token] += 1
for lead_text in lead_texts:
    for token in lead_text:
         frequency[token] += 1
            
headline_texts = [[token for token in headline_text if frequency[token] > 1] for headline_text in headline_texts]
keywords_texts = [[token for token in keywords_text if frequency[token] > 1] for keywords_text in keywords_texts]
lead_texts = [[token for token in lead_text if frequency[token] > 1] for lead_text in lead_texts]

# %%
dictionary_headline = corpora.Dictionary(headline_texts)
dictionary_keywords = corpora.Dictionary(keywords_texts)
dictionary_lead = corpora.Dictionary(lead_texts)

# %%
headline_corpus = [dictionary.doc2bow(headline_text) for headline_text in headline_texts]
keywords_corpus = [dictionary.doc2bow(keywords_text) for keywords_text in keywords_texts]
lead_corpus = [dictionary.doc2bow(lead_text) for lead_text in lead_texts]

# %%
NUM_TOPICS = 5  
ldamodel_headlines = LdaModel(headline_corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=12)
ldamodel_keywords = LdaModel(keywords_corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=12)
ldamodel_lead = LdaModel(lead_corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=12)

# %%
topics_headlines = ldamodel_headlines.show_topics()
for topic_headlines in topics_headlines:
    print(topic_headlines)
# Out:
# (0, '0.019*"briefing" + 0.017*"dies" + 0.006*"trump" + 0.006*"dead" + 0.006*"police" + 0.005*"us" + 0.005*"joe" + 0.005*"man" + 0.004*"top" + 0.004*"hurricane"')
# (1, '0.014*"election" + 0.012*"trump" + 0.012*"day" + 0.009*"primary" + 0.008*"results" + 0.008*"california" + 0.007*"democratic" + 0.007*"us" + 0.007*"million" + 0.006*"district"')
# (2, '0.050*"new" + 0.014*"york" + 0.011*"tv" + 0.010*"convention" + 0.009*"night" + 0.008*"whats" + 0.008*"city" + 0.007*"power" + 0.006*"climate" + 0.006*"change"')
# (3, '0.019*"review" + 0.012*"biden" + 0.010*"week" + 0.010*"2020" + 0.009*"2019" + 0.006*"corrections" + 0.006*"court" + 0.006*"open" + 0.005*"best" + 0.005*"republicans"')
# (4, '0.025*"trump" + 0.012*"impeachment" + 0.009*"world" + 0.008*"hong" + 0.007*"says" + 0.007*"house" + 0.007*"kong" + 0.007*"trumps" + 0.006*"white" + 0.006*"us"')

# %%
topics_keywords = ldamodel_keywords.show_topics()
for topic_keywords in topics_keywords:
    print(topic_keywords)
# Out:
# (0, '0.036*"estate" + 0.036*"real" + 0.034*"coronavirus" + 0.031*"housing" + 0.028*"residential" + 0.028*"music" + 0.022*"fashion" + 0.021*"weddings" + 0.019*"travel" + 0.015*"global"')
# (1, '0.082*"states" + 0.081*"united" + 0.076*"government" + 0.075*"politics" + 0.044*"2020" + 0.041*"election" + 0.041*"presidential" + 0.021*"international" + 0.018*"impeachment" + 0.018*"us"')
# (2, '0.046*"books" + 0.045*"literature" + 0.023*"deaths" + 0.023*"coronavirus" + 0.023*"art" + 0.016*"theater" + 0.015*"cooking" + 0.015*"safety" + 0.015*"life" + 0.015*"cookbooks"')
# (3, '0.032*"media" + 0.026*"social" + 0.025*"trumpukraine" + 0.025*"complaint" + 0.025*"inquiry" + 0.025*"whistleblower" + 0.023*"news" + 0.019*"computers" + 0.019*"shootings" + 0.018*"internet"')
# (4, '0.030*"black" + 0.024*"movies" + 0.024*"people" + 0.023*"blacks" + 0.019*"television" + 0.019*"rights" + 0.018*"women" + 0.018*"girls" + 0.018*"race" + 0.016*"discrimination"')

# %%
topics_lead = ldamodel_lead.show_topics()
for topic_lead in topics_lead:
    print(topic_lead)
# Out:
# (0, '0.022*"new" + 0.013*"york" + 0.010*"city" + 0.009*"people" + 0.009*"said" + 0.008*"police" + 0.007*"school" + 0.006*"via" + 0.006*"week" + 0.006*"two"')
# (1, '0.020*"president" + 0.015*"trump" + 0.011*"washington" + 0.009*"states" + 0.008*"united" + 0.006*"said" + 0.006*"would" + 0.006*"democratic" + 0.005*"national" + 0.005*"house"')
# (2, '0.028*"get" + 0.022*"want" + 0.019*"new" + 0.016*"sign" + 0.015*"email" + 0.015*"times" + 0.015*"heres" + 0.013*"york" + 0.011*"signup" + 0.011*"newsletter"')
# (3, '0.006*"years" + 0.005*"new" + 0.005*"first" + 0.005*"home" + 0.004*"one" + 0.004*"world" + 0.004*"two" + 0.004*"married" + 0.003*"died" + 0.003*"art"')
# (4, '0.010*"like" + 0.009*"one" + 0.007*"time" + 0.005*"even" + 0.005*"would" + 0.004*"night" + 0.004*"many" + 0.004*"first" + 0.004*"us" + 0.004*"back"')

# %%
word_dict_headlines = {};
for i in range(NUM_TOPICS):
    words_headlines = ldamodel_headlines.show_topic(i, topn = 20)
    word_dict_headlines['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in words_headlines]
pd.DataFrame(word_dict_headlines)
# Out:
#    Topic # 01     Topic # 02   Topic # 03   Topic # 04   Topic # 05
# 0    briefing       election          new       review        trump
# 1        dies          trump         york        biden  impeachment
# 2       trump            day           tv         week        world
# 3        dead        primary   convention         2020         hong
# 4      police        results        night         2019         says
# 5          us     california        whats  corrections        house
# 6         joe     democratic         city        court         kong
# 7         man             us        power         open       trumps
# 8         top        million      climate         best        white
# 9   hurricane       district       change  republicans           us
# 10    tuesday           says       health       summer          nyc
# 11       quiz            get           us          big          war
# 12    johnson  congressional         need        trump      weekend
# 13      black            one  coronavirus        watch        china
# 14    evening      quotation       crisis    democrats         back
# 15    ukraine           2020        great       debate         like
# 16          1           time       market         love   republican
# 17        say         harris         fire     business        trade
# 18       cant        college        fight         race           go
# 19      years          virus         know        books    president

# %%
word_dict_keywords = {};
for i in range(NUM_TOPICS):
    words_keywords = ldamodel_keywords.show_topic(i, topn = 20)
    word_dict_keywords['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in words_keywords]
pd.DataFrame(word_dict_keywords)
# Out:
#        Topic # 01     Topic # 02   Topic # 03     Topic # 04      Topic # 05
# 0          estate         states        books          media           black
# 1            real         united   literature         social          movies
# 2     coronavirus     government       deaths        inquiry          people
# 3         housing       politics  coronavirus  whistleblower          blacks
# 4     residential           2020          art   trumpukraine      television
# 5           music       election      theater      complaint          rights
# 6         fashion   presidential      cooking           news           women
# 7        weddings  international       safety      computers           girls
# 8          travel    impeachment         life      shootings            race
# 9          global             us    cookbooks       internet  discrimination
# 10        warming      relations    vacations         police     coronavirus
# 11        apparel      elections      culture     misconduct           civil
# 12          rates       protests       health           2016       education
# 13  institutional        defense   quarantine      brutality           human
# 14           rock       military      writing          trump        movement
# 15            pop         forces      writers           2019        colleges
# 16       baseball        murders         food    advertising    universities
# 17      emissions       national  restaurants           ties        football
# 18            gas     convention      traffic        russian           labor
# 19         design    immigration    accidents     associates       childhood

# %%
word_dict_lead = {};
for i in range(NUM_TOPICS):
    words_lead  = ldamodel_lead.show_topic(i, topn = 20)
    word_dict_lead ['Topic # ' + '{:02d}'.format(i+1)] = [i[0] for i in words_lead]
pd.DataFrame(word_dict_lead)
# Out:
#    Topic # 01  Topic # 02  Topic # 03  Topic # 04 Topic # 05
# 0         new   president         get       years       like
# 1        york       trump        want         new        one
# 2        city  washington         new       first       time
# 3      people      states        sign        home       even
# 4        said      united       email         one      would
# 5      police        said       times       world      night
# 6      school       would       heres         two       many
# 7         via  democratic        york     married      first
# 8        week    national      signup        died         us
# 9         two       house  newsletter         art       back
# 10        man      former    briefing        sept       make
# 11        los    american     morning         ago       work
# 12       died     tuesday       today       house        way
# 13    angeles    thursday        good        city       much
# 14      start       state     article       weeks       year
# 15      music   political        part    american     editor
# 16        san   wednesday        hong         see      could
# 17        one     federal         day       since       best
# 18      black      trumps       inbox      became     season
# 19     killed  government         nan  collection      years

# %% [markdown]
# ### Predominant topics discovered:

# %% [markdown]
# * Politics: elections, federal government, impeachment and immigration
# * Race and gender: representation, activism and police brutality
# * Crisis: pandemic, global warming and natural disaster
# * Quarantine: new way of life and new pastimes
